# %% [markdown]
# # NB06d — Reptile Meta-Learning ADAPTATIU sobre PPO Agent (Dense Reward)
#
# **Objectiu**: Entrena un agent PPO amb **Reptile meta-learning adaptatiu** que:
# - **Inner loops dinàmics**: Cada tasca s'entrena fins que **convergeix** (mètrica ho detecta)
# - **Outer updates automàtics**: Quan s'acumulen N tasques O passa X temps
# - **Early stopping global**: Para quan el meta-agent **convergeix** sobre val
#
# ## Diferències vs. versió clàssica
#
# | Aspecte | Clàssic | Adaptatiu |
# |---------|---------|----------|
# | Inner steps | **Fix** (10k steps) | **Dinàmic** (fins convergir, 5k-30k) |
# | Batch size | **Fix** (10 tasques) | **Dinàmic** (acumula fins 5 o timeout) |
# | Meta iters | **Fix** (15k iters) | **Dinàmic** (para quan val sharpe convergeix) |
# | Filtratge | **Cap** | **Automàtic** (només tasques convergides) |
# | Budget | **1.5B steps** (!!) | **~10-50M steps** (eficient) |
#
# ## Sistema adaptatiu
#
# ```
# ┌─ META-ENTRENAMENT (loop principal) ───────────────────┐
# │                                                       │
# │  ┌─ INNER LOOP BATCH ──────────────────────────┐    │
# │  │  → Tasca 1: entrena fins convergir (Sharpe) │    │
# │  │  → Tasca 2: entrena fins convergir          │    │
# │  │  → Tasca 3: entrena fins convergir          │    │
# │  │  → ... (fins N tasques o timeout)           │    │
# │  └──────────────────────────────────────────────┘    │
# │              ↓                                        │
# │  ┌─ OUTER UPDATE (Reptile) ───────────────────┐     │
# │  │  θ ← θ + ε·mean(φᵢ - θ)                    │     │
# │  └──────────────────────────────────────────────┘    │
# │              ↓                                        │
# │  ┌─ AVALUACIÓ META (periòdica) ───────────────┐     │
# │  │  Val Sharpe → early stopping?              │     │
# │  └──────────────────────────────────────────────┘    │
# │              ↓                                        │
# │         Convergit? → PARA                             │
# │         NO → REPEAT                                   │
# └───────────────────────────────────────────────────────┘
# ```

# %%
# =============================================================================
# CEL·LA 1 — IMPORTS
# =============================================================================

import copy
import json
import os as _os
import random
import sys
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import polars as pl
import torch
from codecarbon import EmissionsTracker
from tqdm.auto import tqdm

from src.data.manager import DataManager
from src.rl.agents.actor_critic_policy import ActorCriticPolicy
from src.rl.envs.crypto_market_env import (
    CryptoMarketEnv, INITIAL_BALANCE, MAX_EPISODE_STEPS,
    W_PNL, steps_per_4h_for, REALIZE_BONUS_SCALE,
)
from src.rl.metrics import compute_sharpe, compute_max_drawdown

# Import sistema adaptatiu
# # sys.path.insert(0, str(Path.cwd()))
from src.rl.meta_learning import (
    AdaptiveReptile,
    InnerConvergenceCriteria,
    OuterUpdateTrigger,
    MetaConvergenceCriteria,
)

warnings.filterwarnings('ignore')
print('Imports OK')
# Out:
# Imports OK

# %%
# =============================================================================
# CEL·LA 2 — CONFIGURACIÓ: SEED, DEVICE, PATHS
# =============================================================================

# Reproducibilitat
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {DEVICE}')

# CWD
_cwd = Path.cwd()
if not (_cwd / 'data' / 'processed').exists():
    _root = _cwd.parents[1]
    if (_root / 'data' / 'processed').exists():
        _os.chdir(_root)
        print(f'CWD -> {Path.cwd()}')

# ── SELECTOR: BASE AGENT (MODIFICAR AQUÍ) ────────────────────────────────────
USE_PRETRAINED = False  # True = _adj (ajusta checkpoint), False = _new (fresh init)

# Agents disponibles per meta-learning
AVAILABLE_AGENTS = {
    'ppo_pytorch_dense_final': 'checkpoints_dense/ppo_pytorch_dense_final.pt',
    'ppo_pytorch_sparse_final': 'checkpoints_sparse/ppo_pytorch_sparse_final.pt',
}

BASE_AGENT = 'ppo_pytorch_dense_final'  # ← CANVIA AIXÒ per seleccionar checkpoint

if BASE_AGENT not in AVAILABLE_AGENTS:
    raise ValueError(f"BASE_AGENT desconegut: '{BASE_AGENT}'")

# ──────────────────────────────────────────────────────────────────────────────

# Paths
BEST_PARAMS_PATH = Path('checkpoints_dense/ppo_best_params.json')
RESULTS  = Path('results_dense') / '06d_ppo_reptile_adaptive_new'
RESULTS.mkdir(parents=True, exist_ok=True)
CODECARBON_DIR = RESULTS / 'codecarbon'
CODECARBON_DIR.mkdir(parents=True, exist_ok=True)

# Variant naming: _adj si pre-trained, _new si fresh init
variant = '_adj' if USE_PRETRAINED else '_new'
META_CKPT = Path(f'checkpoints_dense/ppo_reptile_meta{variant}_adaptative.pt')

# Dades
TIMEFRAME = '60m'
STEPS_PER_WEEK = 7 * 24  # 168 passos/setmana a 60m

print(f'Selector: USE_PRETRAINED={USE_PRETRAINED}, BASE_AGENT={BASE_AGENT}')
print(f'Variant: {variant}')
print(f'Meta checkpoint: {META_CKPT.name}')
print(f'Paths OK')
# Out:
# Device: cuda
# CWD -> c:\Users\Xavier\S9_M2.981 - TFM\00_Documentacio\Activitats\Modul_3\quant_rl_trader
# Selector: USE_PRETRAINED=False, BASE_AGENT=ppo_pytorch_dense_final
# Variant: _new
# Meta checkpoint: ppo_reptile_meta_new_adaptative.pt
# Paths OK

# %%
# =============================================================================
# CEL·LA 3 — CRITERIS DE CONVERGÈNCIA (sistema adaptatiu)
# =============================================================================

# ── Inner Loop Convergence ───────────────────────────────────────────────────
inner_criteria = InnerConvergenceCriteria(
    min_steps=5_000,                    # Mínim d'steps abans d'avaluar
    max_steps=30_000,                   # Màxim (timeout per tasca)
    eval_every=2_000,                   # Avalua convergència cada 2k steps
    eval_episodes=5,                    # Episodis per avaluar sharpe
    
    # Convergència per performance
    target_sharpe=0.8,                  # Si sharpe >= 0.8 → convergit
    min_sharpe_improvement=0.3,         # Millora mínima des d'inici
    plateau_threshold=0.05,             # Millora <5% → plateau
    plateau_patience=3,                 # 3 evals sense millora → convergit
    
    # Convergència per gradients
    min_grad_norm=0.01,                 # Gradient massa petit → convergit
    max_grad_norm=10.0,                 # Gradient massa gran → divergència
    
    # Convergència per paràmetres
    max_param_distance=15.0,            # ||φ - θ|| massa gran → overfitting
)

# ── Outer Update Trigger ─────────────────────────────────────────────────────
outer_trigger = OuterUpdateTrigger(
    batch_size=5,                       # 5 tasques convergides → outer update
    max_time_seconds=450.0,             # O cada 5 min → outer update
    min_tasks=3,                        # Mínim 3 tasques per update vàlid
)

# ── Meta Convergence (ADAPTATIU segons _new vs _adj) ─────────────────────────
if USE_PRETRAINED:
    # MODE _adj: Model pre-entrenat busca meta-optimalitat
    # → NO target de performance (pot degradar temporalment)
    # → Només plateau detection amb més paciència
    meta_criteria = MetaConvergenceCriteria(
        max_meta_iters=500,
        eval_every=5,
        eval_episodes=25,
        
        target_val_sharpe=None,         # ← NO target absolut (accepta degradació)
        plateau_threshold=0.05,         # ← Més sensible a plateau (5%)
        plateau_patience=30,            # ← Més paciència (30 evals)
        min_val_sharpe=-999.0,          # ← No penalitza degradació
    )
    print('Meta criteria MODE: _adj (sense targets de performance)')
else:
    # MODE _new: Fresh init busca performance alta
    # → Target de performance absolut
    # → Menys paciència, vol arribar a sharpe alt
    meta_criteria = MetaConvergenceCriteria(
        max_meta_iters=500,
        eval_every=5,
        eval_episodes=25,
        
        target_val_sharpe=30.21,         # ← Target absolut (0.75 x Sharpe entrenament estàndard)
        plateau_threshold=0.1,          # ← Menys sensible (10%)
        plateau_patience=20,            # ← Menys paciència (20 evals)
        min_val_sharpe=0.5,             # ← Mínim acceptable (0.5)
    )
    print('Meta criteria MODE: _new (amb targets de performance)')

# ── Reptile Hyperparameters ──────────────────────────────────────────────────
REPTILE_EPS = 0.1                       # Outer update step size (conservador)
TASK_WEEKS = 12                         # Durada de cada tasca (12 setmanes)
TASK_STEPS = TASK_WEEKS * STEPS_PER_WEEK

# ── Adaptation (rolling-window test) ─────────────────────────────────────────
SUPPORT_WEEKS = 6
ADAPT_STEPS = 15_000
N_EVAL_WEEKS = 1

print('\nCriteris de convergència definits:')
print(f'  Inner: {inner_criteria.min_steps:,}-{inner_criteria.max_steps:,} steps, '
      f'target_sharpe={inner_criteria.target_sharpe}')
print(f'  Outer: batch={outer_trigger.batch_size}, timeout={outer_trigger.max_time_seconds}s')
print(f'  Meta:  max_iters={meta_criteria.max_meta_iters}, '
      f'target_val_sharpe={meta_criteria.target_val_sharpe}, '
      f'plateau_patience={meta_criteria.plateau_patience}')
print(f'  Reptile: eps={REPTILE_EPS}, task_weeks={TASK_WEEKS} ({TASK_STEPS:,} files)')
# Out:
# Meta criteria MODE: _new (amb targets de performance)
#
# Criteris de convergència definits:
#   Inner: 5,000-30,000 steps, target_sharpe=0.8
#   Outer: batch=5, timeout=450.0s
#   Meta:  max_iters=500, target_val_sharpe=30.21, plateau_patience=20
#   Reptile: eps=0.1, task_weeks=12 (2,016 files)

# %%
# =============================================================================
# CEL·LA 4 — CÀRREGA DE DADES
# =============================================================================

dm = DataManager(interval=TIMEFRAME, project_root=Path('.'))
FEATURE_COLS = dm.features
N_FEATURES   = len(FEATURE_COLS)

df_train, df_val, df_test = dm.load_all()
df_meta = pl.concat([df_train, df_val])

print(f'Train: {len(df_train):>8,}  ({df_train["timestamp"].min()} → {df_train["timestamp"].max()})')
print(f'Val:   {len(df_val):>8,}  ({df_val["timestamp"].min()} → {df_val["timestamp"].max()})')
print(f'Test:  {len(df_test):>8,}  ({df_test["timestamp"].min()} → {df_test["timestamp"].max()})')
print(f'Meta:  {len(df_meta):>8,}')
print(f'\nTasks possibles (TASK_WEEKS={TASK_WEEKS}): '
      f'{max(0, len(df_meta) - TASK_STEPS):,} finestres')
# Out:
# Train:   43,763  (2018-01-01 00:00:00 → 2022-12-31 23:00:00)
# Val:      8,759  (2023-01-01 00:00:00 → 2023-12-31 23:00:00)
# Test:    17,500  (2024-01-01 00:00:00 → 2025-12-31 00:00:00)
# Meta:    52,522
#
# Tasks possibles (TASK_WEEKS=12): 50,506 finestres

# %%
# =============================================================================
# CEL·LA 5 — FACTORIA D'ENTORN + VERIFICACIÓ
# =============================================================================

def make_env(df: pl.DataFrame, **kwargs) -> CryptoMarketEnv:
    '''Factoria per crear l'entorn DENSE amb FEATURE_COLS.'''
    return CryptoMarketEnv(
        df=df,
        feature_cols=FEATURE_COLS,
        w_pnl=W_PNL,
        steps_per_4h=steps_per_4h_for(TIMEFRAME),
        realize_bonus_scale=REALIZE_BONUS_SCALE,
        **kwargs,
    )

_env = make_env(df_train)
_obs, _info = _env.reset(seed=SEED)
OBS_DIM   = _env.observation_space.shape[0]
N_ACTIONS = _env.action_space.n
del _env

print(f'make_env OK | OBS_DIM={OBS_DIM}  N_ACTIONS={N_ACTIONS}')
# Out:
# make_env OK | OBS_DIM=71  N_ACTIONS=4

# %%
# =============================================================================
# CEL·LA 6 — CARREGA PPO CONFIG + AGENT BASE (fresh init O pre-entrenat)
# =============================================================================

# ── Hiperparàmetres PPO (defaults) ───────────────────────────────────────────
DEFAULT_PPO_CFG = {
    'learning_rate': 3e-4,
    'n_steps': 2048,
    'batch_size': 256,
    'n_epochs': 5,
    'gamma': 0.99,
    'gae_lambda': 0.95,
    'clip_range': 0.20,
    'ent_coef': 0.01,
    'vf_coef': 0.5,
    'max_grad_norm': 0.5,
    'net_arch': [128, 64],
}

# ── Carrega best params si existeix ──────────────────────────────────────────
if BEST_PARAMS_PATH.exists():
    print(f'Carregant best params des de {BEST_PARAMS_PATH} ...')
    with open(BEST_PARAMS_PATH, encoding='utf-8') as f:
        _bp_data = json.load(f)
    _bp = _bp_data['best_params']
    
    ppo_config = {
        'learning_rate': float(_bp.get('learning_rate', DEFAULT_PPO_CFG['learning_rate'])),
        'n_steps': int(_bp.get('n_steps', DEFAULT_PPO_CFG['n_steps'])),
        'batch_size': int(_bp.get('batch_size', DEFAULT_PPO_CFG['batch_size'])),
        'n_epochs': int(_bp.get('n_epochs', DEFAULT_PPO_CFG['n_epochs'])),
        'gamma': float(_bp.get('gamma', DEFAULT_PPO_CFG['gamma'])),
        'gae_lambda': float(_bp.get('gae_lambda', DEFAULT_PPO_CFG['gae_lambda'])),
        'clip_range': float(_bp.get('clip_range', DEFAULT_PPO_CFG['clip_range'])),
        'ent_coef': float(_bp.get('ent_coef', DEFAULT_PPO_CFG['ent_coef'])),
        'vf_coef': float(_bp.get('vf_coef', DEFAULT_PPO_CFG['vf_coef'])),
        'max_grad_norm': float(DEFAULT_PPO_CFG['max_grad_norm']),
        'net_arch': DEFAULT_PPO_CFG['net_arch'],
    }
    print(f'  Best params carregats: lr={ppo_config["learning_rate"]:.2e}  '
          f'n_steps={ppo_config["n_steps"]}  batch={ppo_config["batch_size"]}  '
          f'epochs={ppo_config["n_epochs"]}')
    print(f'  trial={_bp_data["best_trial"]}  sharpe={_bp_data["final_sharpe"]:.2f}  '
          f'ret={_bp_data["final_return"]:.2f}%')
else:
    print(f'AVÍS: {BEST_PARAMS_PATH} no trobat → usar DEFAULT_PPO_CFG')
    ppo_config = DEFAULT_PPO_CFG

# ── Crea/Carrega agent base ──────────────────────────────────────────────────
PRETRAINED_CKPT = Path(AVAILABLE_AGENTS[BASE_AGENT]) if USE_PRETRAINED else None

if USE_PRETRAINED and PRETRAINED_CKPT and PRETRAINED_CKPT.exists():
    print(f'\nCarregant PRE-ENTRENAT: {PRETRAINED_CKPT}')
    base_policy = ActorCriticPolicy.load(str(PRETRAINED_CKPT), device=DEVICE)
    base_policy.train()
    n_params = base_policy.count_params()
    print(f'  Checkpoint carregat: {n_params:,} params')
else:
    if USE_PRETRAINED:
        print(f'\nAVÍS: Checkpoint {PRETRAINED_CKPT} no trobat → fresh init')
    else:
        print(f'\nCreant agent base (fresh init) ...')
    
    torch.manual_seed(SEED)
    base_policy = ActorCriticPolicy(
        OBS_DIM, N_ACTIONS, ppo_config['net_arch']
    ).to(DEVICE)
    base_policy.train()
    n_params = base_policy.count_params()
    print(f'  Base policy: {n_params:,} params')

print(f'PPO config: {ppo_config}')
# Out:
# Carregant best params des de checkpoints_dense\ppo_best_params.json ...
#   Best params carregats: lr=2.77e-04  n_steps=4096  batch=64  epochs=7
#   trial=TPE_trial009  sharpe=43.01  ret=256.58%
#
# Creant agent base (fresh init) ...
#   Base policy: 35,269 params
# PPO config: {'learning_rate': 0.0002772159821008165, 'n_steps': 4096, 'batch_size': 64, 'n_epochs': 7, 'gamma': 0.9967078871822386, 'gae_lambda': 0.9014929046035071, 'clip_range': 0.2024186116598562, 'ent_coef': 0.009854799703235616, 'vf_coef': 0.7338795928070874, 'max_grad_norm': 0.5, 'net_arch': [128, 64]}

# %%
# =============================================================================
# CEL·LA 7 — TASK SAMPLER
# =============================================================================

rng_meta = np.random.default_rng(SEED)

def sample_task() -> pl.DataFrame:
    '''Mostra una finestra aleatòria de TASK_STEPS files de df_meta.'''
    max_start = len(df_meta) - TASK_STEPS
    if max_start <= 0:
        return df_meta
    start = int(rng_meta.integers(0, max_start))
    return df_meta[start: start + TASK_STEPS]

# Test
_task = sample_task()
print(f'sample_task OK  → {len(_task)} files  (TASK_STEPS={TASK_STEPS})')
print(f'Tasks possibles: {max(0, len(df_meta) - TASK_STEPS):,}')
# Out:
# sample_task OK  → 2016 files  (TASK_STEPS=2016)
# Tasks possibles: 50,506

# %%
# =============================================================================
# CEL·LA 8 — CREA SISTEMA REPTILE ADAPTATIU
# =============================================================================

reptile = AdaptiveReptile(
    inner_criteria=inner_criteria,
    outer_trigger=outer_trigger,
    meta_criteria=meta_criteria,
    device=DEVICE,
    ppo_config=ppo_config,
    reptile_eps=REPTILE_EPS,
    tensorboard_log=str(RESULTS / 'tensorboard'),  # ← TensorBoard logging
)

print('AdaptiveReptile system creat.')
print(f'  Inner: {inner_criteria.min_steps:,}-{inner_criteria.max_steps:,} steps')
print(f'  Outer: batch={outer_trigger.batch_size}')
print(f'  Meta:  max_iters={meta_criteria.max_meta_iters}')
print(f'  TensorBoard: {RESULTS / "tensorboard"}')
# Out:
# AdaptiveReptile system creat.
#   Inner: 5,000-30,000 steps
#   Outer: batch=5
#   Meta:  max_iters=500
#   TensorBoard: results_dense\06d_ppo_reptile_adaptive_new\tensorboard

# %%
# =============================================================================
# CEL·LA 9 — RUN ADAPTIVE META-TRAINING
# =============================================================================

import time as _time

if META_CKPT.exists():
    print(f'Carregant meta-checkpoint des de {META_CKPT} ...')
    meta_policy = ActorCriticPolicy.load(META_CKPT, device=DEVICE)
    meta_policy.train()
    _d = torch.load(str(META_CKPT), map_location=DEVICE, weights_only=False)
    meta_history = _d.get('meta_history', [])
    inner_diagnostics = _d.get('inner_diagnostics', [])
    emissions_meta = _d.get('emissions_meta_g_co2', 0.0)
    train_time_s = _d.get('train_time_s', 0.0)
    total_tasks = _d.get('total_tasks_processed', 0)
    total_meta_iters = _d.get('total_meta_iters', 0)
    best_val_sharpe = _d.get('best_val_sharpe', -np.inf)
    print(f'  Meta-checkpoint carregat.')
    print(f'  Meta iters: {total_meta_iters}  Tasks: {total_tasks}  '
          f'Best val sharpe: {best_val_sharpe:+.4f}')
else:
    print(f'Iniciant Reptile ADAPTATIU meta-entrenament ...')
    print(f'Sistema pararà automàticament quan convergeixin inner loops i meta-agent.\n')
    
    t0 = _time.time()
    tracker = EmissionsTracker(
        project_name='06d_ppo_reptile_adaptive',
        output_dir=str(CODECARBON_DIR),
        log_level='error'
    )
    tracker.start()
    
    result = reptile.meta_train(
        base_policy=copy.deepcopy(base_policy),
        task_sampler=sample_task,
        env_factory=make_env,
        val_df=df_val,
        verbose=True,
        checkpoint_path=META_CKPT,
        checkpoint_every=50,
    )
    
    emissions_meta = (tracker.stop() or 0.0) * 1000  # grams CO2
    train_time_s = _time.time() - t0
    
    meta_policy = result['meta_policy']
    meta_history = result['meta_history']
    inner_diagnostics = result['inner_diagnostics']
    total_tasks = result['total_tasks_processed']
    total_meta_iters = result['total_meta_iters']
    best_val_sharpe = result['best_val_sharpe']
    
    print(f'\n' + '='*60)
    print(f'Meta-entrenament completat: {train_time_s/60:.1f} min')
    print(f'  Total meta-iters: {total_meta_iters}')
    print(f'  Total tasks processades: {total_tasks}')
    print(f'  Best val sharpe: {best_val_sharpe:+.4f}')
    print(f'  Emissions meta: {emissions_meta:.2f} g CO2eq')
    print('='*60)
    
    # Desa checkpoint
    META_CKPT.parent.mkdir(parents=True, exist_ok=True)
    torch.save({
        'policy_state_dict': meta_policy.state_dict(),
        'hyperparams': ppo_config,
        'meta_history': meta_history,
        'inner_diagnostics': inner_diagnostics,
        'emissions_meta_g_co2': emissions_meta,
        'train_time_s': train_time_s,
        'total_tasks_processed': total_tasks,
        'total_meta_iters': total_meta_iters,
        'best_val_sharpe': best_val_sharpe,
        'inner_criteria': inner_criteria.__dict__,
        'outer_trigger': outer_trigger.__dict__,
        'meta_criteria': meta_criteria.__dict__,
        'reptile_eps': REPTILE_EPS,
    }, META_CKPT)
    print(f'\nMeta-checkpoint desat: {META_CKPT}')

if meta_history:
    best = max(meta_history, key=lambda h: h['val_sharpe'])
    print(f'\nMillor val: Sharpe={best["val_sharpe"]:+.4f}  '
          f'Ret={best["val_return"]:+.2f}%  iter {best["meta_iter"]}')
# Out:
# [codecarbon WARNING @ 18:30:35] Multiple instances of codecarbon are allowed to run at the same time.
# Iniciant Reptile ADAPTATIU meta-entrenament ...
# Sistema pararà automàticament quan convergeixin inner loops i meta-agent.
#
#   Task 1: SKIP (gradient_explosion)
#   Task 2: SKIP (gradient_explosion)
#   Task 3: target_sharpe_reached (8,192 steps, sharpe=+32298698.55)
#   Task 4: SKIP (gradient_explosion)
#   Task 5: SKIP (gradient_explosion)
#   Task 6: SKIP (gradient_explosion)
#   Task 7: SKIP (gradient_explosion)
#   Task 8: SKIP (gradient_explosion)
#   Task 9: SKIP (gradient_explosion)
#   Task 10: SKIP (gradient_explosion)
#   Task 11: SKIP (gradient_explosion)
#   Task 12: SKIP (gradient_explosion)
#   Task 13: SKIP (gradient_explosion)
#   Task 14: SKIP (gradient_explosion)
#   Task 15: SKIP (gradient_explosion)
#   Task 16: target_sharpe_reached (8,192 steps, sharpe=+3825962242.67)
#   Task 17: target_sharpe_reached (8,192 steps, sharpe=+3566949937.79)
#   Batch timeout: 3 tasks in 608.7s
#
# Meta-iter 1: Outer update amb 3 tasques
#   Task 18: SKIP (gradient_explosion)
#   Task 19: SKIP (gradient_explosion)
#   Task 20: SKIP (gradient_explosion)
#   Task 21: SKIP (gradient_explosion)
#   Task 22: target_sharpe_reached (8,192 steps, sharpe=+2924734222.86)
#   Task 23: SKIP (gradient_explosion)
#   Task 24: SKIP (gradient_explosion)
#   Task 25: SKIP (gradient_explosion)
#   Task 26: target_sharpe_reached (8,192 steps, sharpe=+267039206.81)
#   Task 27: target_sharpe_reached (8,192 steps, sharpe=+846363193.17)
#   Task 28: SKIP (gradient_explosion)
#   Task 29: SKIP (gradient_explosion)
#   Task 30: SKIP (gradient_explosion)
#   Task 31: SKIP (gradient_explosion)
#   Task 32: target_sharpe_reached (8,192 steps, sharpe=+362004436.82)
#   Batch timeout: 4 tasks in 456.6s
#
# Meta-iter 2: Outer update amb 4 tasques
#   Task 33: SKIP (gradient_explosion)
#   Task 34: SKIP (gradient_explosion)
#   Task 35: target_sharpe_reached (8,192 steps, sharpe=+155790669.11)
#   Task 36: SKIP (gradient_explosion)
#   Task 37: SKIP (gradient_explosion)
#   Task 38: target_sharpe_reached (8,192 steps, sharpe=+1553651687.44)
#   Task 39: SKIP (gradient_explosion)
#   Task 40: target_sharpe_reached (8,192 steps, sharpe=+267329708.45)
#   Task 41: SKIP (gradient_explosion)
#   Task 42: SKIP (gradient_explosion)
#   Task 43: SKIP (gradient_explosion)
#   Task 44: SKIP (gradient_explosion)
#   Task 45: SKIP (gradient_explosion)
#   Task 46: SKIP (gradient_explosion)
#   Task 47: SKIP (gradient_explosion)
#   Task 48: target_sharpe_reached (8,192 steps, sharpe=+3090690408.77)
#   Task 49: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 472.7s
#
# Meta-iter 3: Outer update amb 4 tasques
#   Task 50: target_sharpe_reached (8,192 steps, sharpe=+1246686937.71)
#   Task 51: target_sharpe_reached (8,192 steps, sharpe=+7599803224.47)
#   Task 52: target_sharpe_reached (8,192 steps, sharpe=+2343029481.43)
#   Task 53: target_sharpe_reached (8,192 steps, sharpe=+6744777502.11)
#   Task 54: target_sharpe_reached (8,192 steps, sharpe=+9239996705.89)
#
# Meta-iter 4: Outer update amb 5 tasques
#   Task 55: SKIP (gradient_explosion)
#   Task 56: SKIP (gradient_explosion)
#   Task 57: SKIP (gradient_explosion)
#   Task 58: target_sharpe_reached (8,192 steps, sharpe=+4240708087.42)
#   Task 59: SKIP (gradient_explosion)
#   Task 60: SKIP (gradient_explosion)
#   Task 61: target_sharpe_reached (8,192 steps, sharpe=+4858742723.14)
#   Task 62: SKIP (gradient_explosion)
#   Task 63: SKIP (gradient_explosion)
#   Task 64: SKIP (gradient_explosion)
#   Task 65: SKIP (gradient_explosion)
#   Task 66: SKIP (gradient_explosion)
#   Task 67: target_sharpe_reached (8,192 steps, sharpe=+2376340876.43)
#   Task 68: SKIP (gradient_explosion)
#   Task 69: SKIP (gradient_explosion)
#   Task 70: SKIP (gradient_explosion)
#   Task 71: target_sharpe_reached (8,192 steps, sharpe=+3657693194.69)
#   Batch timeout: 4 tasks in 477.7s
#
# Meta-iter 5: Outer update amb 4 tasques
#   Val: sharpe=+0.3060 ret=+0.47% best=+0.3060 [✓ NEW BEST]
#
#   Task 72: target_sharpe_reached (8,192 steps, sharpe=+4131832769.55)
#   Task 73: target_sharpe_reached (8,192 steps, sharpe=+3850609586.05)
#   Task 74: SKIP (gradient_explosion)
#   Task 75: target_sharpe_reached (8,192 steps, sharpe=+10079906859.91)
#   Task 76: SKIP (gradient_explosion)
#   Task 77: target_sharpe_reached (8,192 steps, sharpe=+9850135550.02)
#   Task 78: target_sharpe_reached (8,192 steps, sharpe=+3512831959.72)
#
# Meta-iter 6: Outer update amb 5 tasques
#   Task 79: SKIP (gradient_explosion)
#   Task 80: SKIP (gradient_explosion)
#   Task 81: SKIP (gradient_explosion)
#   Task 82: SKIP (gradient_explosion)
#   Task 83: SKIP (gradient_explosion)
#   Task 84: SKIP (gradient_explosion)
#   Task 85: SKIP (gradient_explosion)
#   Task 86: target_sharpe_reached (8,192 steps, sharpe=+1717543367.38)
#   Task 87: SKIP (gradient_explosion)
#   Task 88: target_sharpe_reached (8,192 steps, sharpe=+2680439978.89)
#   Task 89: target_sharpe_reached (8,192 steps, sharpe=+150315919.90)
#   Task 90: SKIP (gradient_explosion)
#   Task 91: SKIP (gradient_explosion)
#   Task 92: SKIP (gradient_explosion)
#   Task 93: target_sharpe_reached (8,192 steps, sharpe=+3074813761.04)
#   Batch timeout: 4 tasks in 453.4s
#
# Meta-iter 7: Outer update amb 4 tasques
#   Task 94: target_sharpe_reached (8,192 steps, sharpe=+647201348.93)
#   Task 95: SKIP (gradient_explosion)
#   Task 96: target_sharpe_reached (8,192 steps, sharpe=+3060879945.99)
#   Task 97: SKIP (gradient_explosion)
#   Task 98: SKIP (gradient_explosion)
#   Task 99: SKIP (gradient_explosion)
#   Task 100: SKIP (gradient_explosion)
#   Task 101: SKIP (gradient_explosion)
#   Task 102: SKIP (gradient_explosion)
#   Task 103: target_sharpe_reached (8,192 steps, sharpe=+1917254813.85)
#   Task 104: target_sharpe_reached (8,192 steps, sharpe=+562811635.56)
#   Task 105: target_sharpe_reached (8,192 steps, sharpe=+877829382.90)
#
# Meta-iter 8: Outer update amb 5 tasques
#   Task 106: target_sharpe_reached (8,192 steps, sharpe=+1651711480.95)
#   Task 107: SKIP (gradient_explosion)
#   Task 108: target_sharpe_reached (8,192 steps, sharpe=+2827425004.02)
#   Task 109: SKIP (gradient_explosion)
#   Task 110: target_sharpe_reached (8,192 steps, sharpe=+1838470876.62)
#   Task 111: SKIP (gradient_explosion)
#   Task 112: SKIP (gradient_explosion)
#   Task 113: target_sharpe_reached (8,192 steps, sharpe=+4301309362.38)
#   Task 114: SKIP (gradient_explosion)
#   Task 115: target_sharpe_reached (8,192 steps, sharpe=+4238460693.25)
#
# Meta-iter 9: Outer update amb 5 tasques
#   Task 116: SKIP (gradient_explosion)
#   Task 117: SKIP (gradient_explosion)
#   Task 118: SKIP (gradient_explosion)
#   Task 119: target_sharpe_reached (8,192 steps, sharpe=+3426909462.92)
#   Task 120: target_sharpe_reached (8,192 steps, sharpe=+285753778.36)
#   Task 121: target_sharpe_reached (8,192 steps, sharpe=+3736342308.35)
#   Task 122: SKIP (gradient_explosion)
#   Task 123: SKIP (gradient_explosion)
#   Task 124: SKIP (gradient_explosion)
#   Task 125: SKIP (gradient_explosion)
#   Task 126: SKIP (gradient_explosion)
#   Task 127: target_sharpe_reached (8,192 steps, sharpe=+2421205854.31)
#   Task 128: SKIP (gradient_explosion)
#   Task 129: SKIP (gradient_explosion)
#   Task 130: target_sharpe_reached (8,192 steps, sharpe=+3359923259.45)
#
# Meta-iter 10: Outer update amb 5 tasques
#   Val: sharpe=+0.0000 ret=+0.00% best=+0.3060 [plateau 1/20]
#
#   Task 131: SKIP (gradient_explosion)
#   Task 132: SKIP (gradient_explosion)
#   Task 133: SKIP (gradient_explosion)
#   Task 134: SKIP (gradient_explosion)
#   Task 135: SKIP (gradient_explosion)
#   Task 136: SKIP (gradient_explosion)
#   Task 137: SKIP (gradient_explosion)
#   Task 138: SKIP (gradient_explosion)
#   Task 139: target_sharpe_reached (8,192 steps, sharpe=+101248613.77)
#   Task 140: target_sharpe_reached (8,192 steps, sharpe=+3043367797.67)
#   Task 141: target_sharpe_reached (8,192 steps, sharpe=+14232907699.25)
#   Task 142: target_sharpe_reached (8,192 steps, sharpe=+1939524183.61)
#   Task 143: SKIP (gradient_explosion)
#   Task 144: target_sharpe_reached (8,192 steps, sharpe=+4299081655.33)
#
# Meta-iter 11: Outer update amb 5 tasques
#   Task 145: SKIP (gradient_explosion)
#   Task 146: SKIP (gradient_explosion)
#   Task 147: target_sharpe_reached (8,192 steps, sharpe=+5275791866.35)
#   Task 148: target_sharpe_reached (8,192 steps, sharpe=+895910059.90)
#   Task 149: target_sharpe_reached (8,192 steps, sharpe=+1057868854.13)
#   Task 150: SKIP (gradient_explosion)
#   Task 151: SKIP (gradient_explosion)
#   Task 152: SKIP (gradient_explosion)
#   Task 153: SKIP (gradient_explosion)
#   Task 154: target_sharpe_reached (8,192 steps, sharpe=+102824442.11)
#   Task 155: SKIP (gradient_explosion)
#   Task 156: target_sharpe_reached (8,192 steps, sharpe=+4005759638.86)
#
# Meta-iter 12: Outer update amb 5 tasques
#   Task 157: SKIP (gradient_explosion)
#   Task 158: SKIP (gradient_explosion)
#   Task 159: SKIP (gradient_explosion)
#   Task 160: SKIP (gradient_explosion)
#   Task 161: SKIP (gradient_explosion)
#   Task 162: target_sharpe_reached (8,192 steps, sharpe=+1043982733.47)
#   Task 163: SKIP (gradient_explosion)
#   Task 164: target_sharpe_reached (8,192 steps, sharpe=+805674944.51)
#   Task 165: SKIP (gradient_explosion)
#   Task 166: SKIP (gradient_explosion)
#   Task 167: SKIP (gradient_explosion)
#   Task 168: SKIP (gradient_explosion)
#   Task 169: target_sharpe_reached (8,192 steps, sharpe=+886883954.81)
#   Task 170: SKIP (gradient_explosion)
#   Task 171: SKIP (gradient_explosion)
#   Task 172: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 452.7s
#
# Meta-iter 13: Outer update amb 3 tasques
#   Task 173: SKIP (gradient_explosion)
#   Task 174: SKIP (gradient_explosion)
#   Task 175: target_sharpe_reached (8,192 steps, sharpe=+6124848174.89)
#   Task 176: SKIP (gradient_explosion)
#   Task 177: SKIP (gradient_explosion)
#   Task 178: SKIP (gradient_explosion)
#   Task 179: SKIP (gradient_explosion)
#   Task 180: target_sharpe_reached (8,192 steps, sharpe=+587795248.09)
#   Task 181: target_sharpe_reached (8,192 steps, sharpe=+2456306995.69)
#   Task 182: target_sharpe_reached (8,192 steps, sharpe=+9498833855.49)
#   Task 183: SKIP (gradient_explosion)
#   Task 184: target_sharpe_reached (8,192 steps, sharpe=+10042361230.40)
#
# Meta-iter 14: Outer update amb 5 tasques
#   Task 185: SKIP (gradient_explosion)
#   Task 186: SKIP (gradient_explosion)
#   Task 187: SKIP (gradient_explosion)
#   Task 188: SKIP (gradient_explosion)
#   Task 189: SKIP (gradient_explosion)
#   Task 190: target_sharpe_reached (8,192 steps, sharpe=+1516493577.54)
#   Task 191: SKIP (gradient_explosion)
#   Task 192: target_sharpe_reached (8,192 steps, sharpe=+1091264783.22)
#   Task 193: SKIP (gradient_explosion)
#   Task 194: SKIP (gradient_explosion)
#   Task 195: target_sharpe_reached (8,192 steps, sharpe=+1860348.91)
#   Task 196: SKIP (gradient_explosion)
#   Task 197: target_sharpe_reached (8,192 steps, sharpe=+3087849566.19)
#   Task 198: SKIP (gradient_explosion)
#   Task 199: target_sharpe_reached (8,192 steps, sharpe=+520057985.99)
#
# Meta-iter 15: Outer update amb 5 tasques
#   Val: sharpe=+0.0000 ret=+0.00% best=+0.3060 [plateau 2/20]
#
#   Task 200: SKIP (gradient_explosion)
#   Task 201: SKIP (gradient_explosion)
#   Task 202: SKIP (gradient_explosion)
#   Task 203: SKIP (gradient_explosion)
#   Task 204: target_sharpe_reached (8,192 steps, sharpe=+2624524120.00)
#   Task 205: SKIP (gradient_explosion)
#   Task 206: target_sharpe_reached (8,192 steps, sharpe=+2719350983.13)
#   Task 207: SKIP (gradient_explosion)
#   Task 208: SKIP (gradient_explosion)
#   Task 209: SKIP (gradient_explosion)
#   Task 210: SKIP (gradient_explosion)
#   Task 211: SKIP (gradient_explosion)
#   Task 212: SKIP (gradient_explosion)
#   Task 213: SKIP (gradient_explosion)
#   Task 214: SKIP (gradient_explosion)
#   Task 215: SKIP (gradient_explosion)
#   Task 216: SKIP (gradient_explosion)
#   Task 217: target_sharpe_reached (8,192 steps, sharpe=+1877004106.26)
#   Batch timeout: 3 tasks in 514.0s
#
# Meta-iter 16: Outer update amb 3 tasques
#   Task 218: SKIP (gradient_explosion)
#   Task 219: SKIP (gradient_explosion)
#   Task 220: SKIP (gradient_explosion)
#   Task 221: SKIP (gradient_explosion)
#   Task 222: SKIP (gradient_explosion)
#   Task 223: SKIP (gradient_explosion)
#   Task 224: SKIP (gradient_explosion)
#   Task 225: SKIP (gradient_explosion)
#   Task 226: target_sharpe_reached (8,192 steps, sharpe=+1080845286.21)
#   Task 227: target_sharpe_reached (8,192 steps, sharpe=+2556314081.12)
#   Task 228: target_sharpe_reached (8,192 steps, sharpe=+165088356.78)
#   Task 229: SKIP (gradient_explosion)
#   Task 230: SKIP (gradient_explosion)
#   Task 231: SKIP (gradient_explosion)
#   Task 232: SKIP (gradient_explosion)
#   Task 233: target_sharpe_reached (8,192 steps, sharpe=+1346508880.57)
#   Batch timeout: 4 tasks in 478.5s
#
# Meta-iter 17: Outer update amb 4 tasques
#   Task 234: target_sharpe_reached (8,192 steps, sharpe=+10442564029.00)
#   Task 235: SKIP (gradient_explosion)
#   Task 236: SKIP (gradient_explosion)
#   Task 237: SKIP (gradient_explosion)
#   Task 238: SKIP (gradient_explosion)
#   Task 239: SKIP (gradient_explosion)
#   Task 240: target_sharpe_reached (8,192 steps, sharpe=+4004708272.79)
#   Task 241: target_sharpe_reached (8,192 steps, sharpe=+667449722.28)
#   Task 242: target_sharpe_reached (8,192 steps, sharpe=+1060183675.41)
#   Task 243: target_sharpe_reached (8,192 steps, sharpe=+854878358.18)
#
# Meta-iter 18: Outer update amb 5 tasques
#   Task 244: SKIP (gradient_explosion)
#   Task 245: SKIP (gradient_explosion)
#   Task 246: target_sharpe_reached (8,192 steps, sharpe=+1335503346.80)
#   Task 247: SKIP (gradient_explosion)
#   Task 248: SKIP (gradient_explosion)
#   Task 249: SKIP (gradient_explosion)
#   Task 250: SKIP (gradient_explosion)
#   Task 251: SKIP (gradient_explosion)
#   Task 252: SKIP (gradient_explosion)
#   Task 253: SKIP (gradient_explosion)
#   Task 254: target_sharpe_reached (8,192 steps, sharpe=+2557866909.00)
#   Task 255: target_sharpe_reached (8,192 steps, sharpe=+3990809121.04)
#   Task 256: target_sharpe_reached (8,192 steps, sharpe=+2975074452.12)
#   Task 257: SKIP (gradient_explosion)
#   Task 258: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 456.9s
#
# Meta-iter 19: Outer update amb 4 tasques
#   Task 259: SKIP (gradient_explosion)
#   Task 260: target_sharpe_reached (8,192 steps, sharpe=+1398895239.24)
#   Task 261: SKIP (gradient_explosion)
#   Task 262: SKIP (gradient_explosion)
#   Task 263: SKIP (gradient_explosion)
#   Task 264: SKIP (gradient_explosion)
#   Task 265: target_sharpe_reached (8,192 steps, sharpe=+2893245788.02)
#   Task 266: SKIP (gradient_explosion)
#   Task 267: target_sharpe_reached (8,192 steps, sharpe=+806927651.34)
#   Task 268: target_sharpe_reached (8,192 steps, sharpe=+2560912832.65)
#   Task 269: SKIP (gradient_explosion)
#   Task 270: SKIP (gradient_explosion)
#   Task 271: target_sharpe_reached (8,192 steps, sharpe=+586465751.63)
#
# Meta-iter 20: Outer update amb 5 tasques
#   Val: sharpe=+0.0000 ret=+0.00% best=+0.3060 [plateau 3/20]
#
#   Task 272: target_sharpe_reached (8,192 steps, sharpe=+3020475754.15)
#   Task 273: target_sharpe_reached (8,192 steps, sharpe=+724376306.77)
#   Task 274: SKIP (gradient_explosion)
#   Task 275: target_sharpe_reached (8,192 steps, sharpe=+18560004281.50)
#   Task 276: SKIP (gradient_explosion)
#   Task 277: SKIP (gradient_explosion)
#   Task 278: target_sharpe_reached (8,192 steps, sharpe=+139895379.60)
#   Task 279: SKIP (gradient_explosion)
#   Task 280: SKIP (gradient_explosion)
#   Task 281: SKIP (gradient_explosion)
#   Task 282: target_sharpe_reached (8,192 steps, sharpe=+2655491637.37)
#
# Meta-iter 21: Outer update amb 5 tasques
#   Task 283: SKIP (gradient_explosion)
#   Task 284: target_sharpe_reached (8,192 steps, sharpe=+187927304.75)
#   Task 285: SKIP (gradient_explosion)
#   Task 286: SKIP (gradient_explosion)
#   Task 287: SKIP (gradient_explosion)
#   Task 288: SKIP (gradient_explosion)
#   Task 289: SKIP (gradient_explosion)
#   Task 290: target_sharpe_reached (8,192 steps, sharpe=+1465060508.58)
#   Task 291: SKIP (gradient_explosion)
#   Task 292: SKIP (gradient_explosion)
#   Task 293: SKIP (gradient_explosion)
#   Task 294: SKIP (gradient_explosion)
#   Task 295: target_sharpe_reached (8,192 steps, sharpe=+13099384.45)
#   Task 296: SKIP (gradient_explosion)
#   Task 297: SKIP (gradient_explosion)
#   Task 298: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 458.2s
#
# Meta-iter 22: Outer update amb 3 tasques
#   Task 299: target_sharpe_reached (8,192 steps, sharpe=+1123831946.67)
#   Task 300: SKIP (gradient_explosion)
#   Task 301: target_sharpe_reached (8,192 steps, sharpe=+1012505397.62)
#   Task 302: target_sharpe_reached (8,192 steps, sharpe=+1605822259.12)
#   Task 303: target_sharpe_reached (8,192 steps, sharpe=+454051437.73)
#   Task 304: SKIP (gradient_explosion)
#   Task 305: SKIP (gradient_explosion)
#   Task 306: SKIP (gradient_explosion)
#   Task 307: SKIP (gradient_explosion)
#   Task 308: target_sharpe_reached (8,192 steps, sharpe=+140055627.40)
#
# Meta-iter 23: Outer update amb 5 tasques
#   Task 309: SKIP (gradient_explosion)
#   Task 310: target_sharpe_reached (8,192 steps, sharpe=+3821938343.73)
#   Task 311: SKIP (gradient_explosion)
#   Task 312: SKIP (gradient_explosion)
#   Task 313: SKIP (gradient_explosion)
#   Task 314: SKIP (gradient_explosion)
#   Task 315: SKIP (gradient_explosion)
#   Task 316: SKIP (gradient_explosion)
#   Task 317: SKIP (gradient_explosion)
#   Task 318: SKIP (gradient_explosion)
#   Task 319: target_sharpe_reached (8,192 steps, sharpe=+2921694926.27)
#   Task 320: SKIP (gradient_explosion)
#   Task 321: SKIP (gradient_explosion)
#   Task 322: target_sharpe_reached (8,192 steps, sharpe=+2799389941.84)
#   Task 323: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 457.6s
#
# Meta-iter 24: Outer update amb 3 tasques
#   Task 324: SKIP (gradient_explosion)
#   Task 325: target_sharpe_reached (8,192 steps, sharpe=+8851478156.61)
#   Task 326: target_sharpe_reached (8,192 steps, sharpe=+2935675774.53)
#   Task 327: SKIP (gradient_explosion)
#   Task 328: SKIP (gradient_explosion)
#   Task 329: SKIP (gradient_explosion)
#   Task 330: target_sharpe_reached (8,192 steps, sharpe=+87825728.93)
#   Task 331: SKIP (gradient_explosion)
#   Task 332: SKIP (gradient_explosion)
#   Task 333: SKIP (gradient_explosion)
#   Task 334: SKIP (gradient_explosion)
#   Task 335: SKIP (gradient_explosion)
#   Task 336: target_sharpe_reached (8,192 steps, sharpe=+578247389.23)
#   Task 337: target_sharpe_reached (8,192 steps, sharpe=+25631307.69)
#
# Meta-iter 25: Outer update amb 5 tasques
#   Val: sharpe=+0.0000 ret=+0.00% best=+0.3060 [plateau 4/20]
#
#   Task 338: SKIP (gradient_explosion)
#   Task 339: target_sharpe_reached (8,192 steps, sharpe=+794504138.62)
#   Task 340: SKIP (gradient_explosion)
#   Task 341: SKIP (gradient_explosion)
#   Task 342: target_sharpe_reached (8,192 steps, sharpe=+168031329.45)
#   Task 343: target_sharpe_reached (8,192 steps, sharpe=+3685440769.65)
#   Task 344: SKIP (gradient_explosion)
#   Task 345: SKIP (gradient_explosion)
#   Task 346: target_sharpe_reached (8,192 steps, sharpe=+4150172700.83)
#   Task 347: SKIP (gradient_explosion)
#   Task 348: SKIP (gradient_explosion)
#   Task 349: target_sharpe_reached (8,192 steps, sharpe=+504149704.96)
#
# Meta-iter 26: Outer update amb 5 tasques
#   Task 350: target_sharpe_reached (8,192 steps, sharpe=+3794346521.14)
#   Task 351: target_sharpe_reached (8,192 steps, sharpe=+1107092225.31)
#   Task 352: SKIP (gradient_explosion)
#   Task 353: SKIP (gradient_explosion)
#   Task 354: SKIP (gradient_explosion)
#   Task 355: target_sharpe_reached (8,192 steps, sharpe=+3629388072.91)
#   Task 356: target_sharpe_reached (8,192 steps, sharpe=+3115953895.87)
#   Task 357: SKIP (gradient_explosion)
#   Task 358: target_sharpe_reached (8,192 steps, sharpe=+613615694.99)
#
# Meta-iter 27: Outer update amb 5 tasques
#   Task 359: SKIP (gradient_explosion)
#   Task 360: target_sharpe_reached (8,192 steps, sharpe=+1570548835.96)
#   Task 361: SKIP (gradient_explosion)
#   Task 362: SKIP (gradient_explosion)
#   Task 363: SKIP (gradient_explosion)
#   Task 364: SKIP (gradient_explosion)
#   Task 365: SKIP (gradient_explosion)
#   Task 366: target_sharpe_reached (8,192 steps, sharpe=+3434059969.96)
#   Task 367: SKIP (gradient_explosion)
#   Task 368: target_sharpe_reached (8,192 steps, sharpe=+985026285.47)
#   Task 369: SKIP (gradient_explosion)
#   Task 370: target_sharpe_reached (8,192 steps, sharpe=+705005596.88)
#   Task 371: SKIP (gradient_explosion)
#   Task 372: SKIP (gradient_explosion)
#   Task 373: target_sharpe_reached (8,192 steps, sharpe=+1949878325.40)
#
# Meta-iter 28: Outer update amb 5 tasques
#   Task 374: SKIP (gradient_explosion)
#   Task 375: target_sharpe_reached (8,192 steps, sharpe=+1080980449.09)
#   Task 376: target_sharpe_reached (8,192 steps, sharpe=+5073144484.50)
#   Task 377: SKIP (gradient_explosion)
#   Task 378: SKIP (gradient_explosion)
#   Task 379: SKIP (gradient_explosion)
#   Task 380: SKIP (gradient_explosion)
#   Task 381: SKIP (gradient_explosion)
#   Task 382: SKIP (gradient_explosion)
#   Task 383: SKIP (gradient_explosion)
#   Task 384: SKIP (gradient_explosion)
#   Task 385: SKIP (gradient_explosion)
#   Task 386: SKIP (gradient_explosion)
#   Task 387: target_sharpe_reached (8,192 steps, sharpe=+628857407.74)
#   Task 388: SKIP (gradient_explosion)
#   Task 389: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 471.2s
#
# Meta-iter 29: Outer update amb 3 tasques
#   Task 390: target_sharpe_reached (8,192 steps, sharpe=+4210504749.52)
#   Task 391: SKIP (gradient_explosion)
#   Task 392: SKIP (gradient_explosion)
#   Task 393: SKIP (gradient_explosion)
#   Task 394: SKIP (gradient_explosion)
#   Task 395: SKIP (gradient_explosion)
#   Task 396: SKIP (gradient_explosion)
#   Task 397: SKIP (gradient_explosion)
#   Task 398: SKIP (gradient_explosion)
#   Task 399: SKIP (gradient_explosion)
#   Task 400: target_sharpe_reached (8,192 steps, sharpe=+4027237252.84)
#   Task 401: SKIP (gradient_explosion)
#   Task 402: SKIP (gradient_explosion)
#   Task 403: SKIP (gradient_explosion)
#   Task 404: SKIP (gradient_explosion)
#   Task 405: SKIP (gradient_explosion)
#   Task 406: SKIP (gradient_explosion)
#   Task 407: target_sharpe_reached (8,192 steps, sharpe=+3989141547.83)
#   Batch timeout: 3 tasks in 552.2s
#
# Meta-iter 30: Outer update amb 3 tasques
#   Val: sharpe=+0.0000 ret=+0.00% best=+0.3060 [plateau 5/20]
#
#   Task 408: SKIP (gradient_explosion)
#   Task 409: SKIP (gradient_explosion)
#   Task 410: SKIP (gradient_explosion)
#   Task 411: target_sharpe_reached (8,192 steps, sharpe=+9131766993.11)
#   Task 412: SKIP (gradient_explosion)
#   Task 413: SKIP (gradient_explosion)
#   Task 414: SKIP (gradient_explosion)
#   Task 415: target_sharpe_reached (8,192 steps, sharpe=+2979730678.76)
#   Task 416: SKIP (gradient_explosion)
#   Task 417: SKIP (gradient_explosion)
#   Task 418: SKIP (gradient_explosion)
#   Task 419: target_sharpe_reached (8,192 steps, sharpe=+6205186679.97)
#   Task 420: SKIP (gradient_explosion)
#   Task 421: SKIP (gradient_explosion)
#   Task 422: target_sharpe_reached (8,192 steps, sharpe=+2616458040.21)
#   Task 423: target_sharpe_reached (8,192 steps, sharpe=+2865180169.19)
#
# Meta-iter 31: Outer update amb 5 tasques
#   Task 424: SKIP (gradient_explosion)
#   Task 425: target_sharpe_reached (8,192 steps, sharpe=+8756552389.12)
#   Task 426: target_sharpe_reached (8,192 steps, sharpe=+1150167776.17)
#   Task 427: target_sharpe_reached (8,192 steps, sharpe=+1687031545.47)
#   Task 428: SKIP (gradient_explosion)
#   Task 429: SKIP (gradient_explosion)
#   Task 430: SKIP (gradient_explosion)
#   Task 431: target_sharpe_reached (8,192 steps, sharpe=+5231090978.27)
#   Task 432: target_sharpe_reached (8,192 steps, sharpe=+964705130.32)
#
# Meta-iter 32: Outer update amb 5 tasques
#   Task 433: SKIP (gradient_explosion)
#   Task 434: SKIP (gradient_explosion)
#   Task 435: target_sharpe_reached (8,192 steps, sharpe=+4458307474.10)
#   Task 436: SKIP (gradient_explosion)
#   Task 437: SKIP (gradient_explosion)
#   Task 438: SKIP (gradient_explosion)
#   Task 439: target_sharpe_reached (8,192 steps, sharpe=+1346728292.64)
#   Task 440: target_sharpe_reached (8,192 steps, sharpe=+706909730.36)
#   Task 441: SKIP (gradient_explosion)
#   Task 442: SKIP (gradient_explosion)
#   Task 443: target_sharpe_reached (8,192 steps, sharpe=+12811210933.33)
#   Task 444: target_sharpe_reached (8,192 steps, sharpe=+6385768209.71)
#
# Meta-iter 33: Outer update amb 5 tasques
#   Task 445: target_sharpe_reached (8,192 steps, sharpe=+3131255123.12)
#   Task 446: SKIP (gradient_explosion)
#   Task 447: SKIP (gradient_explosion)
#   Task 448: SKIP (gradient_explosion)
#   Task 449: SKIP (gradient_explosion)
#   Task 450: SKIP (gradient_explosion)
#   Task 451: SKIP (gradient_explosion)
#   Task 452: target_sharpe_reached (8,192 steps, sharpe=+7463159370.31)
#   Task 453: SKIP (gradient_explosion)
#   Task 454: SKIP (gradient_explosion)
#   Task 455: SKIP (gradient_explosion)
#   Task 456: SKIP (gradient_explosion)
#   Task 457: SKIP (gradient_explosion)
#   Task 458: SKIP (gradient_explosion)
#   Task 459: SKIP (gradient_explosion)
#   Task 460: SKIP (gradient_explosion)
#   Task 461: SKIP (gradient_explosion)
#   Task 462: SKIP (gradient_explosion)
#   Task 463: target_sharpe_reached (8,192 steps, sharpe=+410536228.88)
#   Batch timeout: 3 tasks in 561.6s
#
# Meta-iter 34: Outer update amb 3 tasques
#   Task 464: SKIP (gradient_explosion)
#   Task 465: SKIP (gradient_explosion)
#   Task 466: SKIP (gradient_explosion)
#   Task 467: SKIP (gradient_explosion)
#   Task 468: SKIP (gradient_explosion)
#   Task 469: SKIP (gradient_explosion)
#   Task 470: target_sharpe_reached (8,192 steps, sharpe=+5173771117.47)
#   Task 471: SKIP (gradient_explosion)
#   Task 472: SKIP (gradient_explosion)
#   Task 473: SKIP (gradient_explosion)
#   Task 474: SKIP (gradient_explosion)
#   Task 475: SKIP (gradient_explosion)
#   Task 476: target_sharpe_reached (8,192 steps, sharpe=+1904454242.57)
#   Task 477: target_sharpe_reached (8,192 steps, sharpe=+995491953.23)
#   Task 478: target_sharpe_reached (8,192 steps, sharpe=+3785192178.79)
#   Batch timeout: 4 tasks in 454.3s
#
# Meta-iter 35: Outer update amb 4 tasques
#   Val: sharpe=+0.0000 ret=+0.00% best=+0.3060 [plateau 6/20]
#
#   Task 479: SKIP (gradient_explosion)
#   Task 480: SKIP (gradient_explosion)
#   Task 481: SKIP (gradient_explosion)
#   Task 482: target_sharpe_reached (8,192 steps, sharpe=+2822618179.96)
#   Task 483: target_sharpe_reached (8,192 steps, sharpe=+492072502.28)
#   Task 484: target_sharpe_reached (8,192 steps, sharpe=+2448672848.77)
#   Task 485: SKIP (gradient_explosion)
#   Task 486: SKIP (gradient_explosion)
#   Task 487: target_sharpe_reached (8,192 steps, sharpe=+3627711779.62)
#   Task 488: target_sharpe_reached (8,192 steps, sharpe=+2366645209.89)
#
# Meta-iter 36: Outer update amb 5 tasques
#   Task 489: target_sharpe_reached (8,192 steps, sharpe=+603598202.33)
#   Task 490: SKIP (gradient_explosion)
#   Task 491: target_sharpe_reached (8,192 steps, sharpe=+927765368.94)
#   Task 492: target_sharpe_reached (8,192 steps, sharpe=+1766143025.24)
#   Task 493: SKIP (gradient_explosion)
#   Task 494: SKIP (gradient_explosion)
#   Task 495: SKIP (gradient_explosion)
#   Task 496: SKIP (gradient_explosion)
#   Task 497: SKIP (gradient_explosion)
#   Task 498: SKIP (gradient_explosion)
#   Task 499: SKIP (gradient_explosion)
#   Task 500: target_sharpe_reached (8,192 steps, sharpe=+3356240928.68)
#   Task 501: SKIP (gradient_explosion)
#   Task 502: SKIP (gradient_explosion)
#   Task 503: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 466.5s
#
# Meta-iter 37: Outer update amb 4 tasques
#   Task 504: target_sharpe_reached (8,192 steps, sharpe=+2474104496.95)
#   Task 505: SKIP (gradient_explosion)
#   Task 506: SKIP (gradient_explosion)
#   Task 507: target_sharpe_reached (8,192 steps, sharpe=+3488839460.35)
#   Task 508: SKIP (gradient_explosion)
#   Task 509: target_sharpe_reached (8,192 steps, sharpe=+3055343094.51)
#   Task 510: SKIP (gradient_explosion)
#   Task 511: target_sharpe_reached (8,192 steps, sharpe=+4471770262.98)
#   Task 512: SKIP (gradient_explosion)
#   Task 513: SKIP (gradient_explosion)
#   Task 514: target_sharpe_reached (8,192 steps, sharpe=+290294231.66)
#
# Meta-iter 38: Outer update amb 5 tasques
#   Task 515: SKIP (gradient_explosion)
#   Task 516: SKIP (gradient_explosion)
#   Task 517: SKIP (gradient_explosion)
#   Task 518: SKIP (gradient_explosion)
#   Task 519: SKIP (gradient_explosion)
#   Task 520: SKIP (gradient_explosion)
#   Task 521: target_sharpe_reached (8,192 steps, sharpe=+4339165374.92)
#   Task 522: SKIP (gradient_explosion)
#   Task 523: SKIP (gradient_explosion)
#   Task 524: SKIP (gradient_explosion)
#   Task 525: SKIP (gradient_explosion)
#   Task 526: SKIP (gradient_explosion)
#   Task 527: SKIP (gradient_explosion)
#   Task 528: SKIP (gradient_explosion)
#   Task 529: SKIP (gradient_explosion)
#   Task 530: target_sharpe_reached (8,192 steps, sharpe=+21885605.17)
#   Task 531: SKIP (gradient_explosion)
#   Task 532: SKIP (gradient_explosion)
#   Task 533: SKIP (gradient_explosion)
#   Task 534: SKIP (gradient_explosion)
#   Task 535: SKIP (gradient_explosion)
#   Task 536: SKIP (gradient_explosion)
#   Task 537: target_sharpe_reached (8,192 steps, sharpe=+4014529147.80)
#   Batch timeout: 3 tasks in 700.9s
#
# Meta-iter 39: Outer update amb 3 tasques
#   Task 538: SKIP (gradient_explosion)
#   Task 539: target_sharpe_reached (8,192 steps, sharpe=+992676360.36)
#   Task 540: SKIP (gradient_explosion)
#   Task 541: target_sharpe_reached (8,192 steps, sharpe=+1487901420.23)
#   Task 542: SKIP (gradient_explosion)
#   Task 543: SKIP (gradient_explosion)
#   Task 544: SKIP (gradient_explosion)
#   Task 545: SKIP (gradient_explosion)
#   Task 546: SKIP (gradient_explosion)
#   Task 547: SKIP (gradient_explosion)
#   Task 548: target_sharpe_reached (8,192 steps, sharpe=+3771142553.95)
#   Task 549: SKIP (gradient_explosion)
#   Task 550: SKIP (gradient_explosion)
#   Task 551: SKIP (gradient_explosion)
#   Task 552: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 451.6s
#
# Meta-iter 40: Outer update amb 3 tasques
#   Val: sharpe=+0.0000 ret=+0.00% best=+0.3060 [plateau 7/20]
#
#   Task 553: target_sharpe_reached (8,192 steps, sharpe=+88374065.41)
#   Task 554: SKIP (gradient_explosion)
#   Task 555: target_sharpe_reached (8,192 steps, sharpe=+7011747021.21)
#   Task 556: SKIP (gradient_explosion)
#   Task 557: SKIP (gradient_explosion)
#   Task 558: target_sharpe_reached (8,192 steps, sharpe=+1584127394.13)
#   Task 559: SKIP (gradient_explosion)
#   Task 560: SKIP (gradient_explosion)
#   Task 561: SKIP (gradient_explosion)
#   Task 562: target_sharpe_reached (8,192 steps, sharpe=+9758316771.03)
#   Task 563: SKIP (gradient_explosion)
#   Task 564: SKIP (gradient_explosion)
#   Task 565: SKIP (gradient_explosion)
#   Task 566: target_sharpe_reached (8,192 steps, sharpe=+7916195218.36)
#
# Meta-iter 41: Outer update amb 5 tasques
#   Task 567: SKIP (gradient_explosion)
#   Task 568: SKIP (gradient_explosion)
#   Task 569: SKIP (gradient_explosion)
#   Task 570: SKIP (gradient_explosion)
#   Task 571: SKIP (gradient_explosion)
#   Task 572: SKIP (gradient_explosion)
#   Task 573: SKIP (gradient_explosion)
#   Task 574: SKIP (gradient_explosion)
#   Task 575: target_sharpe_reached (8,192 steps, sharpe=+1944388438.04)
#   Task 576: SKIP (gradient_explosion)
#   Task 577: target_sharpe_reached (8,192 steps, sharpe=+111690054.77)
#   Task 578: SKIP (gradient_explosion)
#   Task 579: SKIP (gradient_explosion)
#   Task 580: SKIP (gradient_explosion)
#   Task 581: SKIP (gradient_explosion)
#   Task 582: SKIP (gradient_explosion)
#   Task 583: SKIP (gradient_explosion)
#   Task 584: SKIP (gradient_explosion)
#   Task 585: SKIP (gradient_explosion)
#   Task 586: target_sharpe_reached (8,192 steps, sharpe=+1575724182.31)
#   Batch timeout: 3 tasks in 593.1s
#
# Meta-iter 42: Outer update amb 3 tasques
#   Task 587: target_sharpe_reached (8,192 steps, sharpe=+979751478.10)
#   Task 588: SKIP (gradient_explosion)
#   Task 589: target_sharpe_reached (8,192 steps, sharpe=+2502973396.10)
#   Task 590: SKIP (gradient_explosion)
#   Task 591: SKIP (gradient_explosion)
#   Task 592: target_sharpe_reached (8,192 steps, sharpe=+2980570811.91)
#   Task 593: SKIP (gradient_explosion)
#   Task 594: SKIP (gradient_explosion)
#   Task 595: target_sharpe_reached (8,192 steps, sharpe=+2390960571.46)
#   Task 596: target_sharpe_reached (8,192 steps, sharpe=+1617756150.67)
#
# Meta-iter 43: Outer update amb 5 tasques
#   Task 597: SKIP (gradient_explosion)
#   Task 598: SKIP (gradient_explosion)
#   Task 599: target_sharpe_reached (8,192 steps, sharpe=+649690849.42)
#   Task 600: target_sharpe_reached (8,192 steps, sharpe=+2163029587.82)
#   Task 601: target_sharpe_reached (8,192 steps, sharpe=+43434340.33)
#   Task 602: target_sharpe_reached (8,192 steps, sharpe=+5246858752.14)
#   Task 603: SKIP (gradient_explosion)
#   Task 604: SKIP (gradient_explosion)
#   Task 605: SKIP (gradient_explosion)
#   Task 606: SKIP (gradient_explosion)
#   Task 607: SKIP (gradient_explosion)
#   Task 608: SKIP (gradient_explosion)
#   Task 609: SKIP (gradient_explosion)
#   Task 610: SKIP (gradient_explosion)
#   Task 611: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 480.7s
#
# Meta-iter 44: Outer update amb 4 tasques
#   Task 612: SKIP (gradient_explosion)
#   Task 613: target_sharpe_reached (8,192 steps, sharpe=+2314414144.83)
#   Task 614: target_sharpe_reached (8,192 steps, sharpe=+1596192909.64)
#   Task 615: SKIP (gradient_explosion)
#   Task 616: target_sharpe_reached (8,192 steps, sharpe=+2999666665.72)
#   Task 617: target_sharpe_reached (8,192 steps, sharpe=+144116757.30)
#   Task 618: target_sharpe_reached (8,192 steps, sharpe=+340624847.70)
#
# Meta-iter 45: Outer update amb 5 tasques
#   Val: sharpe=+0.0000 ret=+0.00% best=+0.3060 [plateau 8/20]
#
#   Task 619: target_sharpe_reached (8,192 steps, sharpe=+3977758618.00)
#   Task 620: SKIP (gradient_explosion)
#   Task 621: SKIP (gradient_explosion)
#   Task 622: SKIP (gradient_explosion)
#   Task 623: SKIP (gradient_explosion)
#   Task 624: SKIP (gradient_explosion)
#   Task 625: target_sharpe_reached (8,192 steps, sharpe=+7302384751.27)
#   Task 626: SKIP (gradient_explosion)
#   Task 627: target_sharpe_reached (8,192 steps, sharpe=+2461976960.41)
#   Task 628: target_sharpe_reached (8,192 steps, sharpe=+6176230633.29)
#   Task 629: target_sharpe_reached (8,192 steps, sharpe=+2529708315.63)
#
# Meta-iter 46: Outer update amb 5 tasques
#   Task 630: target_sharpe_reached (8,192 steps, sharpe=+4979488169.16)
#   Task 631: SKIP (gradient_explosion)
#   Task 632: SKIP (gradient_explosion)
#   Task 633: target_sharpe_reached (8,192 steps, sharpe=+1476608676.46)
#   Task 634: SKIP (gradient_explosion)
#   Task 635: target_sharpe_reached (8,192 steps, sharpe=+310228316.13)
#   Task 636: SKIP (gradient_explosion)
#   Task 637: SKIP (gradient_explosion)
#   Task 638: SKIP (gradient_explosion)
#   Task 639: target_sharpe_reached (8,192 steps, sharpe=+755847819.67)
#   Task 640: target_sharpe_reached (8,192 steps, sharpe=+3085919444.08)
#
# Meta-iter 47: Outer update amb 5 tasques
#   Task 641: SKIP (gradient_explosion)
#   Task 642: SKIP (gradient_explosion)
#   Task 643: target_sharpe_reached (8,192 steps, sharpe=+17791906336.96)
#   Task 644: target_sharpe_reached (8,192 steps, sharpe=+719438764.85)
#   Task 645: SKIP (gradient_explosion)
#   Task 646: SKIP (gradient_explosion)
#   Task 647: SKIP (gradient_explosion)
#   Task 648: target_sharpe_reached (8,192 steps, sharpe=+266517469.92)
#   Task 649: target_sharpe_reached (8,192 steps, sharpe=+3254091463.60)
#   Task 650: target_sharpe_reached (8,192 steps, sharpe=+13178800178.38)
#
# Meta-iter 48: Outer update amb 5 tasques
#   Task 651: target_sharpe_reached (8,192 steps, sharpe=+2422974887.84)
#   Task 652: SKIP (gradient_explosion)
#   Task 653: target_sharpe_reached (8,192 steps, sharpe=+1640676960.28)
#   Task 654: SKIP (gradient_explosion)
#   Task 655: target_sharpe_reached (8,192 steps, sharpe=+3495303520.63)
#   Task 656: SKIP (gradient_explosion)
#   Task 657: SKIP (gradient_explosion)
#   Task 658: SKIP (gradient_explosion)
#   Task 659: SKIP (gradient_explosion)
#   Task 660: target_sharpe_reached (8,192 steps, sharpe=+2158859306.64)
#   Task 661: target_sharpe_reached (8,192 steps, sharpe=+5203050043.74)
#
# Meta-iter 49: Outer update amb 5 tasques
#   Task 662: SKIP (gradient_explosion)
#   Task 663: SKIP (gradient_explosion)
#   Task 664: SKIP (gradient_explosion)
#   Task 665: SKIP (gradient_explosion)
#   Task 666: SKIP (gradient_explosion)
#   Task 667: SKIP (gradient_explosion)
#   Task 668: SKIP (gradient_explosion)
#   Task 669: SKIP (gradient_explosion)
#   Task 670: SKIP (gradient_explosion)
#   Task 671: target_sharpe_reached (8,192 steps, sharpe=+2151752406.37)
#   Task 672: SKIP (gradient_explosion)
#   Task 673: target_sharpe_reached (8,192 steps, sharpe=+1314185073.92)
#   Task 674: target_sharpe_reached (8,192 steps, sharpe=+2682717088.27)
#   Batch timeout: 3 tasks in 456.7s
#
# Meta-iter 50: Outer update amb 3 tasques
#   Val: sharpe=+0.0000 ret=+0.00% best=+0.3060 [plateau 9/20]
#
#   [ckpt] Desat checkpoint @ iter 50 → ppo_reptile_meta_new_adaptative.pt
#   Task 675: target_sharpe_reached (8,192 steps, sharpe=+3352476152.38)
#   Task 676: SKIP (gradient_explosion)
#   Task 677: target_sharpe_reached (8,192 steps, sharpe=+502506105.41)
#   Task 678: SKIP (gradient_explosion)
#   Task 679: SKIP (gradient_explosion)
#   Task 680: SKIP (gradient_explosion)
#   Task 681: target_sharpe_reached (8,192 steps, sharpe=+3921902265.07)
#   Task 682: target_sharpe_reached (8,192 steps, sharpe=+315711683.55)
#   Task 683: target_sharpe_reached (8,192 steps, sharpe=+334642208.35)
#
# Meta-iter 51: Outer update amb 5 tasques
#   Task 684: SKIP (gradient_explosion)
#   Task 685: SKIP (gradient_explosion)
#   Task 686: SKIP (gradient_explosion)
#   Task 687: SKIP (gradient_explosion)
#   Task 688: SKIP (gradient_explosion)
#   Task 689: SKIP (gradient_explosion)
#   Task 690: SKIP (gradient_explosion)
#   Task 691: target_sharpe_reached (8,192 steps, sharpe=+696918121.25)
#   Task 692: SKIP (gradient_explosion)
#   Task 693: SKIP (gradient_explosion)
#   Task 694: target_sharpe_reached (8,192 steps, sharpe=+379813227.11)
#   Task 695: SKIP (gradient_explosion)
#   Task 696: SKIP (gradient_explosion)
#   Task 697: SKIP (gradient_explosion)
#   Task 698: SKIP (gradient_explosion)
#   Task 699: target_sharpe_reached (8,192 steps, sharpe=+1127822172.15)
#   Batch timeout: 3 tasks in 636.8s
#
# Meta-iter 52: Outer update amb 3 tasques
#   Task 700: SKIP (gradient_explosion)
#   Task 701: target_sharpe_reached (8,192 steps, sharpe=+1146698603.53)
#   Task 702: SKIP (gradient_explosion)
#   Task 703: SKIP (gradient_explosion)
#   Task 704: SKIP (gradient_explosion)
#   Task 705: target_sharpe_reached (8,192 steps, sharpe=+3641311585.15)
#   Task 706: target_sharpe_reached (8,192 steps, sharpe=+1763581904.03)
#   Task 707: SKIP (gradient_explosion)
#   Task 708: target_sharpe_reached (8,192 steps, sharpe=+9798797036.56)
#   Task 709: SKIP (gradient_explosion)
#   Task 710: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 456.2s
#
# Meta-iter 53: Outer update amb 4 tasques
#   Task 711: SKIP (gradient_explosion)
#   Task 712: SKIP (gradient_explosion)
#   Task 713: SKIP (gradient_explosion)
#   Task 714: SKIP (gradient_explosion)
#   Task 715: SKIP (gradient_explosion)
#   Task 716: target_sharpe_reached (8,192 steps, sharpe=+2314541696.02)
#   Task 717: SKIP (gradient_explosion)
#   Task 718: SKIP (gradient_explosion)
#   Task 719: SKIP (gradient_explosion)
#   Task 720: target_sharpe_reached (8,192 steps, sharpe=+3879773970.04)
#   Task 721: SKIP (gradient_explosion)
#   Task 722: target_sharpe_reached (8,192 steps, sharpe=+2379677910.65)
#   Batch timeout: 3 tasks in 491.7s
#
# Meta-iter 54: Outer update amb 3 tasques
#   Task 723: SKIP (gradient_explosion)
#   Task 724: SKIP (gradient_explosion)
#   Task 725: target_sharpe_reached (8,192 steps, sharpe=+2937174252.10)
#   Task 726: SKIP (gradient_explosion)
#   Task 727: SKIP (gradient_explosion)
#   Task 728: target_sharpe_reached (8,192 steps, sharpe=+13521569418.00)
#   Task 729: SKIP (gradient_explosion)
#   Task 730: SKIP (gradient_explosion)
#   Task 731: target_sharpe_reached (8,192 steps, sharpe=+630201117.79)
#   Task 732: SKIP (gradient_explosion)
#   Task 733: SKIP (gradient_explosion)
#   Task 734: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 476.9s
#
# Meta-iter 55: Outer update amb 3 tasques
#   Val: sharpe=+0.0000 ret=+0.00% best=+0.3060 [plateau 10/20]
#
#   Task 735: target_sharpe_reached (8,192 steps, sharpe=+2429996537.70)
#   Task 736: SKIP (gradient_explosion)
#   Task 737: target_sharpe_reached (8,192 steps, sharpe=+409960827.60)
#   Task 738: target_sharpe_reached (8,192 steps, sharpe=+4381685370.91)
#   Task 739: target_sharpe_reached (8,192 steps, sharpe=+1513354555.60)
#   Task 740: SKIP (gradient_explosion)
#   Task 741: SKIP (gradient_explosion)
#   Task 742: SKIP (gradient_explosion)
#   Task 743: SKIP (gradient_explosion)
#   Task 744: SKIP (gradient_explosion)
#   Task 745: target_sharpe_reached (8,192 steps, sharpe=+2336361127.76)
#
# Meta-iter 56: Outer update amb 5 tasques
#   Task 746: SKIP (gradient_explosion)
#   Task 747: SKIP (gradient_explosion)
#   Task 748: target_sharpe_reached (8,192 steps, sharpe=+740139297.93)
#   Task 749: SKIP (gradient_explosion)
#   Task 750: SKIP (gradient_explosion)
#   Task 751: SKIP (gradient_explosion)
#   Task 752: target_sharpe_reached (8,192 steps, sharpe=+110738319.67)
#   Task 753: SKIP (gradient_explosion)
#   Task 754: SKIP (gradient_explosion)
#   Task 755: target_sharpe_reached (8,192 steps, sharpe=+53274208.41)
#   Task 756: target_sharpe_reached (8,192 steps, sharpe=+4995267347.65)
#   Task 757: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 483.1s
#
# Meta-iter 57: Outer update amb 4 tasques
#   Task 758: SKIP (gradient_explosion)
#   Task 759: target_sharpe_reached (8,192 steps, sharpe=+2533815951.60)
#   Task 760: SKIP (gradient_explosion)
#   Task 761: SKIP (gradient_explosion)
#   Task 762: target_sharpe_reached (8,192 steps, sharpe=+966569061.54)
#   Task 763: SKIP (gradient_explosion)
#   Task 764: target_sharpe_reached (8,192 steps, sharpe=+2332426745.24)
#   Task 765: SKIP (gradient_explosion)
#   Task 766: SKIP (gradient_explosion)
#   Task 767: SKIP (gradient_explosion)
#   Task 768: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 451.3s
#
# Meta-iter 58: Outer update amb 3 tasques
#   Task 769: SKIP (gradient_explosion)
#   Task 770: SKIP (gradient_explosion)
#   Task 771: SKIP (gradient_explosion)
#   Task 772: target_sharpe_reached (8,192 steps, sharpe=+291130796.45)
#   Task 773: SKIP (gradient_explosion)
#   Task 774: target_sharpe_reached (8,192 steps, sharpe=+1551553113.86)
#   Task 775: target_sharpe_reached (8,192 steps, sharpe=+574594066.45)
#   Task 776: SKIP (gradient_explosion)
#   Task 777: SKIP (gradient_explosion)
#   Task 778: SKIP (gradient_explosion)
#   Task 779: SKIP (gradient_explosion)
#   Task 780: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 480.5s
#
# Meta-iter 59: Outer update amb 3 tasques
#   Task 781: SKIP (gradient_explosion)
#   Task 782: target_sharpe_reached (8,192 steps, sharpe=+4060188706.76)
#   Task 783: SKIP (gradient_explosion)
#   Task 784: SKIP (gradient_explosion)
#   Task 785: SKIP (gradient_explosion)
#   Task 786: SKIP (gradient_explosion)
#   Task 787: target_sharpe_reached (8,192 steps, sharpe=+145110443.67)
#   Task 788: SKIP (gradient_explosion)
#   Task 789: SKIP (gradient_explosion)
#   Task 790: target_sharpe_reached (8,192 steps, sharpe=+1155023059.00)
#   Task 791: SKIP (gradient_explosion)
#   Task 792: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 471.6s
#
# Meta-iter 60: Outer update amb 3 tasques
#   Val: sharpe=+0.0000 ret=+0.00% best=+0.3060 [plateau 11/20]
#
#   Task 793: SKIP (gradient_explosion)
#   Task 794: SKIP (gradient_explosion)
#   Task 795: SKIP (gradient_explosion)
#   Task 796: SKIP (gradient_explosion)
#   Task 797: SKIP (gradient_explosion)
#   Task 798: target_sharpe_reached (8,192 steps, sharpe=+943863244.10)
#   Task 799: SKIP (gradient_explosion)
#   Task 800: SKIP (gradient_explosion)
#   Task 801: SKIP (gradient_explosion)
#   Task 802: SKIP (gradient_explosion)
#   Task 803: SKIP (gradient_explosion)
#   Task 804: SKIP (gradient_explosion)
#   Task 805: SKIP (gradient_explosion)
#   Task 806: SKIP (gradient_explosion)
#   Task 807: SKIP (gradient_explosion)
#   Task 808: SKIP (gradient_explosion)
#   Task 809: SKIP (gradient_explosion)
#   Task 810: target_sharpe_reached (8,192 steps, sharpe=+1223766362.59)
#   Task 811: SKIP (gradient_explosion)
#   Task 812: target_sharpe_reached (8,192 steps, sharpe=+1992382633.62)
#   Batch timeout: 3 tasks in 801.5s
#
# Meta-iter 61: Outer update amb 3 tasques
#   Task 813: SKIP (gradient_explosion)
#   Task 814: SKIP (gradient_explosion)
#   Task 815: SKIP (gradient_explosion)
#   Task 816: SKIP (gradient_explosion)
#   Task 817: SKIP (gradient_explosion)
#   Task 818: target_sharpe_reached (8,192 steps, sharpe=+3955609617.79)
#   Task 819: SKIP (gradient_explosion)
#   Task 820: target_sharpe_reached (8,192 steps, sharpe=+1230552055.27)
#   Task 821: target_sharpe_reached (8,192 steps, sharpe=+3598384850.04)
#   Task 822: SKIP (gradient_explosion)
#   Task 823: SKIP (gradient_explosion)
#   Task 824: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 477.6s
#
# Meta-iter 62: Outer update amb 3 tasques
#   Task 825: target_sharpe_reached (8,192 steps, sharpe=+719318930.28)
#   Task 826: target_sharpe_reached (8,192 steps, sharpe=+331858540.28)
#   Task 827: target_sharpe_reached (8,192 steps, sharpe=+983617217.60)
#   Task 828: target_sharpe_reached (8,192 steps, sharpe=+1052407564.49)
#   Task 829: SKIP (gradient_explosion)
#   Task 830: SKIP (gradient_explosion)
#   Task 831: target_sharpe_reached (8,192 steps, sharpe=+2932679481.38)
#
# Meta-iter 63: Outer update amb 5 tasques
#   Task 832: SKIP (gradient_explosion)
#   Task 833: SKIP (gradient_explosion)
#   Task 834: target_sharpe_reached (8,192 steps, sharpe=+2165159800.86)
#   Task 835: SKIP (gradient_explosion)
#   Task 836: target_sharpe_reached (8,192 steps, sharpe=+1313313159.54)
#   Task 837: target_sharpe_reached (8,192 steps, sharpe=+7990248890.72)
#   Task 838: target_sharpe_reached (8,192 steps, sharpe=+738099136.61)
#   Task 839: SKIP (gradient_explosion)
#   Task 840: SKIP (gradient_explosion)
#   Task 841: target_sharpe_reached (8,192 steps, sharpe=+2590620081.55)
#
# Meta-iter 64: Outer update amb 5 tasques
#   Task 842: SKIP (gradient_explosion)
#   Task 843: SKIP (gradient_explosion)
#   Task 844: target_sharpe_reached (8,192 steps, sharpe=+1983678237.01)
#   Task 845: SKIP (gradient_explosion)
#   Task 846: SKIP (gradient_explosion)
#   Task 847: target_sharpe_reached (8,192 steps, sharpe=+2405139018.29)
#   Task 848: SKIP (gradient_explosion)
#   Task 849: SKIP (gradient_explosion)
#   Task 850: target_sharpe_reached (8,192 steps, sharpe=+2237389553.27)
#   Task 851: SKIP (gradient_explosion)
#   Task 852: target_sharpe_reached (8,192 steps, sharpe=+579505811.83)
#   Task 853: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 480.9s
#
# Meta-iter 65: Outer update amb 4 tasques
#   Val: sharpe=+0.0000 ret=+0.00% best=+0.3060 [plateau 12/20]
#
#   Task 854: SKIP (gradient_explosion)
#   Task 855: SKIP (gradient_explosion)
#   Task 856: target_sharpe_reached (8,192 steps, sharpe=+2006491622.68)
#   Task 857: SKIP (gradient_explosion)
#   Task 858: target_sharpe_reached (8,192 steps, sharpe=+3898217160.99)
#   Task 859: target_sharpe_reached (8,192 steps, sharpe=+961438919.44)
#   Task 860: SKIP (gradient_explosion)
#   Task 861: SKIP (gradient_explosion)
#   Task 862: SKIP (gradient_explosion)
#   Task 863: SKIP (gradient_explosion)
#   Task 864: target_sharpe_reached (8,192 steps, sharpe=+1585535576.82)
#   Task 865: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 481.8s
#
# Meta-iter 66: Outer update amb 4 tasques
#   Task 866: target_sharpe_reached (8,192 steps, sharpe=+722140545.24)
#   Task 867: SKIP (gradient_explosion)
#   Task 868: SKIP (gradient_explosion)
#   Task 869: SKIP (gradient_explosion)
#   Task 870: SKIP (gradient_explosion)
#   Task 871: target_sharpe_reached (8,192 steps, sharpe=+9252184020.37)
#   Task 872: target_sharpe_reached (8,192 steps, sharpe=+2997432800.00)
#   Task 873: SKIP (gradient_explosion)
#   Task 874: SKIP (gradient_explosion)
#   Task 875: SKIP (gradient_explosion)
#   Task 876: SKIP (gradient_explosion)
#   Task 877: target_sharpe_reached (8,192 steps, sharpe=+4873194212.71)
#   Batch timeout: 4 tasks in 488.8s
#
# Meta-iter 67: Outer update amb 4 tasques
#   Task 878: SKIP (gradient_explosion)
#   Task 879: SKIP (gradient_explosion)
#   Task 880: SKIP (gradient_explosion)
#   Task 881: target_sharpe_reached (8,192 steps, sharpe=+3437339971.30)
#   Task 882: SKIP (gradient_explosion)
#   Task 883: SKIP (gradient_explosion)
#   Task 884: target_sharpe_reached (8,192 steps, sharpe=+1630189806.57)
#   Task 885: target_sharpe_reached (8,192 steps, sharpe=+5086467123.40)
#   Task 886: target_sharpe_reached (8,192 steps, sharpe=+2300812657.71)
# ...
#   Task 1058: SKIP (gradient_explosion)
#   Task 1059: SKIP (gradient_explosion)
#   Task 1060: target_sharpe_reached (8,192 steps, sharpe=+212194898.04)
#   Batch timeout: 4 tasks in 465.0s
#
# Meta-iter 82: Outer update amb 4 tasques
#   Task 1061: target_sharpe_reached (8,192 steps, sharpe=+768569.40)
#   Task 1062: SKIP (gradient_explosion)
#   Task 1063: SKIP (gradient_explosion)
#   Task 1064: target_sharpe_reached (8,192 steps, sharpe=+2984907822.61)
#   Task 1065: SKIP (gradient_explosion)
#   Task 1066: SKIP (gradient_explosion)
#   Task 1067: SKIP (gradient_explosion)
#   Task 1068: SKIP (gradient_explosion)
#   Task 1069: target_sharpe_reached (8,192 steps, sharpe=+1485688581.95)
#   Task 1070: target_sharpe_reached (8,192 steps, sharpe=+1912756319.92)
#   Task 1071: target_sharpe_reached (8,192 steps, sharpe=+8125899992.09)
#
# Meta-iter 83: Outer update amb 5 tasques
#   Task 1072: target_sharpe_reached (8,192 steps, sharpe=+1505597708.88)
#   Task 1073: SKIP (gradient_explosion)
#   Task 1074: SKIP (gradient_explosion)
#   Task 1075: target_sharpe_reached (8,192 steps, sharpe=+150182141.92)
#   Task 1076: SKIP (gradient_explosion)
#   Task 1077: SKIP (gradient_explosion)
#   Task 1078: SKIP (gradient_explosion)
#   Task 1079: SKIP (gradient_explosion)
#   Task 1080: SKIP (gradient_explosion)
#   Task 1081: SKIP (gradient_explosion)
#   Task 1082: target_sharpe_reached (8,192 steps, sharpe=+660910831.30)
#   Task 1083: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 468.8s
#
# Meta-iter 84: Outer update amb 3 tasques
#   Task 1084: target_sharpe_reached (8,192 steps, sharpe=+8947143704.85)
#   Task 1085: SKIP (gradient_explosion)
#   Task 1086: SKIP (gradient_explosion)
#   Task 1087: target_sharpe_reached (8,192 steps, sharpe=+3695718981.07)
#   Task 1088: SKIP (gradient_explosion)
#   Task 1089: SKIP (gradient_explosion)
#   Task 1090: SKIP (gradient_explosion)
#   Task 1091: SKIP (gradient_explosion)
#   Task 1092: target_sharpe_reached (8,192 steps, sharpe=+2473626427.80)
#   Task 1093: target_sharpe_reached (8,192 steps, sharpe=+982162130.44)
#   Task 1094: SKIP (gradient_explosion)
#   Task 1095: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 467.0s
#
# Meta-iter 85: Outer update amb 4 tasques
#   Val: sharpe=-1.8049 ret=-14.07% best=+0.3060 [plateau 16/20]
#
#   Task 1096: SKIP (gradient_explosion)
#   Task 1097: target_sharpe_reached (8,192 steps, sharpe=+245863560.54)
#   Task 1098: SKIP (gradient_explosion)
#   Task 1099: SKIP (gradient_explosion)
#   Task 1100: SKIP (gradient_explosion)
#   Task 1101: target_sharpe_reached (8,192 steps, sharpe=+5139682851.17)
#   Task 1102: SKIP (gradient_explosion)
#   Task 1103: SKIP (gradient_explosion)
#   Task 1104: SKIP (gradient_explosion)
#   Task 1105: target_sharpe_reached (8,192 steps, sharpe=+2205869806.69)
#   Task 1106: target_sharpe_reached (8,192 steps, sharpe=+2478513673.65)
#   Task 1107: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 466.1s
#
# Meta-iter 86: Outer update amb 4 tasques
#   Task 1108: SKIP (gradient_explosion)
#   Task 1109: SKIP (gradient_explosion)
#   Task 1110: SKIP (gradient_explosion)
#   Task 1111: target_sharpe_reached (8,192 steps, sharpe=+7598408776.46)
#   Task 1112: target_sharpe_reached (8,192 steps, sharpe=+4850410826.90)
#   Task 1113: SKIP (gradient_explosion)
#   Task 1114: target_sharpe_reached (8,192 steps, sharpe=+6581653999.24)
#   Task 1115: SKIP (gradient_explosion)
#   Task 1116: target_sharpe_reached (8,192 steps, sharpe=+4536071692.15)
#   Task 1117: target_sharpe_reached (8,192 steps, sharpe=+46743873.10)
#
# Meta-iter 87: Outer update amb 5 tasques
#   Task 1118: SKIP (gradient_explosion)
#   Task 1119: SKIP (gradient_explosion)
#   Task 1120: SKIP (gradient_explosion)
#   Task 1121: target_sharpe_reached (8,192 steps, sharpe=+1042077293.29)
#   Task 1122: SKIP (gradient_explosion)
#   Task 1123: target_sharpe_reached (8,192 steps, sharpe=+2765378756.14)
#   Task 1124: SKIP (gradient_explosion)
#   Task 1125: target_sharpe_reached (8,192 steps, sharpe=+2496524082.18)
#   Task 1126: target_sharpe_reached (8,192 steps, sharpe=+2246296500.02)
#   Task 1127: SKIP (gradient_explosion)
#   Task 1128: SKIP (gradient_explosion)
#   Task 1129: SKIP (gradient_explosion)
#   Task 1130: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 479.8s
#
# Meta-iter 88: Outer update amb 4 tasques
#   Task 1131: target_sharpe_reached (8,192 steps, sharpe=+3098724349.10)
#   Task 1132: SKIP (gradient_explosion)
#   Task 1133: SKIP (gradient_explosion)
#   Task 1134: target_sharpe_reached (8,192 steps, sharpe=+2447151540.09)
#   Task 1135: target_sharpe_reached (8,192 steps, sharpe=+1056315162.12)
#   Task 1136: SKIP (gradient_explosion)
#   Task 1137: SKIP (gradient_explosion)
#   Task 1138: target_sharpe_reached (8,192 steps, sharpe=+4331852938.19)
#   Task 1139: SKIP (gradient_explosion)
#   Task 1140: SKIP (gradient_explosion)
#   Task 1141: target_sharpe_reached (8,192 steps, sharpe=+920783116.43)
#
# Meta-iter 89: Outer update amb 5 tasques
#   Task 1142: SKIP (gradient_explosion)
#   Task 1143: target_sharpe_reached (8,192 steps, sharpe=+2061485654.24)
#   Task 1144: SKIP (gradient_explosion)
#   Task 1145: target_sharpe_reached (8,192 steps, sharpe=+18944573574.65)
#   Task 1146: SKIP (gradient_explosion)
#   Task 1147: target_sharpe_reached (8,192 steps, sharpe=+2944163551.68)
#   Task 1148: target_sharpe_reached (8,192 steps, sharpe=+1566632609.41)
#   Task 1149: SKIP (gradient_explosion)
#   Task 1150: target_sharpe_reached (8,192 steps, sharpe=+2335736224.04)
#
# Meta-iter 90: Outer update amb 5 tasques
#   Val: sharpe=-0.0565 ret=-1.09% best=+0.3060 [plateau 17/20]
#
#   Task 1151: SKIP (gradient_explosion)
#   Task 1152: SKIP (gradient_explosion)
#   Task 1153: SKIP (gradient_explosion)
#   Task 1154: target_sharpe_reached (8,192 steps, sharpe=+36152125.23)
#   Task 1155: SKIP (gradient_explosion)
#   Task 1156: SKIP (gradient_explosion)
#   Task 1157: target_sharpe_reached (8,192 steps, sharpe=+3269635836.12)
#   Task 1158: target_sharpe_reached (8,192 steps, sharpe=+3454430382.92)
#   Task 1159: target_sharpe_reached (8,192 steps, sharpe=+757406891.86)
#   Task 1160: SKIP (gradient_explosion)
#   Task 1161: SKIP (gradient_explosion)
#   Task 1162: target_sharpe_reached (8,192 steps, sharpe=+2183686248.70)
#
# Meta-iter 91: Outer update amb 5 tasques
#   Task 1163: SKIP (gradient_explosion)
#   Task 1164: target_sharpe_reached (8,192 steps, sharpe=+2960421145.48)
#   Task 1165: SKIP (gradient_explosion)
#   Task 1166: SKIP (gradient_explosion)
#   Task 1167: target_sharpe_reached (8,192 steps, sharpe=+1778876165.08)
#   Task 1168: target_sharpe_reached (8,192 steps, sharpe=+3926728735.04)
#   Task 1169: SKIP (gradient_explosion)
#   Task 1170: SKIP (gradient_explosion)
#   Task 1171: SKIP (gradient_explosion)
#   Task 1172: target_sharpe_reached (8,192 steps, sharpe=+1659400360.20)
#   Task 1173: target_sharpe_reached (8,192 steps, sharpe=+2340009752.21)
#
# Meta-iter 92: Outer update amb 5 tasques
#   Task 1174: target_sharpe_reached (8,192 steps, sharpe=+1481644108.65)
#   Task 1175: SKIP (gradient_explosion)
#   Task 1176: SKIP (gradient_explosion)
#   Task 1177: target_sharpe_reached (8,192 steps, sharpe=+4248780160.02)
#   Task 1178: target_sharpe_reached (8,192 steps, sharpe=+239529839.86)
#   Task 1179: SKIP (gradient_explosion)
#   Task 1180: SKIP (gradient_explosion)
#   Task 1181: SKIP (gradient_explosion)
#   Task 1182: target_sharpe_reached (8,192 steps, sharpe=+1509293027.77)
#   Task 1183: SKIP (gradient_explosion)
#   Task 1184: SKIP (gradient_explosion)
#   Task 1185: SKIP (gradient_explosion)
#   Task 1186: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 482.4s
#
# Meta-iter 93: Outer update amb 4 tasques
#   Task 1187: SKIP (gradient_explosion)
#   Task 1188: SKIP (gradient_explosion)
#   Task 1189: target_sharpe_reached (8,192 steps, sharpe=+3670661279.04)
#   Task 1190: SKIP (gradient_explosion)
#   Task 1191: target_sharpe_reached (8,192 steps, sharpe=+1335419415.03)
#   Task 1192: SKIP (gradient_explosion)
#   Task 1193: SKIP (gradient_explosion)
#   Task 1194: SKIP (gradient_explosion)
#   Task 1195: SKIP (gradient_explosion)
#   Task 1196: SKIP (gradient_explosion)
#   Task 1197: SKIP (gradient_explosion)
#   Task 1198: SKIP (gradient_explosion)
#   Task 1199: SKIP (gradient_explosion)
#   Task 1200: SKIP (gradient_explosion)
#   Task 1201: target_sharpe_reached (8,192 steps, sharpe=+12991382302.74)
#   Batch timeout: 3 tasks in 568.7s
#
# Meta-iter 94: Outer update amb 3 tasques
#   Task 1202: SKIP (gradient_explosion)
#   Task 1203: target_sharpe_reached (8,192 steps, sharpe=+1647973483.93)
#   Task 1204: target_sharpe_reached (8,192 steps, sharpe=+497568436.95)
#   Task 1205: SKIP (gradient_explosion)
#   Task 1206: SKIP (gradient_explosion)
#   Task 1207: SKIP (gradient_explosion)
#   Task 1208: SKIP (gradient_explosion)
#   Task 1209: SKIP (gradient_explosion)
#   Task 1210: SKIP (gradient_explosion)
#   Task 1211: SKIP (gradient_explosion)
#   Task 1212: target_sharpe_reached (8,192 steps, sharpe=+4787062395.44)
#   Task 1213: target_sharpe_reached (8,192 steps, sharpe=+1333680914.20)
#   Batch timeout: 4 tasks in 460.3s
#
# Meta-iter 95: Outer update amb 4 tasques
#   Val: sharpe=-0.1505 ret=-3.01% best=+0.3060 [plateau 18/20]
#
#   Task 1214: SKIP (gradient_explosion)
#   Task 1215: SKIP (gradient_explosion)
#   Task 1216: SKIP (gradient_explosion)
#   Task 1217: target_sharpe_reached (8,192 steps, sharpe=+4801274142.51)
#   Task 1218: SKIP (gradient_explosion)
#   Task 1219: target_sharpe_reached (8,192 steps, sharpe=+205055803.46)
#   Task 1220: SKIP (gradient_explosion)
#   Task 1221: SKIP (gradient_explosion)
#   Task 1222: SKIP (gradient_explosion)
#   Task 1223: SKIP (gradient_explosion)
#   Task 1224: SKIP (gradient_explosion)
#   Task 1225: SKIP (gradient_explosion)
#   Task 1226: SKIP (gradient_explosion)
#   Task 1227: SKIP (gradient_explosion)
#   Task 1228: SKIP (gradient_explosion)
#   Task 1229: SKIP (gradient_explosion)
#   Task 1230: SKIP (gradient_explosion)
#   Task 1231: target_sharpe_reached (8,192 steps, sharpe=+5235363649.18)
#   Batch timeout: 3 tasks in 677.6s
#
# Meta-iter 96: Outer update amb 3 tasques
#   Task 1232: target_sharpe_reached (8,192 steps, sharpe=+1400943513.23)
#   Task 1233: target_sharpe_reached (8,192 steps, sharpe=+3877766866.29)
#   Task 1234: SKIP (gradient_explosion)
#   Task 1235: SKIP (gradient_explosion)
#   Task 1236: target_sharpe_reached (8,192 steps, sharpe=+2581024632.09)
#   Task 1237: SKIP (gradient_explosion)
#   Task 1238: SKIP (gradient_explosion)
#   Task 1239: target_sharpe_reached (8,192 steps, sharpe=+745705016.84)
#   Task 1240: SKIP (gradient_explosion)
#   Task 1241: SKIP (gradient_explosion)
#   Task 1242: target_sharpe_reached (8,192 steps, sharpe=+517297316.52)
#
# Meta-iter 97: Outer update amb 5 tasques
#   Task 1243: target_sharpe_reached (8,192 steps, sharpe=+12688525750.60)
#   Task 1244: SKIP (gradient_explosion)
#   Task 1245: SKIP (gradient_explosion)
#   Task 1246: target_sharpe_reached (8,192 steps, sharpe=+982108617.86)
#   Task 1247: SKIP (gradient_explosion)
#   Task 1248: SKIP (gradient_explosion)
#   Task 1249: SKIP (gradient_explosion)
#   Task 1250: target_sharpe_reached (8,192 steps, sharpe=+1948007798.61)
#   Task 1251: target_sharpe_reached (8,192 steps, sharpe=+978044545.76)
#   Task 1252: SKIP (gradient_explosion)
#   Task 1253: target_sharpe_reached (8,192 steps, sharpe=+1323297457.48)
#
# Meta-iter 98: Outer update amb 5 tasques
#   Task 1254: SKIP (gradient_explosion)
#   Task 1255: SKIP (gradient_explosion)
#   Task 1256: SKIP (gradient_explosion)
#   Task 1257: SKIP (gradient_explosion)
#   Task 1258: SKIP (gradient_explosion)
#   Task 1259: target_sharpe_reached (8,192 steps, sharpe=+2401529928.58)
#   Task 1260: SKIP (gradient_explosion)
#   Task 1261: SKIP (gradient_explosion)
#   Task 1262: SKIP (gradient_explosion)
#   Task 1263: target_sharpe_reached (8,192 steps, sharpe=+1079671670.00)
#   Task 1264: target_sharpe_reached (8,192 steps, sharpe=+2935298802.92)
#   Task 1265: SKIP (gradient_explosion)
#   Task 1266: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 476.7s
#
# Meta-iter 99: Outer update amb 3 tasques
#   Task 1267: SKIP (gradient_explosion)
#   Task 1268: target_sharpe_reached (8,192 steps, sharpe=+789240557.66)
#   Task 1269: SKIP (gradient_explosion)
#   Task 1270: target_sharpe_reached (8,192 steps, sharpe=+2515913691.24)
#   Task 1271: SKIP (gradient_explosion)
#   Task 1272: SKIP (gradient_explosion)
#   Task 1273: target_sharpe_reached (8,192 steps, sharpe=+1977691959.66)
#   Task 1274: SKIP (gradient_explosion)
#   Task 1275: SKIP (gradient_explosion)
#   Task 1276: target_sharpe_reached (8,192 steps, sharpe=+2634146314.01)
#   Task 1277: SKIP (gradient_explosion)
#   Task 1278: target_sharpe_reached (8,192 steps, sharpe=+2045552056.45)
#
# Meta-iter 100: Outer update amb 5 tasques
#   Val: sharpe=-0.1681 ret=-3.10% best=+0.3060 [plateau 19/20]
#
#   [ckpt] Desat checkpoint @ iter 100 → ppo_reptile_meta_new_adaptative.pt
#   Task 1279: target_sharpe_reached (8,192 steps, sharpe=+1255681263.08)
#   Task 1280: target_sharpe_reached (8,192 steps, sharpe=+5081691527.85)
#   Task 1281: target_sharpe_reached (8,192 steps, sharpe=+5148686775.90)
#   Task 1282: target_sharpe_reached (8,192 steps, sharpe=+1114650456.70)
#   Task 1283: SKIP (gradient_explosion)
#   Task 1284: target_sharpe_reached (8,192 steps, sharpe=+7547311803.62)
#
# Meta-iter 101: Outer update amb 5 tasques
#   Task 1285: SKIP (gradient_explosion)
#   Task 1286: SKIP (gradient_explosion)
#   Task 1287: target_sharpe_reached (8,192 steps, sharpe=+4204237567.39)
#   Task 1288: SKIP (gradient_explosion)
#   Task 1289: SKIP (gradient_explosion)
#   Task 1290: target_sharpe_reached (8,192 steps, sharpe=+6271800474.09)
#   Task 1291: SKIP (gradient_explosion)
#   Task 1292: SKIP (gradient_explosion)
#   Task 1293: SKIP (gradient_explosion)
#   Task 1294: SKIP (gradient_explosion)
#   Task 1295: target_sharpe_reached (8,192 steps, sharpe=+3733406132.96)
#   Task 1296: target_sharpe_reached (8,192 steps, sharpe=+3249847099.37)
#   Batch timeout: 4 tasks in 458.8s
#
# Meta-iter 102: Outer update amb 4 tasques
#   Task 1297: target_sharpe_reached (8,192 steps, sharpe=+2712918958.86)
#   Task 1298: SKIP (gradient_explosion)
#   Task 1299: target_sharpe_reached (8,192 steps, sharpe=+1118634342.62)
#   Task 1300: SKIP (gradient_explosion)
#   Task 1301: target_sharpe_reached (8,192 steps, sharpe=+414290387.39)
#   Task 1302: SKIP (gradient_explosion)
#   Task 1303: target_sharpe_reached (8,192 steps, sharpe=+408144591.57)
#   Task 1304: SKIP (gradient_explosion)
#   Task 1305: target_sharpe_reached (8,192 steps, sharpe=+2265790095.38)
#
# Meta-iter 103: Outer update amb 5 tasques
#   Task 1306: SKIP (gradient_explosion)
#   Task 1307: target_sharpe_reached (8,192 steps, sharpe=+3972871939.52)
#   Task 1308: target_sharpe_reached (8,192 steps, sharpe=+2161321403.14)
#   Task 1309: target_sharpe_reached (8,192 steps, sharpe=+2041125157.57)
#   Task 1310: target_sharpe_reached (8,192 steps, sharpe=+50609035.52)
#   Task 1311: target_sharpe_reached (8,192 steps, sharpe=+576906486.58)
#
# Meta-iter 104: Outer update amb 5 tasques
#   Task 1312: SKIP (gradient_explosion)
#   Task 1313: target_sharpe_reached (8,192 steps, sharpe=+2080342831.31)
#   Task 1314: SKIP (gradient_explosion)
#   Task 1315: SKIP (gradient_explosion)
#   Task 1316: SKIP (gradient_explosion)
#   Task 1317: SKIP (gradient_explosion)
#   Task 1318: SKIP (gradient_explosion)
#   Task 1319: target_sharpe_reached (8,192 steps, sharpe=+1321975093.53)
#   Task 1320: SKIP (gradient_explosion)
#   Task 1321: target_sharpe_reached (8,192 steps, sharpe=+504602824.49)
#   Task 1322: SKIP (gradient_explosion)
#   Task 1323: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 471.0s
#
# Meta-iter 105: Outer update amb 3 tasques
#   Val: sharpe=-0.4004 ret=-7.47% best=+0.3060 [plateau 20/20]
#
# ✗ Meta early stopping: 20 evals sense millora
#
# Restored best meta-agent: val_sharpe=+0.3060
#
# ============================================================
# Meta-entrenament completat: 775.4 min
#   Total meta-iters: 105
#   Total tasks processades: 1323
#   Best val sharpe: +0.3060
#   Emissions meta: 253.70 g CO2eq
# ============================================================
#
# Meta-checkpoint desat: checkpoints_dense\ppo_reptile_meta_new_adaptative.pt
#
# Millor val: Sharpe=+0.3060  Ret=+0.47%  iter 5

# %%
# =============================================================================
# CEL·LA 10 — ANÀLISI INNER DIAGNOSTICS
# =============================================================================

if inner_diagnostics:
    print(f'\nInner Loop Diagnostics ({len(inner_diagnostics)} tasques processades)\n')
    print('='*80)
    
    # Estadístiques de convergència
    converged = [d for d in inner_diagnostics if d['converged']]
    reasons = {}
    for d in inner_diagnostics:
        r = d['reason']
        reasons[r] = reasons.get(r, 0) + 1
    
    print(f'Tasques convergides: {len(converged)}/{len(inner_diagnostics)} '
          f'({len(converged)/len(inner_diagnostics)*100:.1f}%)')
    print(f'\nRaons de finalització:')
    for reason, count in sorted(reasons.items(), key=lambda x: -x[1]):
        print(f'  {reason:30s}: {count:4d} ({count/len(inner_diagnostics)*100:5.1f}%)')
    
    # Estadístiques de steps
    steps = [d['steps'] for d in converged]
    if steps:
        print(f'\nSteps per tasca convergida:')
        print(f'  Mean: {np.mean(steps):,.0f}')
        print(f'  Median: {np.median(steps):,.0f}')
        print(f'  Min: {np.min(steps):,.0f}')
        print(f'  Max: {np.max(steps):,.0f}')
    
    # Sharpe final
    sharpes = [d['final_sharpe'] for d in converged]
    if sharpes:
        print(f'\nSharpe final (tasques convergides):')
        print(f'  Mean: {np.mean(sharpes):+.4f}')
        print(f'  Median: {np.median(sharpes):+.4f}')
        print(f'  Min: {np.min(sharpes):+.4f}')
        print(f'  Max: {np.max(sharpes):+.4f}')
    
    print('='*80)
else:
    print('No inner diagnostics disponibles')
# Out:
# Inner Loop Diagnostics (1323 tasques processades)
#
# ================================================================================
# Tasques convergides: 1323/1323 (100.0%)
#
# Raons de finalització:
#   gradient_explosion            :  881 ( 66.6%)
#   target_sharpe_reached         :  442 ( 33.4%)
#
# Steps per tasca convergida:
#   Mean: 8,192
#   Median: 8,192
#   Min: 8,192
#   Max: 8,192
#
# Sharpe final (tasques convergides):
#   Mean: +271961753.4899
#   Median: +0.0000
#   Min: -3350395054.5009
#   Max: +18944573574.6480
# ================================================================================

# %%
# =============================================================================
# CEL·LA 11 — META-TRAINING CURVES
# =============================================================================

if meta_history:
    fig, axes = plt.subplots(2, 2, figsize=(16, 10))
    
    iters = [h['meta_iter'] for h in meta_history]
    ret_v = [h['val_return'] for h in meta_history]
    sh_v  = [h['val_sharpe'] for h in meta_history]
    n_adapted = [h['n_adapted'] for h in meta_history]
    
    # Val Return
    axes[0, 0].plot(iters, ret_v, 'o-', color='#1f77b4', lw=2)
    axes[0, 0].axhline(0, color='gray', ls='--', lw=0.8)
    axes[0, 0].set_title('Reptile Adaptatiu — Retorn mig (val)')
    axes[0, 0].set_xlabel('Meta-iteració')
    axes[0, 0].set_ylabel('Return (%)')
    axes[0, 0].grid(alpha=0.3)
    
    # Val Sharpe
    axes[0, 1].plot(iters, sh_v, 'o-', color='#2ca02c', lw=2)
    axes[0, 1].axhline(0, color='gray', ls='--', lw=0.8)
    if meta_criteria.target_val_sharpe is not None:
        axes[0, 1].axhline(meta_criteria.target_val_sharpe, color='red', ls='--', lw=1.0, alpha=0.5, label=f'Target ({meta_criteria.target_val_sharpe})')
    axes[0, 1].set_title('Reptile Adaptatiu — Sharpe (val)')
    axes[0, 1].set_xlabel('Meta-iteració')
    axes[0, 1].set_ylabel('Sharpe')
    axes[0, 1].legend()
    axes[0, 1].grid(alpha=0.3)
    
    # N tasques adaptades per batch
    axes[1, 0].plot(iters, n_adapted, 'o-', color='#ff7f0e', lw=2)
    axes[1, 0].axhline(outer_trigger.batch_size, color='red', ls='--', lw=1.0, alpha=0.5, label=f'Target batch ({outer_trigger.batch_size})')
    axes[1, 0].set_title('Tasques convergides per outer update')
    axes[1, 0].set_xlabel('Meta-iteració')
    axes[1, 0].set_ylabel('N tasques')
    axes[1, 0].legend()
    axes[1, 0].grid(alpha=0.3)
    
    # Millora acumulada
    if len(sh_v) > 0:
        improvement = [s - sh_v[0] for s in sh_v]
        axes[1, 1].plot(iters, improvement, 'o-', color='#d62728', lw=2)
        axes[1, 1].axhline(0, color='gray', ls='--', lw=0.8)
        axes[1, 1].set_title('Millora Sharpe des inici')
        axes[1, 1].set_xlabel('Meta-iteració')
        axes[1, 1].set_ylabel('Δ Sharpe')
        axes[1, 1].grid(alpha=0.3)
    
    plt.suptitle('NB06d — PPO Reptile Adaptatiu Meta-training', fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.savefig(RESULTS / 'meta_training_curves.png', dpi=120, bbox_inches='tight')
    plt.show()
else:
    print('Sense historial de meta-entrenament')

# %% [markdown]
# ## Continua amb avaluació (rolling-window, etc.)
#
# A partir d'aquí pots copiar les cel·les d'avaluació del notebook original (CEL·LA 12-18):
# - `ppo_walk_forward`
# - `ppo_rolling_meta_eval` (amb fast-adaptation)
# - Equity curves
# - Action distribution
# - Comparative table
#
# Les funcions d'avaluació són idèntiques, només canvia el `meta_policy` que és el resultat del sistema adaptatiu.
