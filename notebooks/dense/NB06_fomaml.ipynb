# %% [markdown]
# # NB06d — FOMAML Meta-Learning ADAPTATIU sobre PPO Agent (Dense Reward)
#
# **Objectiu**: Entrena un agent PPO amb **FOMAML meta-learning adaptatiu** que:
# - **Inner loops dinàmics**: Cada tasca s'entrena fins que **convergeix** (mètrica ho detecta)
# - **Outer updates automàtics**: Quan s'acumulen N tasques O passa X temps
# - **Early stopping global**: Para quan el meta-agent **convergeix** sobre val
#
# ## Diferències vs. versió clàssica
#
# | Aspecte | Clàssic | Adaptatiu |
# |---------|---------|----------|
# | Inner steps | **Fix** (10k steps) | **Dinàmic** (fins convergir, 5k-30k) |
# | Batch size | **Fix** (10 tasques) | **Dinàmic** (acumula fins 5 o timeout) |
# | Meta iters | **Fix** (15k iters) | **Dinàmic** (para quan val sharpe convergeix) |
# | Filtratge | **Cap** | **Automàtic** (només tasques convergides) |
# | Budget | **1.5B steps** (!!) | **~10-50M steps** (eficient) |
#
# ## Sistema adaptatiu
#
# ```
# ┌─ META-ENTRENAMENT (loop principal) ───────────────────┐
# │                                                       │
# │  ┌─ INNER LOOP BATCH ──────────────────────────┐    │
# │  │  → Tasca 1: entrena fins convergir (Sharpe) │    │
# │  │  → Tasca 2: entrena fins convergir          │    │
# │  │  → Tasca 3: entrena fins convergir          │    │
# │  │  → ... (fins N tasques o timeout)           │    │
# │  └──────────────────────────────────────────────┘    │
# │              ↓                                        │
# │  ┌─ OUTER UPDATE (FOMAML) ───────────────────┐     │
# │  │  θ ← θ + ε·mean(φᵢ - θ)                    │     │
# │  └──────────────────────────────────────────────┘    │
# │              ↓                                        │
# │  ┌─ AVALUACIÓ META (periòdica) ───────────────┐     │
# │  │  Val Sharpe → early stopping?              │     │
# │  └──────────────────────────────────────────────┘    │
# │              ↓                                        │
# │         Convergit? → PARA                             │
# │         NO → REPEAT                                   │
# └───────────────────────────────────────────────────────┘
# ```

# %%
# =============================================================================
# CEL·LA 1 — IMPORTS
# =============================================================================

import copy
import json
import os as _os
import random
import sys
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import polars as pl
import torch
from codecarbon import EmissionsTracker
from tqdm.auto import tqdm

from src.data.manager import DataManager
from src.rl.agents.actor_critic_policy import ActorCriticPolicy
from src.rl.envs.crypto_market_env import (
    CryptoMarketEnv, INITIAL_BALANCE, MAX_EPISODE_STEPS,
    W_PNL, steps_per_4h_for, REALIZE_BONUS_SCALE,
)
from src.rl.metrics import compute_sharpe, compute_max_drawdown

# Import sistema adaptatiu
# sys.path.insert(0, str(Path.cwd()))
from src.rl.meta_learning import (
    AdaptiveFOMAML,
    InnerConvergenceCriteria,
    OuterUpdateTrigger,
    MetaConvergenceCriteria,
)

warnings.filterwarnings('ignore')
print('Imports OK')
# Out:
# Imports OK

# %%
# =============================================================================
# CEL·LA 2 — CONFIGURACIÓ: SEED, DEVICE, PATHS
# =============================================================================

# Reproducibilitat
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {DEVICE}')

# CWD
_cwd = Path.cwd()
if not (_cwd / 'data' / 'processed').exists():
    _root = _cwd.parents[1]
    if (_root / 'data' / 'processed').exists():
        _os.chdir(_root)
        print(f'CWD -> {Path.cwd()}')

# ── SELECTOR: BASE AGENT (MODIFICAR AQUÍ) ────────────────────────────────────
USE_PRETRAINED = False  # True = _adj (ajusta checkpoint), False = _new (fresh init)

# Agents disponibles per meta-learning
AVAILABLE_AGENTS = {
    'ppo_pytorch_dense_final': 'checkpoints_dense/ppo_pytorch_dense_final.pt',
    'ppo_pytorch_sparse_final': 'checkpoints_sparse/ppo_pytorch_sparse_final.pt',
}

BASE_AGENT = 'ppo_pytorch_dense_final'  # ← CANVIA AIXÒ per seleccionar checkpoint

if BASE_AGENT not in AVAILABLE_AGENTS:
    raise ValueError(f"BASE_AGENT desconegut: '{BASE_AGENT}'")

# ──────────────────────────────────────────────────────────────────────────────

# Paths
BEST_PARAMS_PATH = Path('checkpoints_dense/ppo_best_params.json')
RESULTS  = Path('results_dense') / '06d_ppo_fomaml_adaptive_new'
RESULTS.mkdir(parents=True, exist_ok=True)
CODECARBON_DIR = RESULTS / 'codecarbon'
CODECARBON_DIR.mkdir(parents=True, exist_ok=True)

# Variant naming: _adj si pre-trained, _new si fresh init
variant = '_adj' if USE_PRETRAINED else '_new'
META_CKPT = Path(f'checkpoints_dense/ppo_fomaml_meta{variant}_adaptative.pt')

# Dades
TIMEFRAME = '60m'
STEPS_PER_WEEK = 7 * 24  # 168 passos/setmana a 60m

print(f'Selector: USE_PRETRAINED={USE_PRETRAINED}, BASE_AGENT={BASE_AGENT}')
print(f'Variant: {variant}')
print(f'Meta checkpoint: {META_CKPT.name}')
print(f'Paths OK')
# Out:
# Device: cuda
# Selector: USE_PRETRAINED=False, BASE_AGENT=ppo_pytorch_dense_final
# Variant: _new
# Meta checkpoint: ppo_fomaml_meta_new_adaptative.pt
# Paths OK

# %%
# =============================================================================
# CEL·LA 3 — CRITERIS DE CONVERGÈNCIA (sistema adaptatiu)
# =============================================================================

# ── Inner Loop Convergence ───────────────────────────────────────────────────
inner_criteria = InnerConvergenceCriteria(
    min_steps=5_000,                    # Mínim d'steps abans d'avaluar
    max_steps=30_000,                   # Màxim (timeout per tasca)
    eval_every=2_000,                   # Avalua convergència cada 2k steps
    eval_episodes=5,                    # Episodis per avaluar sharpe
    
    # Convergència per performance
    target_sharpe=0.8,                  # Si sharpe >= 0.8 → convergit
    min_sharpe_improvement=0.3,         # Millora mínima des d'inici
    plateau_threshold=0.05,             # Millora <5% → plateau
    plateau_patience=3,                 # 3 evals sense millora → convergit
    
    # Convergència per gradients
    min_grad_norm=0.01,                 # Gradient massa petit → convergit
    max_grad_norm=10.0,                 # Gradient massa gran → divergència
    
    # Convergència per paràmetres
    max_param_distance=15.0,            # ||φ - θ|| massa gran → overfitting
)

# ── Outer Update Trigger ─────────────────────────────────────────────────────
outer_trigger = OuterUpdateTrigger(
    batch_size=5,                       # 5 tasques convergides → outer update
    max_time_seconds=300.0,             # O cada 5 min → outer update
    min_tasks=3,                        # Mínim 3 tasques per update vàlid
)

# ── Meta Convergence (ADAPTATIU segons _new vs _adj) ─────────────────────────
if USE_PRETRAINED:
    # MODE _adj: Model pre-entrenat busca meta-optimalitat
    # → NO target de performance (pot degradar temporalment)
    # → Només plateau detection amb més paciència
    meta_criteria = MetaConvergenceCriteria(
        max_meta_iters=500,
        eval_every=5,
        eval_episodes=25,
        
        target_val_sharpe=None,         # ← NO target absolut (accepta degradació)
        plateau_threshold=0.05,         # ← Més sensible a plateau (5%)
        plateau_patience=30,            # ← Més paciència (30 evals)
        min_val_sharpe=-999.0,          # ← No penalitza degradació
    )
    print('Meta criteria MODE: _adj (sense targets de performance)')
else:
    # MODE _new: Fresh init busca performance alta
    # → Target de performance absolut
    # → Menys paciència, vol arribar a sharpe alt
    meta_criteria = MetaConvergenceCriteria(
        max_meta_iters=500,
        eval_every=5,
        eval_episodes=25,
        
        target_val_sharpe=30.21,         # ← Target absolut (0.75 x Sharpe entrenament estàndard)
        plateau_threshold=0.1,          # ← Menys sensible (10%)
        plateau_patience=20,            # ← Menys paciència (20 evals)
        min_val_sharpe=0.5,             # ← Mínim acceptable (0.5)
    )
    print('Meta criteria MODE: _new (amb targets de performance)')

# ── FOMAML Hyperparameters ───────────────────────────────────────────────────
META_LR = 1e-4                          # Learning rate per outer update
SUPPORT_RATIO = 0.7                     # 70% support, 30% query
TASK_WEEKS = 12                         # Durada de cada tasca (12 setmanes)
TASK_STEPS = TASK_WEEKS * STEPS_PER_WEEK

# ── Adaptation (rolling-window test) ─────────────────────────────────────────
SUPPORT_WEEKS = 6
ADAPT_STEPS = 15_000
N_EVAL_WEEKS = 1

print('\nCriteris de convergència definits:')
print(f'  Inner: {inner_criteria.min_steps:,}-{inner_criteria.max_steps:,} steps, '
      f'target_sharpe={inner_criteria.target_sharpe}')
print(f'  Outer: batch={outer_trigger.batch_size}, timeout={outer_trigger.max_time_seconds}s')
print(f'  Meta:  max_iters={meta_criteria.max_meta_iters}, '
      f'target_val_sharpe={meta_criteria.target_val_sharpe}, '
      f'plateau_patience={meta_criteria.plateau_patience}')
print(f'  FOMAML: meta_lr={META_LR:.0e}, support_ratio={SUPPORT_RATIO}, '
      f'task_weeks={TASK_WEEKS} ({TASK_STEPS:,} files)')
# Out:
# Meta criteria MODE: _new (amb targets de performance)
#
# Criteris de convergència definits:
#   Inner: 5,000-30,000 steps, target_sharpe=0.8
#   Outer: batch=5, timeout=300.0s
#   Meta:  max_iters=500, target_val_sharpe=30.21, plateau_patience=20
#   FOMAML: meta_lr=1e-04, support_ratio=0.7, task_weeks=12 (2,016 files)

# %%
# =============================================================================
# CEL·LA 4 — CÀRREGA DE DADES
# =============================================================================

dm = DataManager(interval=TIMEFRAME, project_root=Path('.'))
FEATURE_COLS = dm.features
N_FEATURES   = len(FEATURE_COLS)

df_train, df_val, df_test = dm.load_all()
df_meta = pl.concat([df_train, df_val])

print(f'Train: {len(df_train):>8,}  ({df_train["timestamp"].min()} → {df_train["timestamp"].max()})')
print(f'Val:   {len(df_val):>8,}  ({df_val["timestamp"].min()} → {df_val["timestamp"].max()})')
print(f'Test:  {len(df_test):>8,}  ({df_test["timestamp"].min()} → {df_test["timestamp"].max()})')
print(f'Meta:  {len(df_meta):>8,}')
print(f'\nTasks possibles (TASK_WEEKS={TASK_WEEKS}): '
      f'{max(0, len(df_meta) - TASK_STEPS):,} finestres')
# Out:
# Train:   43,763  (2018-01-01 00:00:00 → 2022-12-31 23:00:00)
# Val:      8,759  (2023-01-01 00:00:00 → 2023-12-31 23:00:00)
# Test:    17,500  (2024-01-01 00:00:00 → 2025-12-31 00:00:00)
# Meta:    52,522
#
# Tasks possibles (TASK_WEEKS=12): 50,506 finestres

# %%
# =============================================================================
# CEL·LA 5 — FACTORIA D'ENTORN + VERIFICACIÓ
# =============================================================================

def make_env(df: pl.DataFrame, **kwargs) -> CryptoMarketEnv:
    '''Factoria per crear l'entorn DENSE amb FEATURE_COLS.'''
    return CryptoMarketEnv(
        df=df,
        feature_cols=FEATURE_COLS,
        w_pnl=W_PNL,
        steps_per_4h=steps_per_4h_for(TIMEFRAME),
        realize_bonus_scale=REALIZE_BONUS_SCALE,
        **kwargs,
    )

_env = make_env(df_train)
_obs, _info = _env.reset(seed=SEED)
OBS_DIM   = _env.observation_space.shape[0]
N_ACTIONS = _env.action_space.n
del _env

print(f'make_env OK | OBS_DIM={OBS_DIM}  N_ACTIONS={N_ACTIONS}')
# Out:
# make_env OK | OBS_DIM=71  N_ACTIONS=4

# %%
# =============================================================================
# CEL·LA 6 — CARREGA PPO CONFIG + AGENT BASE (fresh init O pre-entrenat)
# =============================================================================

# ── Hiperparàmetres PPO (defaults) ───────────────────────────────────────────
DEFAULT_PPO_CFG = {
    'learning_rate': 3e-4,
    'n_steps': 2048,
    'batch_size': 256,
    'n_epochs': 5,
    'gamma': 0.99,
    'gae_lambda': 0.95,
    'clip_range': 0.20,
    'ent_coef': 0.01,
    'vf_coef': 0.5,
    'max_grad_norm': 0.5,
    'net_arch': [128, 64],
}

# ── Carrega best params si existeix ──────────────────────────────────────────
if BEST_PARAMS_PATH.exists():
    print(f'Carregant best params des de {BEST_PARAMS_PATH} ...')
    with open(BEST_PARAMS_PATH, encoding='utf-8') as f:
        _bp_data = json.load(f)
    _bp = _bp_data['best_params']
    
    ppo_config = {
        'learning_rate': float(_bp.get('learning_rate', DEFAULT_PPO_CFG['learning_rate'])),
        'n_steps': int(_bp.get('n_steps', DEFAULT_PPO_CFG['n_steps'])),
        'batch_size': int(_bp.get('batch_size', DEFAULT_PPO_CFG['batch_size'])),
        'n_epochs': int(_bp.get('n_epochs', DEFAULT_PPO_CFG['n_epochs'])),
        'gamma': float(_bp.get('gamma', DEFAULT_PPO_CFG['gamma'])),
        'gae_lambda': float(_bp.get('gae_lambda', DEFAULT_PPO_CFG['gae_lambda'])),
        'clip_range': float(_bp.get('clip_range', DEFAULT_PPO_CFG['clip_range'])),
        'ent_coef': float(_bp.get('ent_coef', DEFAULT_PPO_CFG['ent_coef'])),
        'vf_coef': float(_bp.get('vf_coef', DEFAULT_PPO_CFG['vf_coef'])),
        'max_grad_norm': float(DEFAULT_PPO_CFG['max_grad_norm']),
        'net_arch': DEFAULT_PPO_CFG['net_arch'],
    }
    print(f'  Best params carregats: lr={ppo_config["learning_rate"]:.2e}  '
          f'n_steps={ppo_config["n_steps"]}  batch={ppo_config["batch_size"]}  '
          f'epochs={ppo_config["n_epochs"]}')
    print(f'  trial={_bp_data["best_trial"]}  sharpe={_bp_data["final_sharpe"]:.2f}  '
          f'ret={_bp_data["final_return"]:.2f}%')
else:
    print(f'AVÍS: {BEST_PARAMS_PATH} no trobat → usar DEFAULT_PPO_CFG')
    ppo_config = DEFAULT_PPO_CFG

# ── Crea/Carrega agent base ──────────────────────────────────────────────────
PRETRAINED_CKPT = Path(AVAILABLE_AGENTS[BASE_AGENT]) if USE_PRETRAINED else None

if USE_PRETRAINED and PRETRAINED_CKPT and PRETRAINED_CKPT.exists():
    print(f'\nCarregant PRE-ENTRENAT: {PRETRAINED_CKPT}')
    base_policy = ActorCriticPolicy.load(str(PRETRAINED_CKPT), device=DEVICE)
    base_policy.train()
    n_params = base_policy.count_params()
    print(f'  Checkpoint carregat: {n_params:,} params')
else:
    if USE_PRETRAINED:
        print(f'\nAVÍS: Checkpoint {PRETRAINED_CKPT} no trobat → fresh init')
    else:
        print(f'\nCreant agent base (fresh init) ...')
    
    torch.manual_seed(SEED)
    base_policy = ActorCriticPolicy(
        OBS_DIM, N_ACTIONS, ppo_config['net_arch']
    ).to(DEVICE)
    base_policy.train()
    n_params = base_policy.count_params()
    print(f'  Base policy: {n_params:,} params')

print(f'PPO config: {ppo_config}')
# Out:
# Carregant best params des de checkpoints_dense\ppo_best_params.json ...
#   Best params carregats: lr=2.77e-04  n_steps=4096  batch=64  epochs=7
#   trial=TPE_trial009  sharpe=43.01  ret=256.58%
#
# Creant agent base (fresh init) ...
#   Base policy: 35,269 params
# PPO config: {'learning_rate': 0.0002772159821008165, 'n_steps': 4096, 'batch_size': 64, 'n_epochs': 7, 'gamma': 0.9967078871822386, 'gae_lambda': 0.9014929046035071, 'clip_range': 0.2024186116598562, 'ent_coef': 0.009854799703235616, 'vf_coef': 0.7338795928070874, 'max_grad_norm': 0.5, 'net_arch': [128, 64]}

# %%
# =============================================================================
# CEL·LA 7 — TASK SAMPLER
# =============================================================================

rng_meta = np.random.default_rng(SEED)

def sample_task() -> pl.DataFrame:
    '''Mostra una finestra aleatòria de TASK_STEPS files de df_meta.'''
    max_start = len(df_meta) - TASK_STEPS
    if max_start <= 0:
        return df_meta
    start = int(rng_meta.integers(0, max_start))
    return df_meta[start: start + TASK_STEPS]

# Test
_task = sample_task()
print(f'sample_task OK  → {len(_task)} files  (TASK_STEPS={TASK_STEPS})')
print(f'Tasks possibles: {max(0, len(df_meta) - TASK_STEPS):,}')
# Out:
# sample_task OK  → 2016 files  (TASK_STEPS=2016)
# Tasks possibles: 50,506

# %%
# =============================================================================
# CEL·LA 8 — CREA SISTEMA FOMAML ADAPTATIU
# =============================================================================

# n_steps del PPO base (4096) és massa gran per a finestres de tasca curtes
# (TASK_STEPS=2016 → support=1411 files < 4096*2=8192 → totes les tasques es descarten).
# Per meta-learning, l'inner loop fa pocs passos sobre una finestra curta;
# n_steps=512 és suficient per capturar gradients locals sense excedir el support.
meta_ppo_config = {**ppo_config, 'n_steps': 512}

fomaml = AdaptiveFOMAML(
    inner_criteria=inner_criteria,
    outer_trigger=outer_trigger,
    meta_criteria=meta_criteria,
    device=DEVICE,
    ppo_config=meta_ppo_config,
    meta_lr=META_LR,
    support_ratio=SUPPORT_RATIO,
    tensorboard_log=str(RESULTS / 'tensorboard'),
)

print('AdaptiveFOMAML system creat.')
print(f'  Inner: {inner_criteria.min_steps:,}-{inner_criteria.max_steps:,} steps')
print(f'  Outer: batch={outer_trigger.batch_size}')
print(f'  Meta:  max_iters={meta_criteria.max_meta_iters}')
print(f'  PPO n_steps (meta): {meta_ppo_config["n_steps"]} (base: {ppo_config["n_steps"]})')
print(f'  TensorBoard: {RESULTS / "tensorboard"}')
# Out:
# AdaptiveFOMAML system creat.
#   Inner: 5,000-30,000 steps
#   Outer: batch=5
#   Meta:  max_iters=500
#   PPO n_steps (meta): 512 (base: 4096)
#   TensorBoard: results_dense\06d_ppo_fomaml_adaptive_new\tensorboard

# %%
# =============================================================================
# CEL·LA 9 — RUN ADAPTIVE META-TRAINING
# =============================================================================

import time as _time

if META_CKPT.exists():
    print(f'Carregant meta-checkpoint des de {META_CKPT} ...')
    meta_policy = ActorCriticPolicy.load(META_CKPT, device=DEVICE)
    meta_policy.train()
    _d = torch.load(str(META_CKPT), map_location=DEVICE, weights_only=False)
    meta_history = _d.get('meta_history', [])
    inner_diagnostics = _d.get('inner_diagnostics', [])
    emissions_meta = _d.get('emissions_meta_g_co2', 0.0)
    train_time_s = _d.get('train_time_s', 0.0)
    total_tasks = _d.get('total_tasks_processed', 0)
    total_meta_iters = _d.get('total_meta_iters', 0)
    best_val_sharpe = _d.get('best_val_sharpe', -np.inf)
    print(f'  Meta-checkpoint carregat.')
    print(f'  Meta iters: {total_meta_iters}  Tasks: {total_tasks}  '
          f'Best val sharpe: {best_val_sharpe:+.4f}')
else:
    print(f'Iniciant FOMAML ADAPTATIU meta-entrenament ...')
    print(f'Sistema pararà automàticament quan convergeixin inner loops i meta-agent.\n')

    t0 = _time.time()
    tracker = EmissionsTracker(
        project_name='06d_ppo_fomaml_adaptive',
        output_dir=str(CODECARBON_DIR),
        log_level='error'
    )
    tracker.start()

    result = fomaml.meta_train(
        base_policy=copy.deepcopy(base_policy),
        task_sampler=sample_task,
        env_factory=make_env,
        val_df=df_val,
        verbose=True,
        checkpoint_path=META_CKPT,
        checkpoint_every=50,
    )

    emissions_meta = (tracker.stop() or 0.0) * 1000  # grams CO2
    train_time_s = _time.time() - t0

    meta_policy = result['meta_policy']
    meta_history = result['meta_history']
    inner_diagnostics = result['inner_diagnostics']
    total_tasks = result['total_tasks_processed']
    total_meta_iters = result['total_meta_iters']
    best_val_sharpe = result['best_val_sharpe']

    print(f'\n' + '='*60)
    print(f'Meta-entrenament completat: {train_time_s/60:.1f} min')
    print(f'  Total meta-iters: {total_meta_iters}')
    print(f'  Total tasks processades: {total_tasks}')
    print(f'  Best val sharpe: {best_val_sharpe:+.4f}')
    print(f'  Emissions meta: {emissions_meta:.2f} g CO2eq')
    print('='*60)

    # Desa checkpoint
    META_CKPT.parent.mkdir(parents=True, exist_ok=True)
    torch.save({
        'policy_state_dict': meta_policy.state_dict(),
        'hyperparams': ppo_config,
        'meta_history': meta_history,
        'inner_diagnostics': inner_diagnostics,
        'emissions_meta_g_co2': emissions_meta,
        'train_time_s': train_time_s,
        'total_tasks_processed': total_tasks,
        'total_meta_iters': total_meta_iters,
        'best_val_sharpe': best_val_sharpe,
        'inner_criteria': inner_criteria.__dict__,
        'outer_trigger': outer_trigger.__dict__,
        'meta_criteria': meta_criteria.__dict__,
    }, META_CKPT)
    print(f'\nMeta-checkpoint desat: {META_CKPT}')

if meta_history:
    best = max(meta_history, key=lambda h: h['val_sharpe'])
    print(f'\nMillor val: Sharpe={best["val_sharpe"]:+.4f}  '
          f'Ret={best["val_return"]:+.2f}%  iter {best["meta_iter"]}')
# Out:
# Iniciant FOMAML ADAPTATIU meta-entrenament ...
# Sistema pararà automàticament quan convergeixin inner loops i meta-agent.
#   Task 1: target_sharpe_reached (10,240 steps, sharpe=+374113299.34)
#   Task 2: performance_plateau (30,000 steps, sharpe=+0.00)
#   Task 3: target_sharpe_reached (6,144 steps, sharpe=+285753778.36)
#   Batch timeout: 3 tasks in 581.7s
#
# Meta-iter 1: Outer update (FOMAML) amb 3 tasques
#   Task 4: FAIL (max_steps_timeout)
#   Task 5: target_sharpe_reached (6,144 steps, sharpe=+1516790321.18)
#   Task 6: SKIP (gradient_explosion)
#   Task 7: SKIP (gradient_explosion)
#   Task 8: target_sharpe_reached (6,144 steps, sharpe=+2735990550.17)
#   Task 9: FAIL (max_steps_timeout)
#   Task 10: SKIP (gradient_explosion)
#   Task 11: SKIP (gradient_explosion)
#   Task 12: target_sharpe_reached (6,144 steps, sharpe=+3288860850.21)
#   Batch timeout: 3 tasks in 1230.2s
#
# Meta-iter 2: Outer update (FOMAML) amb 3 tasques
#   Task 13: SKIP (gradient_explosion)
#   Task 14: SKIP (gradient_explosion)
#   Task 15: SKIP (gradient_explosion)
#   Task 16: target_sharpe_reached (6,144 steps, sharpe=+3796106891.63)
#   Task 17: target_sharpe_reached (6,144 steps, sharpe=+4076989843.46)
#   Task 18: target_sharpe_reached (6,144 steps, sharpe=+1234122949.08)
#   Batch timeout: 3 tasks in 499.3s
#
# Meta-iter 3: Outer update (FOMAML) amb 3 tasques
#   Task 19: target_sharpe_reached (16,384 steps, sharpe=+644239812.23)
#   Task 20: SKIP (gradient_explosion)
#   Task 21: SKIP (gradient_explosion)
#   Task 22: target_sharpe_reached (14,336 steps, sharpe=+102190507.05)
#   Task 23: FAIL (max_steps_timeout)
#   Task 24: SKIP (gradient_explosion)
#   Task 25: target_sharpe_reached (6,144 steps, sharpe=+1513919876.75)
#   Batch timeout: 3 tasks in 1119.5s
#
# Meta-iter 4: Outer update (FOMAML) amb 3 tasques
#   Task 26: target_sharpe_reached (10,240 steps, sharpe=+480447478.64)
#   Task 27: target_sharpe_reached (6,144 steps, sharpe=+1279257243.17)
#   Task 28: SKIP (gradient_explosion)
#   Task 29: SKIP (gradient_explosion)
#   Task 30: target_sharpe_reached (16,384 steps, sharpe=+316733220.27)
#   Batch timeout: 3 tasks in 517.7s
#
# Meta-iter 5: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-21.0988 ret=-19.88% best=-21.0988 [✓ NEW BEST]
#
#   Task 31: target_sharpe_reached (6,144 steps, sharpe=+9235090794.28)
#   Task 32: target_sharpe_reached (6,144 steps, sharpe=+106002715.38)
#   Task 33: SKIP (gradient_explosion)
#   Task 34: SKIP (gradient_explosion)
#   Task 35: SKIP (gradient_explosion)
#   Task 36: target_sharpe_reached (14,336 steps, sharpe=+1176498162.92)
#   Batch timeout: 3 tasks in 548.8s
#
# Meta-iter 6: Outer update (FOMAML) amb 3 tasques
#   Task 37: target_sharpe_reached (8,192 steps, sharpe=+1648440090.57)
#   Task 38: SKIP (gradient_explosion)
#   Task 39: SKIP (gradient_explosion)
#   Task 40: SKIP (gradient_explosion)
#   Task 41: SKIP (gradient_explosion)
#   Task 42: SKIP (gradient_explosion)
#   Task 43: FAIL (max_steps_timeout)
#   Task 44: performance_plateau (16,384 steps, sharpe=-1800860634.40)
#   Task 45: target_sharpe_reached (6,144 steps, sharpe=+289100091.91)
#   Batch timeout: 3 tasks in 1059.6s
#
# Meta-iter 7: Outer update (FOMAML) amb 3 tasques
#   Task 46: SKIP (gradient_explosion)
#   Task 47: SKIP (gradient_explosion)
#   Task 48: target_sharpe_reached (6,144 steps, sharpe=+3340338186.22)
#   Task 49: FAIL (max_steps_timeout)
#   Task 50: SKIP (gradient_explosion)
#   Task 51: SKIP (gradient_explosion)
#   Task 52: SKIP (gradient_explosion)
#   Task 53: SKIP (gradient_explosion)
#   Task 54: target_sharpe_reached (6,144 steps, sharpe=+9549158204.79)
#   Task 55: target_sharpe_reached (6,144 steps, sharpe=+1322084928.61)
#   Batch timeout: 3 tasks in 1468.7s
#
# Meta-iter 8: Outer update (FOMAML) amb 3 tasques
#   Task 56: SKIP (gradient_explosion)
#   Task 57: SKIP (gradient_explosion)
#   Task 58: target_sharpe_reached (6,144 steps, sharpe=+4071068447.96)
#   Task 59: SKIP (gradient_explosion)
#   Task 60: SKIP (gradient_explosion)
#   Task 61: target_sharpe_reached (6,144 steps, sharpe=+4673555890.36)
#   Task 62: target_sharpe_reached (6,144 steps, sharpe=+2519598193.36)
#   Batch timeout: 3 tasks in 395.8s
#
# Meta-iter 9: Outer update (FOMAML) amb 3 tasques
#   Task 63: SKIP (gradient_explosion)
#   Task 64: SKIP (gradient_explosion)
#   Task 65: SKIP (gradient_explosion)
#   Task 66: SKIP (gradient_explosion)
#   Task 67: target_sharpe_reached (6,144 steps, sharpe=+2394955065.20)
#   Task 68: target_sharpe_reached (6,144 steps, sharpe=+1937692287.81)
#   Task 69: target_sharpe_reached (8,192 steps, sharpe=+3693157188.88)
#   Batch timeout: 3 tasks in 405.3s
#
# Meta-iter 10: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-19.0796 ret=-19.98% best=-19.0796 [✓ NEW BEST]
#
#   Task 70: SKIP (gradient_explosion)
#   Task 71: target_sharpe_reached (8,192 steps, sharpe=+3493927094.89)
#   Task 72: target_sharpe_reached (16,384 steps, sharpe=+1735242231.76)
#   Task 73: SKIP (gradient_explosion)
#   Task 74: target_sharpe_reached (12,288 steps, sharpe=+1318617766.81)
#   Batch timeout: 3 tasks in 663.8s
#
# Meta-iter 11: Outer update (FOMAML) amb 3 tasques
#   Task 75: target_sharpe_reached (14,336 steps, sharpe=+4668776682.91)
#   Task 76: target_sharpe_reached (6,144 steps, sharpe=+497560186.62)
#   Task 77: target_sharpe_reached (6,144 steps, sharpe=+2115415586.21)
#   Task 78: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 463.4s
#
# Meta-iter 12: Outer update (FOMAML) amb 3 tasques
#   Task 79: target_sharpe_reached (6,144 steps, sharpe=+3128508150.71)
#   Task 80: SKIP (gradient_explosion)
#   Task 81: target_sharpe_reached (18,432 steps, sharpe=+8538567.35)
#   Task 82: SKIP (gradient_explosion)
#   Task 83: target_sharpe_reached (14,336 steps, sharpe=+891426732.13)
#   Batch timeout: 3 tasks in 567.7s
#
# Meta-iter 13: Outer update (FOMAML) amb 3 tasques
#   Task 84: SKIP (gradient_explosion)
#   Task 85: SKIP (gradient_explosion)
#   Task 86: target_sharpe_reached (6,144 steps, sharpe=+1382224803.08)
#   Task 87: target_sharpe_reached (16,384 steps, sharpe=+1598027390.22)
#   Task 88: SKIP (gradient_explosion)
#   Task 89: SKIP (gradient_explosion)
#   Task 90: target_sharpe_reached (6,144 steps, sharpe=+474131259.37)
#   Batch timeout: 3 tasks in 494.1s
#
# Meta-iter 14: Outer update (FOMAML) amb 3 tasques
#   Task 91: target_sharpe_reached (6,144 steps, sharpe=+370518294.80)
#   Task 92: SKIP (gradient_explosion)
#   Task 93: target_sharpe_reached (6,144 steps, sharpe=+3192703446.30)
#   Task 94: target_sharpe_reached (8,192 steps, sharpe=+2160532861.97)
#   Task 95: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 307.2s
#
# Meta-iter 15: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-26.7704 ret=-19.90% best=-19.0796 [plateau 1/20]
#
#   Task 96: SKIP (gradient_explosion)
#   Task 97: target_sharpe_reached (6,144 steps, sharpe=+883180641.89)
#   Task 98: SKIP (gradient_explosion)
#   Task 99: SKIP (gradient_explosion)
#   Task 100: SKIP (gradient_explosion)
#   Task 101: target_sharpe_reached (18,432 steps, sharpe=+2737056532.94)
#   Task 102: SKIP (gradient_explosion)
#   Task 103: SKIP (gradient_explosion)
#   Task 104: SKIP (gradient_explosion)
#   Task 105: target_sharpe_reached (6,144 steps, sharpe=+1015256449.05)
#   Batch timeout: 3 tasks in 994.0s
#
# Meta-iter 16: Outer update (FOMAML) amb 3 tasques
#   Task 106: SKIP (gradient_explosion)
#   Task 107: target_sharpe_reached (12,288 steps, sharpe=+2116902368.07)
#   Task 108: target_sharpe_reached (6,144 steps, sharpe=+1205760791.60)
#   Task 109: SKIP (gradient_explosion)
#   Task 110: target_sharpe_reached (6,144 steps, sharpe=+2087620761.22)
#   Batch timeout: 3 tasks in 436.2s
#
# Meta-iter 17: Outer update (FOMAML) amb 3 tasques
#   Task 111: SKIP (gradient_explosion)
#   Task 112: SKIP (gradient_explosion)
#   Task 113: FAIL (max_steps_timeout)
#   Task 114: SKIP (gradient_explosion)
#   Task 115: target_sharpe_reached (6,144 steps, sharpe=+3888471759.82)
#   Task 116: SKIP (gradient_explosion)
#   Task 117: target_sharpe_reached (6,144 steps, sharpe=+3724480227.66)
#   Task 118: target_sharpe_reached (6,144 steps, sharpe=+2282785285.87)
#   Batch timeout: 3 tasks in 947.2s
#
# Meta-iter 18: Outer update (FOMAML) amb 3 tasques
#   Task 119: target_sharpe_reached (6,144 steps, sharpe=+780555702.15)
#   Task 120: target_sharpe_reached (8,192 steps, sharpe=+285753778.36)
#   Task 121: target_sharpe_reached (6,144 steps, sharpe=+3379507288.09)
#   Task 122: SKIP (gradient_explosion)
#   Task 123: target_sharpe_reached (6,144 steps, sharpe=+6260075481.94)
#   Batch timeout: 4 tasks in 334.0s
#
# Meta-iter 19: Outer update (FOMAML) amb 4 tasques
#   Task 124: target_sharpe_reached (6,144 steps, sharpe=+2881379395.30)
#   Task 125: target_sharpe_reached (6,144 steps, sharpe=+751380970.36)
#   Task 126: SKIP (gradient_explosion)
#   Task 127: target_sharpe_reached (6,144 steps, sharpe=+2173118984.34)
#   Task 128: SKIP (gradient_explosion)
#   Task 129: FAIL (max_steps_timeout)
#   Batch timeout: 3 tasks in 626.3s
#
# Meta-iter 20: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-19.7520 ret=-19.88% best=-19.0796 [plateau 2/20]
#
#   Task 130: target_sharpe_reached (6,144 steps, sharpe=+3238505108.25)
#   Task 131: SKIP (gradient_explosion)
#   Task 132: SKIP (gradient_explosion)
#   Task 133: SKIP (gradient_explosion)
#   Task 134: SKIP (gradient_explosion)
#   Task 135: performance_plateau (14,336 steps, sharpe=-437903084.16)
#   Task 136: SKIP (gradient_explosion)
#   Task 137: target_sharpe_reached (6,144 steps, sharpe=+190546661.14)
#   Batch timeout: 3 tasks in 611.7s
#
# Meta-iter 21: Outer update (FOMAML) amb 3 tasques
#   Task 138: target_sharpe_reached (6,144 steps, sharpe=+806927651.34)
#   Task 139: target_sharpe_reached (6,144 steps, sharpe=+95926620.24)
#   Task 140: target_sharpe_reached (30,000 steps, sharpe=+2315842834.03)
#   Batch timeout: 3 tasks in 508.3s
#
# Meta-iter 22: Outer update (FOMAML) amb 3 tasques
#   Task 141: target_sharpe_reached (6,144 steps, sharpe=+173065052.12)
#   Task 142: SKIP (gradient_explosion)
#   Task 143: SKIP (gradient_explosion)
#   Task 144: SKIP (gradient_explosion)
#   Task 145: target_sharpe_reached (8,192 steps, sharpe=+2616340880.18)
#   Task 146: SKIP (gradient_explosion)
#   Task 147: SKIP (gradient_explosion)
#   Task 148: target_sharpe_reached (16,384 steps, sharpe=+1041430480.21)
#   Batch timeout: 3 tasks in 591.8s
#
# Meta-iter 23: Outer update (FOMAML) amb 3 tasques
#   Task 149: target_sharpe_reached (8,192 steps, sharpe=+3011539451.66)
#   Task 150: target_sharpe_reached (12,288 steps, sharpe=+2292440264.90)
#   Task 151: target_sharpe_reached (6,144 steps, sharpe=+1992288773.92)
#   Task 152: performance_plateau (16,384 steps, sharpe=-2077385796.82)
#   Batch timeout: 4 tasks in 475.1s
#
# Meta-iter 24: Outer update (FOMAML) amb 4 tasques
#   Task 153: SKIP (gradient_explosion)
#   Task 154: target_sharpe_reached (28,160 steps, sharpe=+2061926915.52)
#   Task 155: SKIP (gradient_explosion)
#   Task 156: target_sharpe_reached (6,144 steps, sharpe=+2970541338.30)
#   Task 157: SKIP (gradient_explosion)
#   Task 158: SKIP (gradient_explosion)
#   Task 159: SKIP (gradient_explosion)
#   Task 160: SKIP (gradient_explosion)
#   Task 161: SKIP (gradient_explosion)
#   Task 162: SKIP (gradient_explosion)
#   Task 163: SKIP (gradient_explosion)
#   Task 164: target_sharpe_reached (6,144 steps, sharpe=+752731787.40)
#   Batch timeout: 3 tasks in 1115.1s
#
# Meta-iter 25: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-16.8814 ret=-19.98% best=-16.8814 [✓ NEW BEST]
#
#   Task 165: SKIP (gradient_explosion)
#   Task 166: target_sharpe_reached (6,144 steps, sharpe=+446544273.07)
#   Task 167: SKIP (gradient_explosion)
#   Task 168: target_sharpe_reached (8,192 steps, sharpe=+1222566727.75)
#   Task 169: SKIP (gradient_explosion)
#   Task 170: SKIP (gradient_explosion)
#   Task 171: SKIP (gradient_explosion)
#   Task 172: SKIP (gradient_explosion)
#   Task 173: SKIP (gradient_explosion)
#   Task 174: SKIP (gradient_explosion)
#   Task 175: SKIP (gradient_explosion)
#   Task 176: performance_plateau (22,016 steps, sharpe=-353239418.27)
#   Batch timeout: 3 tasks in 1153.4s
#
# Meta-iter 26: Outer update (FOMAML) amb 3 tasques
#   Task 177: SKIP (gradient_explosion)
#   Task 178: target_sharpe_reached (6,144 steps, sharpe=+61932357.47)
#   Task 179: SKIP (gradient_explosion)
#   Task 180: SKIP (gradient_explosion)
#   Task 181: target_sharpe_reached (6,144 steps, sharpe=+1377532623.14)
#   Task 182: target_sharpe_reached (10,240 steps, sharpe=+9320253291.19)
#   Batch timeout: 3 tasks in 381.4s
#
# Meta-iter 27: Outer update (FOMAML) amb 3 tasques
#   Task 183: SKIP (gradient_explosion)
#   Task 184: SKIP (gradient_explosion)
#   Task 185: target_sharpe_reached (8,192 steps, sharpe=+362450173.51)
#   Task 186: SKIP (gradient_explosion)
#   Task 187: SKIP (gradient_explosion)
#   Task 188: target_sharpe_reached (6,144 steps, sharpe=+3021303926.89)
#   Task 189: target_sharpe_reached (14,336 steps, sharpe=+2165837807.13)
#   Batch timeout: 3 tasks in 587.0s
#
# Meta-iter 28: Outer update (FOMAML) amb 3 tasques
#   Task 190: target_sharpe_reached (6,144 steps, sharpe=+752985987.17)
#   Task 191: SKIP (gradient_explosion)
#   Task 192: SKIP (gradient_explosion)
#   Task 193: SKIP (gradient_explosion)
#   Task 194: target_sharpe_reached (8,192 steps, sharpe=+545801472.07)
#   Task 195: SKIP (gradient_explosion)
#   Task 196: target_sharpe_reached (16,384 steps, sharpe=+675857591.58)
#   Batch timeout: 3 tasks in 782.6s
#
# Meta-iter 29: Outer update (FOMAML) amb 3 tasques
#   Task 197: FAIL (max_steps_timeout)
#   Task 198: SKIP (gradient_explosion)
#   Task 199: FAIL (max_steps_timeout)
#   Task 200: target_sharpe_reached (6,144 steps, sharpe=+4373424775.58)
#   Task 201: target_sharpe_reached (16,384 steps, sharpe=+69254759.13)
#   Task 202: SKIP (gradient_explosion)
#   Task 203: SKIP (gradient_explosion)
#   Task 204: SKIP (gradient_explosion)
#   Task 205: SKIP (gradient_explosion)
#   Task 206: target_sharpe_reached (10,240 steps, sharpe=+2390057668.80)
#   Batch timeout: 3 tasks in 1666.0s
#
# Meta-iter 30: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-50.1231 ret=-20.13% best=-16.8814 [plateau 1/20]
#
#   Task 207: target_sharpe_reached (6,144 steps, sharpe=+169909200.46)
#   Task 208: performance_plateau (20,480 steps, sharpe=-535480550.96)
#   Task 209: SKIP (gradient_explosion)
#   Task 210: SKIP (gradient_explosion)
#   Task 211: SKIP (gradient_explosion)
#   Task 212: SKIP (gradient_explosion)
#   Task 213: FAIL (max_steps_timeout)
#   Task 214: target_sharpe_reached (6,144 steps, sharpe=+2806602295.32)
#   Batch timeout: 3 tasks in 972.1s
#
# Meta-iter 31: Outer update (FOMAML) amb 3 tasques
#   Task 215: target_sharpe_reached (6,144 steps, sharpe=+3710804660.37)
#   Task 216: SKIP (gradient_explosion)
#   Task 217: SKIP (gradient_explosion)
#   Task 218: SKIP (gradient_explosion)
#   Task 219: SKIP (gradient_explosion)
#   Task 220: target_sharpe_reached (6,144 steps, sharpe=+3726359088.58)
#   Task 221: SKIP (gradient_explosion)
#   Task 222: SKIP (gradient_explosion)
#   Task 223: SKIP (gradient_explosion)
#   Task 224: SKIP (gradient_explosion)
#   Task 225: SKIP (gradient_explosion)
#   Task 226: SKIP (gradient_explosion)
#   Task 227: target_sharpe_reached (6,144 steps, sharpe=+3618465225.69)
#   Batch timeout: 3 tasks in 1136.9s
#
# Meta-iter 32: Outer update (FOMAML) amb 3 tasques
#   Task 228: SKIP (gradient_explosion)
#   Task 229: FAIL (max_steps_timeout)
#   Task 230: SKIP (gradient_explosion)
#   Task 231: target_sharpe_reached (10,240 steps, sharpe=+381250325.96)
#   Task 232: SKIP (gradient_explosion)
#   Task 233: target_sharpe_reached (6,144 steps, sharpe=+1759514473.92)
#   Task 234: target_sharpe_reached (6,144 steps, sharpe=+11302831392.40)
#   Batch timeout: 3 tasks in 1073.7s
#
# Meta-iter 33: Outer update (FOMAML) amb 3 tasques
#   Task 235: SKIP (gradient_explosion)
#   Task 236: SKIP (gradient_explosion)
#   Task 237: target_sharpe_reached (8,192 steps, sharpe=+58856070.85)
#   Task 238: SKIP (gradient_explosion)
#   Task 239: SKIP (gradient_explosion)
#   Task 240: target_sharpe_reached (14,336 steps, sharpe=+3513443394.82)
#   Task 241: target_sharpe_reached (6,144 steps, sharpe=+3153707399.31)
#   Batch timeout: 3 tasks in 701.1s
#
# Meta-iter 34: Outer update (FOMAML) amb 3 tasques
#   Task 242: SKIP (gradient_explosion)
#   Task 243: target_sharpe_reached (6,144 steps, sharpe=+837976054.34)
#   Task 244: SKIP (gradient_explosion)
#   Task 245: target_sharpe_reached (6,144 steps, sharpe=+1331730895.67)
#   Task 246: target_sharpe_reached (12,288 steps, sharpe=+2955652047.89)
#   Batch timeout: 3 tasks in 390.8s
#
# Meta-iter 35: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-23.2296 ret=-19.95% best=-16.8814 [plateau 2/20]
#
#   Task 247: SKIP (gradient_explosion)
#   Task 248: SKIP (gradient_explosion)
#   Task 249: SKIP (gradient_explosion)
#   Task 250: SKIP (gradient_explosion)
#   Task 251: target_sharpe_reached (6,144 steps, sharpe=+10469716323.78)
#   Task 252: target_sharpe_reached (6,144 steps, sharpe=+3203373654.88)
#   Task 253: target_sharpe_reached (10,240 steps, sharpe=+151391443.05)
#   Batch timeout: 3 tasks in 847.8s
#
# Meta-iter 36: Outer update (FOMAML) amb 3 tasques
#   Task 254: target_sharpe_reached (6,144 steps, sharpe=+1496796321.42)
#   Task 255: target_sharpe_reached (24,064 steps, sharpe=+3876427740.92)
#   Task 256: SKIP (gradient_explosion)
#   Task 257: performance_plateau (16,384 steps, sharpe=+0.00)
#   Batch timeout: 3 tasks in 838.5s
#
# Meta-iter 37: Outer update (FOMAML) amb 3 tasques
#   Task 258: SKIP (gradient_explosion)
#   Task 259: SKIP (gradient_explosion)
#   Task 260: target_sharpe_reached (8,192 steps, sharpe=+1749379985.68)
#   Task 261: SKIP (gradient_explosion)
#   Task 262: FAIL (max_steps_timeout)
#   Task 263: SKIP (gradient_explosion)
#   Task 264: SKIP (gradient_explosion)
#   Task 265: target_sharpe_reached (6,144 steps, sharpe=+3968200266.60)
#   Task 266: performance_plateau (30,000 steps, sharpe=-1519016182.64)
#   Batch timeout: 3 tasks in 1603.5s
#
# Meta-iter 38: Outer update (FOMAML) amb 3 tasques
#   Task 267: SKIP (gradient_explosion)
#   Task 268: SKIP (gradient_explosion)
#   Task 269: SKIP (gradient_explosion)
#   Task 270: FAIL (max_steps_timeout)
#   Task 271: SKIP (gradient_explosion)
#   Task 272: target_sharpe_reached (6,144 steps, sharpe=+2636679083.81)
#   Task 273: target_sharpe_reached (8,192 steps, sharpe=+1392949992.81)
#   Task 274: SKIP (gradient_explosion)
#   Task 275: target_sharpe_reached (6,144 steps, sharpe=+4891294863.94)
#   Batch timeout: 3 tasks in 1369.1s
#
# Meta-iter 39: Outer update (FOMAML) amb 3 tasques
#   Task 276: SKIP (gradient_explosion)
#   Task 277: SKIP (gradient_explosion)
#   Task 278: target_sharpe_reached (12,288 steps, sharpe=+1506889677.03)
#   Task 279: target_sharpe_reached (6,144 steps, sharpe=+359412581.32)
#   Task 280: target_sharpe_reached (6,144 steps, sharpe=+2686236280.03)
#   Batch timeout: 3 tasks in 476.8s
#
# Meta-iter 40: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-24.8333 ret=-19.92% best=-16.8814 [plateau 3/20]
#
#   Task 281: target_sharpe_reached (6,144 steps, sharpe=+7204996007.55)
#   Task 282: target_sharpe_reached (6,144 steps, sharpe=+2774899230.03)
#   Task 283: target_sharpe_reached (8,192 steps, sharpe=+7760467024.16)
#   Task 284: target_sharpe_reached (6,144 steps, sharpe=+261419714.37)
#   Batch timeout: 4 tasks in 337.8s
#
# Meta-iter 41: Outer update (FOMAML) amb 4 tasques
#   Task 285: SKIP (gradient_explosion)
#   Task 286: SKIP (gradient_explosion)
#   Task 287: target_sharpe_reached (8,192 steps, sharpe=+2941660407.80)
#   Task 288: SKIP (gradient_explosion)
#   Task 289: target_sharpe_reached (6,144 steps, sharpe=+961810024.33)
#   Task 290: SKIP (gradient_explosion)
#   Task 291: SKIP (gradient_explosion)
#   Task 292: target_sharpe_reached (6,144 steps, sharpe=+825573517.04)
#   Batch timeout: 3 tasks in 901.3s
#
# Meta-iter 42: Outer update (FOMAML) amb 3 tasques
#   Task 293: target_sharpe_reached (24,064 steps, sharpe=+1665985039.37)
#   Task 294: SKIP (gradient_explosion)
#   Task 295: SKIP (gradient_explosion)
#   Task 296: target_sharpe_reached (6,144 steps, sharpe=+2543301312.57)
#   Task 297: target_sharpe_reached (16,384 steps, sharpe=+63145574.61)
#   Batch timeout: 3 tasks in 806.6s
#
# Meta-iter 43: Outer update (FOMAML) amb 3 tasques
#   Task 298: target_sharpe_reached (28,160 steps, sharpe=+1587887711.55)
#   Task 299: target_sharpe_reached (6,144 steps, sharpe=+2118054494.42)
#   Task 300: SKIP (gradient_explosion)
#   Task 301: target_sharpe_reached (10,240 steps, sharpe=+910172189.27)
#   Batch timeout: 3 tasks in 707.5s
#
# Meta-iter 44: Outer update (FOMAML) amb 3 tasques
#   Task 302: SKIP (gradient_explosion)
#   Task 303: SKIP (gradient_explosion)
#   Task 304: SKIP (gradient_explosion)
#   Task 305: target_sharpe_reached (10,240 steps, sharpe=+3460722310.69)
#   Task 306: SKIP (gradient_explosion)
#   Task 307: SKIP (gradient_explosion)
#   Task 308: target_sharpe_reached (22,016 steps, sharpe=+1891793463.09)
#   Task 309: SKIP (gradient_explosion)
#   Task 310: target_sharpe_reached (8,192 steps, sharpe=+2104570201.63)
#   Batch timeout: 3 tasks in 1441.1s
#
# Meta-iter 45: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-20.1744 ret=-19.80% best=-16.8814 [plateau 4/20]
#
#   Task 311: SKIP (gradient_explosion)
#   Task 312: SKIP (gradient_explosion)
#   Task 313: SKIP (gradient_explosion)
#   Task 314: target_sharpe_reached (6,144 steps, sharpe=+404960592.43)
#   Task 315: target_sharpe_reached (6,144 steps, sharpe=+2229625021.42)
#   Task 316: SKIP (gradient_explosion)
#   Task 317: SKIP (gradient_explosion)
#   Task 318: SKIP (gradient_explosion)
#   Task 319: target_sharpe_reached (6,144 steps, sharpe=+2043787183.47)
#   Batch timeout: 3 tasks in 970.4s
#
# Meta-iter 46: Outer update (FOMAML) amb 3 tasques
#   Task 320: SKIP (gradient_explosion)
#   Task 321: FAIL (max_steps_timeout)
#   Task 322: target_sharpe_reached (6,144 steps, sharpe=+4177345183.32)
#   Task 323: target_sharpe_reached (14,336 steps, sharpe=+1146102339.68)
#   Task 324: performance_plateau (18,432 steps, sharpe=-1257671643.45)
#   Batch timeout: 3 tasks in 1328.4s
#
# Meta-iter 47: Outer update (FOMAML) amb 3 tasques
#   Task 325: target_sharpe_reached (6,144 steps, sharpe=+7484496797.99)
#   Task 326: SKIP (gradient_explosion)
#   Task 327: SKIP (gradient_explosion)
#   Task 328: SKIP (gradient_explosion)
#   Task 329: SKIP (gradient_explosion)
#   Task 330: target_sharpe_reached (6,144 steps, sharpe=+128974347.78)
#   Task 331: SKIP (gradient_explosion)
#   Task 332: SKIP (gradient_explosion)
#   Task 333: target_sharpe_reached (6,144 steps, sharpe=+142455292.22)
#   Batch timeout: 3 tasks in 1056.2s
#
# Meta-iter 48: Outer update (FOMAML) amb 3 tasques
#   Task 334: target_sharpe_reached (6,144 steps, sharpe=+588970027.86)
#   Task 335: SKIP (gradient_explosion)
#   Task 336: target_sharpe_reached (6,144 steps, sharpe=+585255072.64)
#   Task 337: target_sharpe_reached (6,144 steps, sharpe=+1619367472.53)
#   Batch timeout: 3 tasks in 333.5s
#
# Meta-iter 49: Outer update (FOMAML) amb 3 tasques
#   Task 338: target_sharpe_reached (14,336 steps, sharpe=+3761942679.24)
#   Task 339: target_sharpe_reached (6,144 steps, sharpe=+665986787.51)
#   Task 340: SKIP (gradient_explosion)
#   Task 341: SKIP (gradient_explosion)
#   Task 342: target_sharpe_reached (6,144 steps, sharpe=+538709392.20)
#   Batch timeout: 3 tasks in 536.7s
#
# Meta-iter 50: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-30.3561 ret=-19.91% best=-16.8814 [plateau 5/20]
#
#   [ckpt] Desat checkpoint @ iter 50 → ppo_fomaml_meta_new_adaptative.pt
#   Task 343: target_sharpe_reached (6,144 steps, sharpe=+3963714278.37)
#   Task 344: target_sharpe_reached (28,160 steps, sharpe=+2896525.97)
#   Task 345: SKIP (gradient_explosion)
#   Task 346: target_sharpe_reached (6,144 steps, sharpe=+2448278039.12)
#   Batch timeout: 3 tasks in 771.2s
#
# Meta-iter 51: Outer update (FOMAML) amb 3 tasques
#   Task 347: SKIP (gradient_explosion)
#   Task 348: FAIL (max_steps_timeout)
#   Task 349: target_sharpe_reached (6,144 steps, sharpe=+463821999.83)
#   Task 350: target_sharpe_reached (6,144 steps, sharpe=+3794346521.14)
#   Task 351: SKIP (gradient_explosion)
#   Task 352: SKIP (gradient_explosion)
#   Task 353: target_sharpe_reached (20,480 steps, sharpe=+377731471.88)
#   Batch timeout: 3 tasks in 1824.6s
#
# Meta-iter 52: Outer update (FOMAML) amb 3 tasques
#   Task 354: target_sharpe_reached (14,336 steps, sharpe=+131973477.59)
#   Task 355: target_sharpe_reached (6,144 steps, sharpe=+2940690068.82)
#   Task 356: SKIP (gradient_explosion)
#   Task 357: SKIP (gradient_explosion)
#   Task 358: target_sharpe_reached (6,144 steps, sharpe=+443571563.92)
#   Batch timeout: 3 tasks in 565.5s
#
# Meta-iter 53: Outer update (FOMAML) amb 3 tasques
#   Task 359: target_sharpe_reached (6,144 steps, sharpe=+4310502861.31)
#   Task 360: target_sharpe_reached (6,144 steps, sharpe=+1559176334.07)
#   Task 361: SKIP (gradient_explosion)
#   Task 362: SKIP (gradient_explosion)
#   Task 363: target_sharpe_reached (6,144 steps, sharpe=+1401986129.88)
#   Batch timeout: 3 tasks in 706.6s
#
# Meta-iter 54: Outer update (FOMAML) amb 3 tasques
#   Task 364: target_sharpe_reached (6,144 steps, sharpe=+900600452.62)
#   Task 365: target_sharpe_reached (6,144 steps, sharpe=+1600377659.14)
#   Task 366: target_sharpe_reached (6,144 steps, sharpe=+3597038572.84)
#   Task 367: target_sharpe_reached (8,192 steps, sharpe=+1925594391.12)
#   Batch timeout: 4 tasks in 353.5s
#
# Meta-iter 55: Outer update (FOMAML) amb 4 tasques
#   Val: sharpe=-13.5933 ret=-19.19% best=-13.5933 [✓ NEW BEST]
#
#   Task 368: SKIP (gradient_explosion)
#   Task 369: target_sharpe_reached (12,288 steps, sharpe=+653933003.92)
#   Task 370: SKIP (gradient_explosion)
#   Task 371: target_sharpe_reached (8,192 steps, sharpe=+1176393935.68)
#   Task 372: FAIL (max_steps_timeout)
#   Task 373: target_sharpe_reached (12,288 steps, sharpe=+2477630788.09)
#   Batch timeout: 3 tasks in 1212.4s
#
# Meta-iter 56: Outer update (FOMAML) amb 3 tasques
#   Task 374: SKIP (gradient_explosion)
#   Task 375: target_sharpe_reached (6,144 steps, sharpe=+915612517.73)
#   Task 376: target_sharpe_reached (6,144 steps, sharpe=+1383634491.85)
#   Task 377: target_sharpe_reached (10,240 steps, sharpe=+4416673355.74)
#   Batch timeout: 3 tasks in 419.2s
#
# Meta-iter 57: Outer update (FOMAML) amb 3 tasques
#   Task 378: SKIP (gradient_explosion)
#   Task 379: target_sharpe_reached (12,288 steps, sharpe=+1447911684.10)
#   Task 380: target_sharpe_reached (6,144 steps, sharpe=+2510750285.19)
#   Task 381: SKIP (gradient_explosion)
#   Task 382: FAIL (max_steps_timeout)
#   Task 383: FAIL (max_steps_timeout)
#   Task 384: target_sharpe_reached (6,144 steps, sharpe=+20359703.09)
#   Batch timeout: 3 tasks in 1440.0s
#
# Meta-iter 58: Outer update (FOMAML) amb 3 tasques
#   Task 385: SKIP (gradient_explosion)
#   Task 386: performance_plateau (26,112 steps, sharpe=-402554665.06)
#   Task 387: SKIP (gradient_explosion)
#   Task 388: SKIP (gradient_explosion)
#   Task 389: SKIP (gradient_explosion)
#   Task 390: target_sharpe_reached (12,288 steps, sharpe=+2530112408.70)
#   Task 391: performance_plateau (24,064 steps, sharpe=-1480210430.70)
#   Batch timeout: 3 tasks in 1512.8s
#
# Meta-iter 59: Outer update (FOMAML) amb 3 tasques
#   Task 392: target_sharpe_reached (8,192 steps, sharpe=+2536493474.63)
#   Task 393: SKIP (gradient_explosion)
#   Task 394: SKIP (gradient_explosion)
#   Task 395: FAIL (max_steps_timeout)
#   Task 396: SKIP (gradient_explosion)
#   Task 397: SKIP (gradient_explosion)
#   Task 398: target_sharpe_reached (6,144 steps, sharpe=+1379457807.50)
#   Task 399: SKIP (gradient_explosion)
#   Task 400: SKIP (gradient_explosion)
#   Task 401: SKIP (gradient_explosion)
#   Task 402: target_sharpe_reached (6,144 steps, sharpe=+1318283226.28)
#   Batch timeout: 3 tasks in 1506.9s
#
# Meta-iter 60: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-22.0353 ret=-19.86% best=-13.5933 [plateau 1/20]
#
#   Task 403: target_sharpe_reached (6,144 steps, sharpe=+166097990.08)
#   Task 404: target_sharpe_reached (6,144 steps, sharpe=+396866484.74)
#   Task 405: SKIP (gradient_explosion)
#   Task 406: FAIL (max_steps_timeout)
#   Task 407: SKIP (gradient_explosion)
#   Task 408: SKIP (gradient_explosion)
#   Task 409: SKIP (gradient_explosion)
#   Task 410: SKIP (gradient_explosion)
#   Task 411: SKIP (gradient_explosion)
#   Task 412: SKIP (gradient_explosion)
#   Task 413: target_sharpe_reached (6,144 steps, sharpe=+3705099860.75)
#   Batch timeout: 3 tasks in 1420.6s
#
# Meta-iter 61: Outer update (FOMAML) amb 3 tasques
#   Task 414: target_sharpe_reached (6,144 steps, sharpe=+644577701.78)
#   Task 415: target_sharpe_reached (6,144 steps, sharpe=+3282866175.67)
#   Task 416: SKIP (gradient_explosion)
#   Task 417: SKIP (gradient_explosion)
#   Task 418: SKIP (gradient_explosion)
#   Task 419: SKIP (gradient_explosion)
#   Task 420: SKIP (gradient_explosion)
#   Task 421: SKIP (gradient_explosion)
#   Task 422: SKIP (gradient_explosion)
#   Task 423: target_sharpe_reached (6,144 steps, sharpe=+18657312.03)
#   Batch timeout: 3 tasks in 782.9s
#
# Meta-iter 62: Outer update (FOMAML) amb 3 tasques
#   Task 424: target_sharpe_reached (8,192 steps, sharpe=+68415498.64)
#   Task 425: target_sharpe_reached (8,192 steps, sharpe=+865914240.18)
#   Task 426: target_sharpe_reached (12,288 steps, sharpe=+2479374809.43)
#   Batch timeout: 3 tasks in 423.0s
#
# Meta-iter 63: Outer update (FOMAML) amb 3 tasques
#   Task 427: target_sharpe_reached (8,192 steps, sharpe=+516767227.30)
#   Task 428: SKIP (gradient_explosion)
#   Task 429: SKIP (gradient_explosion)
#   Task 430: SKIP (gradient_explosion)
#   Task 431: target_sharpe_reached (8,192 steps, sharpe=+2283738701.63)
#   Task 432: target_sharpe_reached (8,192 steps, sharpe=+222581145.71)
#   Batch timeout: 3 tasks in 573.2s
#
# Meta-iter 64: Outer update (FOMAML) amb 3 tasques
#   Task 433: target_sharpe_reached (6,144 steps, sharpe=+3840467364.04)
#   Task 434: target_sharpe_reached (10,240 steps, sharpe=+1334973201.13)
#   Task 435: target_sharpe_reached (8,192 steps, sharpe=+1437472565.40)
#   Batch timeout: 3 tasks in 378.7s
#
# Meta-iter 65: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-24.1593 ret=-20.11% best=-13.5933 [plateau 2/20]
#
#   Task 436: SKIP (gradient_explosion)
#   Task 437: target_sharpe_reached (18,432 steps, sharpe=+748802286.35)
#   Task 438: target_sharpe_reached (6,144 steps, sharpe=+373793389.31)
#   Task 439: FAIL (max_steps_timeout)
#   Task 440: SKIP (gradient_explosion)
#   Task 441: SKIP (gradient_explosion)
#   Task 442: SKIP (gradient_explosion)
#   Task 443: target_sharpe_reached (6,144 steps, sharpe=+3682844036.34)
#   Batch timeout: 3 tasks in 1496.1s
#
# Meta-iter 66: Outer update (FOMAML) amb 3 tasques
#   Task 444: target_sharpe_reached (6,144 steps, sharpe=+6478007866.73)
#   Task 445: target_sharpe_reached (6,144 steps, sharpe=+1286341961.08)
#   Task 446: SKIP (gradient_explosion)
#   Task 447: target_sharpe_reached (6,144 steps, sharpe=+1086294770.45)
#   Task 448: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 372.5s
#
# Meta-iter 67: Outer update (FOMAML) amb 3 tasques
#   Task 449: performance_plateau (24,064 steps, sharpe=-785455310.06)
#   Task 450: target_sharpe_reached (6,144 steps, sharpe=+236893859.62)
#   Task 451: performance_plateau (16,384 steps, sharpe=-1915156001.39)
#   Batch timeout: 3 tasks in 630.0s
#
# Meta-iter 68: Outer update (FOMAML) amb 3 tasques
#   Task 452: SKIP (gradient_explosion)
#   Task 453: SKIP (gradient_explosion)
#   Task 454: SKIP (gradient_explosion)
#   Task 455: SKIP (gradient_explosion)
#   Task 456: target_sharpe_reached (6,144 steps, sharpe=+3436882202.16)
#   Task 457: SKIP (gradient_explosion)
#   Task 458: target_sharpe_reached (6,144 steps, sharpe=+39735626.79)
#   Task 459: SKIP (gradient_explosion)
#   Task 460: target_sharpe_reached (10,240 steps, sharpe=+253341261.94)
#   Batch timeout: 3 tasks in 689.0s
#
# Meta-iter 69: Outer update (FOMAML) amb 3 tasques
#   Task 461: target_sharpe_reached (20,480 steps, sharpe=+3301214776.85)
#   Task 462: target_sharpe_reached (12,288 steps, sharpe=+4013939212.66)
#   Task 463: SKIP (gradient_explosion)
#   Task 464: SKIP (gradient_explosion)
#   Task 465: target_sharpe_reached (6,144 steps, sharpe=+694841003.73)
#   Batch timeout: 3 tasks in 594.0s
#
# Meta-iter 70: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-30.2546 ret=-20.03% best=-13.5933 [plateau 3/20]
#
#   Task 466: SKIP (gradient_explosion)
#   Task 467: SKIP (gradient_explosion)
#   Task 468: performance_plateau (22,016 steps, sharpe=-1388737793.45)
#   Task 469: FAIL (max_steps_timeout)
#   Task 470: SKIP (gradient_explosion)
#   Task 471: SKIP (gradient_explosion)
#   Task 472: target_sharpe_reached (14,336 steps, sharpe=+1410489791.72)
#   Task 473: target_sharpe_reached (10,240 steps, sharpe=+2556552864.23)
#   Batch timeout: 3 tasks in 1176.5s
#
# Meta-iter 71: Outer update (FOMAML) amb 3 tasques
#   Task 474: SKIP (gradient_explosion)
#   Task 475: SKIP (gradient_explosion)
#   Task 476: SKIP (gradient_explosion)
#   Task 477: SKIP (gradient_explosion)
#   Task 478: SKIP (gradient_explosion)
#   Task 479: SKIP (gradient_explosion)
#   Task 480: SKIP (gradient_explosion)
#   Task 481: target_sharpe_reached (6,144 steps, sharpe=+759232772.40)
#   Task 482: SKIP (gradient_explosion)
#   Task 483: SKIP (gradient_explosion)
#   Task 484: target_sharpe_reached (6,144 steps, sharpe=+1651356046.20)
#   Task 485: target_sharpe_reached (6,144 steps, sharpe=+7325961821.27)
#   Batch timeout: 3 tasks in 764.2s
#
# Meta-iter 72: Outer update (FOMAML) amb 3 tasques
#   Task 486: target_sharpe_reached (16,384 steps, sharpe=+142665233.11)
#   Task 487: SKIP (gradient_explosion)
#   Task 488: target_sharpe_reached (20,480 steps, sharpe=+1699414744.59)
#   Task 489: performance_plateau (18,432 steps, sharpe=-1515883307.80)
#   Batch timeout: 3 tasks in 691.4s
#
# Meta-iter 73: Outer update (FOMAML) amb 3 tasques
#   Task 490: target_sharpe_reached (10,240 steps, sharpe=+240734170.30)
#   Task 491: target_sharpe_reached (10,240 steps, sharpe=+2209339243.24)
#   Task 492: target_sharpe_reached (6,144 steps, sharpe=+4123308458.68)
#   Task 493: target_sharpe_reached (6,144 steps, sharpe=+1860354469.57)
#   Batch timeout: 4 tasks in 358.0s
#
# Meta-iter 74: Outer update (FOMAML) amb 4 tasques
#   Task 494: target_sharpe_reached (6,144 steps, sharpe=+189110995.95)
#   Task 495: target_sharpe_reached (6,144 steps, sharpe=+48394024.14)
#   Task 496: performance_plateau (24,064 steps, sharpe=-649299540.77)
#   Batch timeout: 3 tasks in 497.4s
#
# Meta-iter 75: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-24.9589 ret=-19.75% best=-13.5933 [plateau 4/20]
#
#   Task 497: SKIP (gradient_explosion)
#   Task 498: target_sharpe_reached (10,240 steps, sharpe=+59452660.08)
#   Task 499: FAIL (max_steps_timeout)
#   Task 500: SKIP (gradient_explosion)
#   Task 501: target_sharpe_reached (6,144 steps, sharpe=+106564403.58)
#   Task 502: target_sharpe_reached (8,192 steps, sharpe=+711442735.03)
#   Batch timeout: 3 tasks in 920.6s
#
# Meta-iter 76: Outer update (FOMAML) amb 3 tasques
#   Task 503: target_sharpe_reached (6,144 steps, sharpe=+2866609788.98)
#   Task 504: target_sharpe_reached (6,144 steps, sharpe=+1413572838.37)
#   Task 505: SKIP (gradient_explosion)
#   Task 506: target_sharpe_reached (6,144 steps, sharpe=+2536836680.08)
#   Task 507: target_sharpe_reached (6,144 steps, sharpe=+3465695273.52)
#   Batch timeout: 4 tasks in 301.9s
#
# Meta-iter 77: Outer update (FOMAML) amb 4 tasques
#   Task 508: SKIP (gradient_explosion)
#   Task 509: SKIP (gradient_explosion)
#   Task 510: target_sharpe_reached (6,144 steps, sharpe=+3301008068.78)
#   Task 511: SKIP (gradient_explosion)
#   Task 512: target_sharpe_reached (6,144 steps, sharpe=+1499194168.97)
#   Task 513: target_sharpe_reached (6,144 steps, sharpe=+1179513672.39)
#   Batch timeout: 3 tasks in 592.0s
#
# Meta-iter 78: Outer update (FOMAML) amb 3 tasques
#   Task 514: target_sharpe_reached (6,144 steps, sharpe=+1336862002.80)
#   Task 515: SKIP (gradient_explosion)
#   Task 516: SKIP (gradient_explosion)
#   Task 517: target_sharpe_reached (6,144 steps, sharpe=+1186521876.54)
#   Task 518: target_sharpe_reached (6,144 steps, sharpe=+4579795378.32)
#   Batch timeout: 3 tasks in 398.4s
#
# Meta-iter 79: Outer update (FOMAML) amb 3 tasques
#   Task 519: SKIP (gradient_explosion)
#   Task 520: SKIP (gradient_explosion)
#   Task 521: target_sharpe_reached (6,144 steps, sharpe=+3838356024.53)
#   Task 522: SKIP (gradient_explosion)
#   Task 523: FAIL (max_steps_timeout)
#   Task 524: target_sharpe_reached (6,144 steps, sharpe=+2292049302.73)
#   Task 525: target_sharpe_reached (8,192 steps, sharpe=+24443704.51)
#   Batch timeout: 3 tasks in 829.0s
#
# Meta-iter 80: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-17.8438 ret=-19.86% best=-13.5933 [plateau 5/20]
#
#   Task 526: SKIP (gradient_explosion)
#   Task 527: SKIP (gradient_explosion)
#   Task 528: SKIP (gradient_explosion)
#   Task 529: SKIP (gradient_explosion)
#   Task 530: target_sharpe_reached (6,144 steps, sharpe=+1638169007.03)
#   Task 531: target_sharpe_reached (6,144 steps, sharpe=+339677481.56)
#   Task 532: SKIP (gradient_explosion)
#   Task 533: FAIL (max_steps_timeout)
#   Task 534: SKIP (gradient_explosion)
#   Task 535: SKIP (gradient_explosion)
#   Task 536: target_sharpe_reached (6,144 steps, sharpe=+57725735.23)
#   Batch timeout: 3 tasks in 1129.9s
#
# Meta-iter 81: Outer update (FOMAML) amb 3 tasques
#   Task 537: target_sharpe_reached (6,144 steps, sharpe=+981793663.44)
#   Task 538: SKIP (gradient_explosion)
#   Task 539: SKIP (gradient_explosion)
#   Task 540: target_sharpe_reached (10,240 steps, sharpe=+812637089.48)
#   Task 541: SKIP (gradient_explosion)
#   Task 542: SKIP (gradient_explosion)
#   Task 543: FAIL (max_steps_timeout)
#   Task 544: target_sharpe_reached (6,144 steps, sharpe=+797503153.76)
#   Batch timeout: 3 tasks in 956.6s
#
# Meta-iter 82: Outer update (FOMAML) amb 3 tasques
#   Task 545: target_sharpe_reached (12,288 steps, sharpe=+2990972878.38)
#   Task 546: FAIL (max_steps_timeout)
#   Task 547: SKIP (gradient_explosion)
#   Task 548: target_sharpe_reached (6,144 steps, sharpe=+4036599358.29)
#   Task 549: SKIP (gradient_explosion)
#   Task 550: target_sharpe_reached (6,144 steps, sharpe=+437143792.94)
#   Batch timeout: 3 tasks in 753.3s
#
# Meta-iter 83: Outer update (FOMAML) amb 3 tasques
#   Task 551: target_sharpe_reached (6,144 steps, sharpe=+2962617273.67)
#   Task 552: SKIP (gradient_explosion)
#   Task 553: target_sharpe_reached (6,144 steps, sharpe=+1814410091.02)
#   Task 554: target_sharpe_reached (6,144 steps, sharpe=+2535151279.56)
#   Task 555: target_sharpe_reached (12,288 steps, sharpe=+7011747021.21)
#   Batch timeout: 4 tasks in 455.3s
#
# Meta-iter 84: Outer update (FOMAML) amb 4 tasques
#   Task 556: target_sharpe_reached (6,144 steps, sharpe=+2952541285.17)
#   Task 557: SKIP (gradient_explosion)
#   Task 558: SKIP (gradient_explosion)
#   Task 559: target_sharpe_reached (6,144 steps, sharpe=+2969096017.50)
#   Task 560: target_sharpe_reached (6,144 steps, sharpe=+509485283.36)
#   Task 561: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 363.0s
#
# Meta-iter 85: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-28.8987 ret=-20.03% best=-13.5933 [plateau 6/20]
#
#   Task 562: target_sharpe_reached (12,288 steps, sharpe=+8940371366.59)
#   Task 563: SKIP (gradient_explosion)
#   Task 564: FAIL (max_steps_timeout)
#   Task 565: SKIP (gradient_explosion)
#   Task 566: SKIP (gradient_explosion)
#   Task 567: target_sharpe_reached (6,144 steps, sharpe=+3419568829.16)
#   Task 568: SKIP (gradient_explosion)
#   Task 569: SKIP (gradient_explosion)
#   Task 570: target_sharpe_reached (6,144 steps, sharpe=+923178251.07)
#   Batch timeout: 3 tasks in 1153.1s
#
# Meta-iter 86: Outer update (FOMAML) amb 3 tasques
#   Task 571: SKIP (gradient_explosion)
#   Task 572: target_sharpe_reached (6,144 steps, sharpe=+2166820517.80)
#   Task 573: SKIP (gradient_explosion)
#   Task 574: SKIP (gradient_explosion)
#   Task 575: target_sharpe_reached (12,288 steps, sharpe=+529038127.73)
#   Task 576: SKIP (gradient_explosion)
#   Task 577: SKIP (gradient_explosion)
#   Task 578: SKIP (gradient_explosion)
#   Task 579: SKIP (gradient_explosion)
#   Task 580: SKIP (gradient_explosion)
#   Task 581: SKIP (gradient_explosion)
#   Task 582: SKIP (gradient_explosion)
#   Task 583: target_sharpe_reached (6,144 steps, sharpe=+2295588594.41)
#   Batch timeout: 3 tasks in 1110.1s
#
# Meta-iter 87: Outer update (FOMAML) amb 3 tasques
#   Task 584: SKIP (gradient_explosion)
#   Task 585: performance_plateau (20,480 steps, sharpe=-1354447127.21)
#   Task 586: target_sharpe_reached (6,144 steps, sharpe=+2053698088.34)
#   Task 587: target_sharpe_reached (6,144 steps, sharpe=+1687661555.56)
#   Batch timeout: 3 tasks in 513.0s
#
# Meta-iter 88: Outer update (FOMAML) amb 3 tasques
#   Task 588: SKIP (gradient_explosion)
#   Task 589: FAIL (max_steps_timeout)
#   Task 590: target_sharpe_reached (14,336 steps, sharpe=+1708801797.59)
#   Task 591: SKIP (gradient_explosion)
#   Task 592: target_sharpe_reached (6,144 steps, sharpe=+3432828920.85)
#   Task 593: target_sharpe_reached (6,144 steps, sharpe=+2030641138.12)
#   Batch timeout: 3 tasks in 961.7s
#
# Meta-iter 89: Outer update (FOMAML) amb 3 tasques
#   Task 594: target_sharpe_reached (6,144 steps, sharpe=+1020004937.23)
#   Task 595: target_sharpe_reached (10,240 steps, sharpe=+1513012539.75)
#   Task 596: target_sharpe_reached (6,144 steps, sharpe=+3502131492.03)
#   Task 597: SKIP (gradient_explosion)
#   Task 598: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 392.2s
#
# Meta-iter 90: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-53.8678 ret=-20.11% best=-13.5933 [plateau 7/20]
#
#   Task 599: SKIP (gradient_explosion)
#   Task 600: SKIP (gradient_explosion)
#   Task 601: SKIP (gradient_explosion)
#   Task 602: SKIP (gradient_explosion)
#   Task 603: SKIP (gradient_explosion)
#   Task 604: target_sharpe_reached (6,144 steps, sharpe=+803862381.45)
#   Task 605: target_sharpe_reached (6,144 steps, sharpe=+509485283.36)
#   Task 606: SKIP (gradient_explosion)
#   Task 607: target_sharpe_reached (6,144 steps, sharpe=+3668736684.98)
#   Batch timeout: 3 tasks in 623.7s
#
# Meta-iter 91: Outer update (FOMAML) amb 3 tasques
#   Task 608: target_sharpe_reached (6,144 steps, sharpe=+655096201.64)
#   Task 609: target_sharpe_reached (6,144 steps, sharpe=+1454505935.54)
#   Task 610: target_sharpe_reached (6,144 steps, sharpe=+1045293547.74)
#   Task 611: target_sharpe_reached (6,144 steps, sharpe=+1302742727.18)
#   Task 612: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 329.3s
#
# Meta-iter 92: Outer update (FOMAML) amb 4 tasques
#   Task 613: SKIP (gradient_explosion)
#   Task 614: target_sharpe_reached (6,144 steps, sharpe=+123189444.80)
#   Task 615: FAIL (max_steps_timeout)
#   Task 616: target_sharpe_reached (6,144 steps, sharpe=+2999666665.72)
#   Task 617: SKIP (gradient_explosion)
#   Task 618: target_sharpe_reached (8,192 steps, sharpe=+1887076699.04)
#   Batch timeout: 3 tasks in 611.9s
#
# Meta-iter 93: Outer update (FOMAML) amb 3 tasques
#   Task 619: target_sharpe_reached (6,144 steps, sharpe=+3727472433.24)
#   Task 620: target_sharpe_reached (6,144 steps, sharpe=+1819658973.42)
#   Task 621: target_sharpe_reached (6,144 steps, sharpe=+6363350705.39)
#   Task 622: target_sharpe_reached (8,192 steps, sharpe=+323597164.91)
#   Task 623: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 321.1s
#
# Meta-iter 94: Outer update (FOMAML) amb 4 tasques
#   Task 624: SKIP (gradient_explosion)
#   Task 625: SKIP (gradient_explosion)
#   Task 626: target_sharpe_reached (6,144 steps, sharpe=+3537150234.95)
#   Task 627: target_sharpe_reached (6,144 steps, sharpe=+2458291686.71)
#   Task 628: target_sharpe_reached (6,144 steps, sharpe=+6176230633.29)
#   Task 629: target_sharpe_reached (6,144 steps, sharpe=+2529708315.63)
#   Batch timeout: 4 tasks in 344.3s
#
# Meta-iter 95: Outer update (FOMAML) amb 4 tasques
#   Val: sharpe=-24.9591 ret=-20.33% best=-13.5933 [plateau 8/20]
#
#   Task 630: target_sharpe_reached (6,144 steps, sharpe=+2867175262.35)
#   Task 631: target_sharpe_reached (6,144 steps, sharpe=+1077502515.96)
#   Task 632: target_sharpe_reached (6,144 steps, sharpe=+1721179624.20)
#   Task 633: SKIP (gradient_explosion)
#   Task 634: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 308.2s
#
# Meta-iter 96: Outer update (FOMAML) amb 3 tasques
#   Task 635: SKIP (gradient_explosion)
#   Task 636: SKIP (gradient_explosion)
#   Task 637: SKIP (gradient_explosion)
#   Task 638: SKIP (gradient_explosion)
#   Task 639: target_sharpe_reached (18,432 steps, sharpe=+1275645875.96)
#   Task 640: SKIP (gradient_explosion)
#   Task 641: target_sharpe_reached (10,240 steps, sharpe=+1141349952.11)
#   Task 642: target_sharpe_reached (6,144 steps, sharpe=+2983839532.04)
#   Batch timeout: 3 tasks in 710.2s
#
# Meta-iter 97: Outer update (FOMAML) amb 3 tasques
#   Task 643: target_sharpe_reached (6,144 steps, sharpe=+4767627334.82)
#   Task 644: target_sharpe_reached (6,144 steps, sharpe=+1339893706.89)
#   Task 645: SKIP (gradient_explosion)
#   Task 646: SKIP (gradient_explosion)
#   Task 647: target_sharpe_reached (6,144 steps, sharpe=+1280089429.92)
#   Batch timeout: 3 tasks in 347.0s
#
# Meta-iter 98: Outer update (FOMAML) amb 3 tasques
#   Task 648: target_sharpe_reached (6,144 steps, sharpe=+691848467.96)
#   Task 649: target_sharpe_reached (6,144 steps, sharpe=+2993443563.20)
#   Task 650: target_sharpe_reached (6,144 steps, sharpe=+8105975355.37)
#   Task 651: SKIP (gradient_explosion)
#   Task 652: target_sharpe_reached (10,240 steps, sharpe=+312831221.40)
#   Batch timeout: 4 tasks in 353.0s
#
# Meta-iter 99: Outer update (FOMAML) amb 4 tasques
#   Task 653: target_sharpe_reached (6,144 steps, sharpe=+163476012.58)
#   Task 654: SKIP (gradient_explosion)
#   Task 655: target_sharpe_reached (6,144 steps, sharpe=+4411824030.59)
#   Task 656: target_sharpe_reached (6,144 steps, sharpe=+492612115.15)
#   Task 657: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 435.3s
#
# Meta-iter 100: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-19.7425 ret=-19.87% best=-13.5933 [plateau 9/20]
#
#   [ckpt] Desat checkpoint @ iter 100 → ppo_fomaml_meta_new_adaptative.pt
#   Task 658: performance_plateau (18,432 steps, sharpe=-286241607.43)
#   Task 659: SKIP (gradient_explosion)
#   Task 660: FAIL (max_steps_timeout)
#   Task 661: target_sharpe_reached (8,192 steps, sharpe=+3468808457.90)
#   Task 662: SKIP (gradient_explosion)
#   Task 663: SKIP (gradient_explosion)
#   Task 664: SKIP (gradient_explosion)
#   Task 665: SKIP (gradient_explosion)
#   Task 666: SKIP (gradient_explosion)
#   Task 667: target_sharpe_reached (6,144 steps, sharpe=+3599060659.37)
#   Batch timeout: 3 tasks in 1337.8s
#
# Meta-iter 101: Outer update (FOMAML) amb 3 tasques
#   Task 668: target_sharpe_reached (10,240 steps, sharpe=+219283821.45)
#   Task 669: SKIP (gradient_explosion)
#   Task 670: target_sharpe_reached (6,144 steps, sharpe=+1114391760.52)
#   Task 671: target_sharpe_reached (6,144 steps, sharpe=+3912798858.26)
#   Batch timeout: 3 tasks in 316.3s
#
# Meta-iter 102: Outer update (FOMAML) amb 3 tasques
#   Task 672: performance_plateau (16,384 steps, sharpe=-760124584.93)
#   Task 673: target_sharpe_reached (6,144 steps, sharpe=+1089995911.54)
#   Task 674: SKIP (gradient_explosion)
#   Task 675: SKIP (gradient_explosion)
#   Task 676: target_sharpe_reached (6,144 steps, sharpe=+3659875633.18)
#   Batch timeout: 3 tasks in 653.6s
#
# Meta-iter 103: Outer update (FOMAML) amb 3 tasques
#   Task 677: SKIP (gradient_explosion)
#   Task 678: SKIP (gradient_explosion)
#   Task 679: SKIP (gradient_explosion)
#   Task 680: FAIL (max_steps_timeout)
#   Task 681: target_sharpe_reached (14,336 steps, sharpe=+4625296567.55)
#   Task 682: target_sharpe_reached (14,336 steps, sharpe=+944245846.10)
#   Task 683: performance_plateau (18,432 steps, sharpe=-2067339431.23)
#   Batch timeout: 3 tasks in 1043.6s
#
# Meta-iter 104: Outer update (FOMAML) amb 3 tasques
#   Task 684: SKIP (gradient_explosion)
#   Task 685: target_sharpe_reached (6,144 steps, sharpe=+1719838195.50)
#   Task 686: target_sharpe_reached (6,144 steps, sharpe=+335310469.59)
#   Task 687: SKIP (gradient_explosion)
#   Task 688: SKIP (gradient_explosion)
#   Task 689: SKIP (gradient_explosion)
#   Task 690: target_sharpe_reached (12,288 steps, sharpe=+2371289886.98)
#   Batch timeout: 3 tasks in 521.0s
#
# Meta-iter 105: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-17.1612 ret=-19.86% best=-13.5933 [plateau 10/20]
#
#   Task 691: SKIP (gradient_explosion)
#   Task 692: target_sharpe_reached (6,144 steps, sharpe=+159812703.69)
#   Task 693: SKIP (gradient_explosion)
#   Task 694: target_sharpe_reached (6,144 steps, sharpe=+401834349.73)
#   Task 695: SKIP (gradient_explosion)
#   Task 696: SKIP (gradient_explosion)
#   Task 697: target_sharpe_reached (6,144 steps, sharpe=+79774156.72)
#   Batch timeout: 3 tasks in 418.8s
#
# Meta-iter 106: Outer update (FOMAML) amb 3 tasques
#   Task 698: performance_plateau (20,480 steps, sharpe=-308276598.46)
# ...
#   Batch timeout: 3 tasks in 378.1s
#
# Meta-iter 124: Outer update (FOMAML) amb 3 tasques
#   Task 804: target_sharpe_reached (6,144 steps, sharpe=+3141677196.48)
#   Task 805: SKIP (gradient_explosion)
#   Task 806: SKIP (gradient_explosion)
#   Task 807: SKIP (gradient_explosion)
#   Task 808: SKIP (gradient_explosion)
#   Task 809: SKIP (gradient_explosion)
#   Task 810: target_sharpe_reached (8,192 steps, sharpe=+1106110751.37)
#   Task 811: SKIP (gradient_explosion)
#   Task 812: target_sharpe_reached (16,384 steps, sharpe=+96140405.23)
#   Batch timeout: 3 tasks in 919.8s
#
# Meta-iter 125: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-17.7812 ret=-19.72% best=-13.5933 [plateau 14/20]
#
#   Task 813: FAIL (max_steps_timeout)
#   Task 814: target_sharpe_reached (10,240 steps, sharpe=+689653511.76)
#   Task 815: SKIP (gradient_explosion)
#   Task 816: target_sharpe_reached (6,144 steps, sharpe=+232696961.32)
#   Task 817: SKIP (gradient_explosion)
#   Task 818: target_sharpe_reached (6,144 steps, sharpe=+2062535137.90)
#   Batch timeout: 3 tasks in 547.4s
#
# Meta-iter 126: Outer update (FOMAML) amb 3 tasques
#   Task 819: target_sharpe_reached (6,144 steps, sharpe=+3827173664.18)
#   Task 820: SKIP (gradient_explosion)
#   Task 821: target_sharpe_reached (6,144 steps, sharpe=+2009950384.41)
#   Task 822: SKIP (gradient_explosion)
#   Task 823: SKIP (gradient_explosion)
#   Task 824: FAIL (max_steps_timeout)
#   Task 825: SKIP (gradient_explosion)
#   Task 826: target_sharpe_reached (6,144 steps, sharpe=+1946564141.33)
#   Batch timeout: 3 tasks in 646.4s
#
# Meta-iter 127: Outer update (FOMAML) amb 3 tasques
#   Task 827: SKIP (gradient_explosion)
#   Task 828: target_sharpe_reached (6,144 steps, sharpe=+3101657402.17)
#   Task 829: SKIP (gradient_explosion)
#   Task 830: target_sharpe_reached (12,288 steps, sharpe=+3286995405.47)
#   Task 831: target_sharpe_reached (6,144 steps, sharpe=+2979059832.12)
#   Batch timeout: 3 tasks in 326.8s
#
# Meta-iter 128: Outer update (FOMAML) amb 3 tasques
#   Task 832: SKIP (gradient_explosion)
#   Task 833: target_sharpe_reached (16,384 steps, sharpe=+3428650515.70)
#   Task 834: target_sharpe_reached (6,144 steps, sharpe=+2822188717.67)
#   Task 835: SKIP (gradient_explosion)
#   Task 836: SKIP (gradient_explosion)
#   Task 837: SKIP (gradient_explosion)
#   Task 838: SKIP (gradient_explosion)
#   Task 839: SKIP (gradient_explosion)
#   Task 840: SKIP (gradient_explosion)
#   Task 841: SKIP (gradient_explosion)
#   Task 842: performance_plateau (22,016 steps, sharpe=-155425992.74)
#   Batch timeout: 3 tasks in 927.8s
#
# Meta-iter 129: Outer update (FOMAML) amb 3 tasques
#   Task 843: SKIP (gradient_explosion)
#   Task 844: SKIP (gradient_explosion)
#   Task 845: target_sharpe_reached (6,144 steps, sharpe=+296399000.00)
#   Task 846: SKIP (gradient_explosion)
#   Task 847: SKIP (gradient_explosion)
#   Task 848: target_sharpe_reached (6,144 steps, sharpe=+564601038.19)
#   Task 849: SKIP (gradient_explosion)
#   Task 850: FAIL (max_steps_timeout)
#   Task 851: SKIP (gradient_explosion)
#   Task 852: target_sharpe_reached (10,240 steps, sharpe=+156599804.59)
#   Batch timeout: 3 tasks in 648.7s
#
# Meta-iter 130: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-39.1859 ret=-20.20% best=-13.5933 [plateau 15/20]
#
#   Task 853: SKIP (gradient_explosion)
#   Task 854: performance_plateau (28,160 steps, sharpe=-4343345.74)
#   Task 855: SKIP (gradient_explosion)
#   Task 856: SKIP (gradient_explosion)
#   Task 857: target_sharpe_reached (6,144 steps, sharpe=+2944380082.46)
#   Task 858: target_sharpe_reached (6,144 steps, sharpe=+3271344222.70)
#   Batch timeout: 3 tasks in 499.8s
#
# Meta-iter 131: Outer update (FOMAML) amb 3 tasques
#   Task 859: target_sharpe_reached (6,144 steps, sharpe=+1604658946.63)
#   Task 860: target_sharpe_reached (6,144 steps, sharpe=+388159334.00)
#   Task 861: FAIL (max_steps_timeout)
#   Task 862: FAIL (max_steps_timeout)
#   Task 863: SKIP (gradient_explosion)
#   Task 864: target_sharpe_reached (12,288 steps, sharpe=+1764104880.27)
#   Batch timeout: 3 tasks in 789.4s
#
# Meta-iter 132: Outer update (FOMAML) amb 3 tasques
#   Task 865: SKIP (gradient_explosion)
#   Task 866: target_sharpe_reached (6,144 steps, sharpe=+1364915105.81)
#   Task 867: target_sharpe_reached (6,144 steps, sharpe=+1591064218.80)
#   Task 868: SKIP (gradient_explosion)
#   Task 869: target_sharpe_reached (6,144 steps, sharpe=+163181329.52)
#   Task 870: SKIP (gradient_explosion)
#   Task 871: target_sharpe_reached (28,160 steps, sharpe=+2845757764.76)
#   Batch timeout: 4 tasks in 458.1s
#
# Meta-iter 133: Outer update (FOMAML) amb 4 tasques
#   Task 872: target_sharpe_reached (10,240 steps, sharpe=+294331650.91)
#   Task 873: target_sharpe_reached (6,144 steps, sharpe=+2383988162.82)
#   Task 874: SKIP (gradient_explosion)
#   Task 875: target_sharpe_reached (8,192 steps, sharpe=+6958762357.57)
#   Task 876: SKIP (gradient_explosion)
#   Task 877: target_sharpe_reached (6,144 steps, sharpe=+5898965992.59)
#   Batch timeout: 4 tasks in 307.5s
#
# Meta-iter 134: Outer update (FOMAML) amb 4 tasques
#   Task 878: SKIP (gradient_explosion)
#   Task 879: target_sharpe_reached (22,016 steps, sharpe=+4184885857.30)
#   Task 880: SKIP (gradient_explosion)
#   Task 881: target_sharpe_reached (6,144 steps, sharpe=+2556779003.48)
#   Task 882: target_sharpe_reached (6,144 steps, sharpe=+244608133.38)
#   Batch timeout: 3 tasks in 425.2s
#
# Meta-iter 135: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-18.2835 ret=-20.13% best=-13.5933 [plateau 16/20]
#
#   Task 883: SKIP (gradient_explosion)
#   Task 884: target_sharpe_reached (8,192 steps, sharpe=+1185697409.34)
#   Task 885: target_sharpe_reached (6,144 steps, sharpe=+3680738726.61)
#   Task 886: target_sharpe_reached (6,144 steps, sharpe=+3504840016.12)
#   Task 887: target_sharpe_reached (6,144 steps, sharpe=+3192915098.96)
#   Task 888: target_sharpe_reached (6,144 steps, sharpe=+1064059917.63)
#
# Meta-iter 136: Outer update (FOMAML) amb 5 tasques
#   Task 889: SKIP (overfitting)
#   Task 890: SKIP (gradient_explosion)
#   Task 891: performance_plateau (22,016 steps, sharpe=-953821313.97)
#   Task 892: SKIP (gradient_explosion)
#   Task 893: target_sharpe_reached (10,240 steps, sharpe=+2338636997.84)
#   Task 894: target_sharpe_reached (8,192 steps, sharpe=+425735537.77)
#   Batch timeout: 3 tasks in 553.7s
#
# Meta-iter 137: Outer update (FOMAML) amb 3 tasques
#   Task 895: SKIP (gradient_explosion)
#   Task 896: target_sharpe_reached (6,144 steps, sharpe=+7220235575.16)
#   Task 897: target_sharpe_reached (10,240 steps, sharpe=+2904841539.20)
#   Task 898: SKIP (gradient_explosion)
#   Task 899: target_sharpe_reached (6,144 steps, sharpe=+2827132403.09)
#   Batch timeout: 3 tasks in 318.9s
#
# Meta-iter 138: Outer update (FOMAML) amb 3 tasques
#   Task 900: SKIP (gradient_explosion)
#   Task 901: SKIP (gradient_explosion)
#   Task 902: target_sharpe_reached (18,432 steps, sharpe=+4177376070.48)
#   Task 903: SKIP (gradient_explosion)
#   Task 904: target_sharpe_reached (6,144 steps, sharpe=+501121553.64)
#   Task 905: SKIP (gradient_explosion)
#   Task 906: target_sharpe_reached (6,144 steps, sharpe=+24268377.68)
#   Batch timeout: 3 tasks in 481.9s
#
# Meta-iter 139: Outer update (FOMAML) amb 3 tasques
#   Task 907: SKIP (gradient_explosion)
#   Task 908: target_sharpe_reached (6,144 steps, sharpe=+2479619975.98)
#   Task 909: performance_plateau (16,384 steps, sharpe=-2012401174.71)
#   Task 910: target_sharpe_reached (6,144 steps, sharpe=+590034761.02)
#   Task 911: SKIP (gradient_explosion)
#   Task 912: SKIP (gradient_explosion)
#   Task 913: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 390.7s
#
# Meta-iter 140: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-36.9006 ret=-20.04% best=-13.5933 [plateau 17/20]
#
#   Task 914: SKIP (gradient_explosion)
#   Task 915: target_sharpe_reached (6,144 steps, sharpe=+172004580.68)
#   Task 916: SKIP (gradient_explosion)
#   Task 917: SKIP (gradient_explosion)
#   Task 918: SKIP (gradient_explosion)
#   Task 919: FAIL (max_steps_timeout)
#   Task 920: target_sharpe_reached (10,240 steps, sharpe=+154816942.88)
#   Task 921: SKIP (gradient_explosion)
#   Task 922: target_sharpe_reached (12,288 steps, sharpe=+10521013.85)
#   Batch timeout: 3 tasks in 746.2s
#
# Meta-iter 141: Outer update (FOMAML) amb 3 tasques
#   Task 923: target_sharpe_reached (6,144 steps, sharpe=+3758008731.28)
#   Task 924: target_sharpe_reached (6,144 steps, sharpe=+3658492486.47)
#   Task 925: target_sharpe_reached (8,192 steps, sharpe=+38465313.32)
#   Task 926: SKIP (gradient_explosion)
#   Task 927: SKIP (gradient_explosion)
#   Task 928: target_sharpe_reached (6,144 steps, sharpe=+506200605.40)
#   Task 929: target_sharpe_reached (6,144 steps, sharpe=+3883737508.17)
#
# Meta-iter 142: Outer update (FOMAML) amb 5 tasques
#   Task 930: SKIP (gradient_explosion)
#   Task 931: SKIP (gradient_explosion)
#   Task 932: SKIP (gradient_explosion)
#   Task 933: SKIP (gradient_explosion)
#   Task 934: SKIP (gradient_explosion)
#   Task 935: target_sharpe_reached (22,016 steps, sharpe=+325334964.83)
#   Task 936: SKIP (gradient_explosion)
#   Task 937: target_sharpe_reached (6,144 steps, sharpe=+3401497178.61)
#   Task 938: target_sharpe_reached (6,144 steps, sharpe=+411539114.88)
#   Batch timeout: 3 tasks in 708.5s
#
# Meta-iter 143: Outer update (FOMAML) amb 3 tasques
#   Task 939: target_sharpe_reached (6,144 steps, sharpe=+6447307088.75)
#   Task 940: target_sharpe_reached (8,192 steps, sharpe=+1086122574.87)
#   Task 941: SKIP (gradient_explosion)
#   Task 942: SKIP (gradient_explosion)
#   Task 943: target_sharpe_reached (6,144 steps, sharpe=+6383845367.42)
#   Task 944: target_sharpe_reached (6,144 steps, sharpe=+3230179948.47)
#   Task 945: FAIL (max_steps_timeout)
#   Batch timeout: 4 tasks in 550.2s
#
# Meta-iter 144: Outer update (FOMAML) amb 4 tasques
#   Task 946: target_sharpe_reached (6,144 steps, sharpe=+515949842.74)
#   Task 947: target_sharpe_reached (18,432 steps, sharpe=+4129286025.01)
#   Task 948: target_sharpe_reached (6,144 steps, sharpe=+547803345.12)
#   Task 949: SKIP (gradient_explosion)
#   Task 950: target_sharpe_reached (6,144 steps, sharpe=+1247153339.75)
#   Batch timeout: 4 tasks in 326.7s
#
# Meta-iter 145: Outer update (FOMAML) amb 4 tasques
#   Val: sharpe=-40.9961 ret=-20.04% best=-13.5933 [plateau 18/20]
#
#   Task 951: SKIP (gradient_explosion)
#   Task 952: SKIP (gradient_explosion)
#   Task 953: target_sharpe_reached (6,144 steps, sharpe=+2209586822.17)
#   Task 954: SKIP (gradient_explosion)
#   Task 955: SKIP (gradient_explosion)
#   Task 956: target_sharpe_reached (6,144 steps, sharpe=+1634212769.43)
#   Task 957: SKIP (gradient_explosion)
#   Task 958: target_sharpe_reached (8,192 steps, sharpe=+177327612.19)
#   Batch timeout: 3 tasks in 697.0s
#
# Meta-iter 146: Outer update (FOMAML) amb 3 tasques
#   Task 959: SKIP (gradient_explosion)
#   Task 960: SKIP (gradient_explosion)
#   Task 961: SKIP (gradient_explosion)
#   Task 962: SKIP (gradient_explosion)
#   Task 963: target_sharpe_reached (6,144 steps, sharpe=+5974958275.04)
#   Task 964: FAIL (max_steps_timeout)
#   Task 965: SKIP (gradient_explosion)
#   Task 966: SKIP (gradient_explosion)
#   Task 967: target_sharpe_reached (12,288 steps, sharpe=+1810905052.04)
#   Task 968: SKIP (gradient_explosion)
#   Task 969: SKIP (gradient_explosion)
#   Task 970: SKIP (gradient_explosion)
#   Task 971: SKIP (gradient_explosion)
#   Task 972: target_sharpe_reached (6,144 steps, sharpe=+6957796927.21)
#   Batch timeout: 3 tasks in 964.5s
#
# Meta-iter 147: Outer update (FOMAML) amb 3 tasques
#   Task 973: target_sharpe_reached (8,192 steps, sharpe=+6616380956.11)
#   Task 974: target_sharpe_reached (6,144 steps, sharpe=+2364031816.42)
#   Task 975: target_sharpe_reached (8,192 steps, sharpe=+5123419011.71)
#   Task 976: target_sharpe_reached (8,192 steps, sharpe=+1117025113.36)
#   Task 977: SKIP (gradient_explosion)
#   Task 978: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 395.6s
#
# Meta-iter 148: Outer update (FOMAML) amb 4 tasques
#   Task 979: SKIP (gradient_explosion)
#   Task 980: SKIP (gradient_explosion)
#   Task 981: SKIP (gradient_explosion)
#   Task 982: target_sharpe_reached (6,144 steps, sharpe=+165088356.78)
#   Task 983: SKIP (gradient_explosion)
#   Task 984: SKIP (gradient_explosion)
#   Task 985: SKIP (gradient_explosion)
#   Task 986: target_sharpe_reached (6,144 steps, sharpe=+1667555321.78)
#   Task 987: target_sharpe_reached (6,144 steps, sharpe=+784481517.19)
#   Batch timeout: 3 tasks in 345.5s
#
# Meta-iter 149: Outer update (FOMAML) amb 3 tasques
#   Task 988: target_sharpe_reached (8,192 steps, sharpe=+406705499.04)
#   Task 989: target_sharpe_reached (6,144 steps, sharpe=+735465542.87)
#   Task 990: target_sharpe_reached (6,144 steps, sharpe=+898224456.05)
#   Task 991: SKIP (gradient_explosion)
#   Task 992: SKIP (gradient_explosion)
#   Task 993: target_sharpe_reached (6,144 steps, sharpe=+1561442284.97)
#   Task 994: SKIP (gradient_explosion)
#   Task 995: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 324.4s
#
# Meta-iter 150: Outer update (FOMAML) amb 4 tasques
#   Val: sharpe=-22.5330 ret=-20.06% best=-13.5933 [plateau 19/20]
#
#   [ckpt] Desat checkpoint @ iter 150 → ppo_fomaml_meta_new_adaptative.pt
#   Task 996: SKIP (gradient_explosion)
#   Task 997: target_sharpe_reached (14,336 steps, sharpe=+2818898939.80)
#   Task 998: target_sharpe_reached (14,336 steps, sharpe=+758733040.82)
#   Task 999: SKIP (gradient_explosion)
#   Task 1000: SKIP (gradient_explosion)
#   Task 1001: SKIP (gradient_explosion)
#   Task 1002: SKIP (gradient_explosion)
#   Task 1003: SKIP (gradient_explosion)
#   Task 1004: target_sharpe_reached (12,288 steps, sharpe=+3398571871.04)
#   Batch timeout: 3 tasks in 924.1s
#
# Meta-iter 151: Outer update (FOMAML) amb 3 tasques
#   Task 1005: SKIP (gradient_explosion)
#   Task 1006: SKIP (gradient_explosion)
#   Task 1007: target_sharpe_reached (6,144 steps, sharpe=+6804322760.55)
#   Task 1008: target_sharpe_reached (16,384 steps, sharpe=+3132169463.96)
#   Task 1009: SKIP (gradient_explosion)
#   Task 1010: SKIP (gradient_explosion)
#   Task 1011: target_sharpe_reached (6,144 steps, sharpe=+1694259267.48)
#   Batch timeout: 3 tasks in 343.1s
#
# Meta-iter 152: Outer update (FOMAML) amb 3 tasques
#   Task 1012: target_sharpe_reached (6,144 steps, sharpe=+3618495383.37)
#   Task 1013: target_sharpe_reached (6,144 steps, sharpe=+1847291164.68)
#   Task 1014: target_sharpe_reached (6,144 steps, sharpe=+1160561333.13)
#   Task 1015: target_sharpe_reached (6,144 steps, sharpe=+1518229192.84)
#   Task 1016: target_sharpe_reached (6,144 steps, sharpe=+5249121445.44)
#
# Meta-iter 153: Outer update (FOMAML) amb 5 tasques
#   Task 1017: SKIP (gradient_explosion)
#   Task 1018: SKIP (gradient_explosion)
#   Task 1019: SKIP (gradient_explosion)
#   Task 1020: target_sharpe_reached (6,144 steps, sharpe=+3078351262.65)
#   Task 1021: FAIL (max_steps_timeout)
#   Task 1022: target_sharpe_reached (6,144 steps, sharpe=+2110531182.80)
#   Task 1023: SKIP (gradient_explosion)
#   Task 1024: SKIP (gradient_explosion)
#   Task 1025: SKIP (gradient_explosion)
#   Task 1026: SKIP (gradient_explosion)
#   Task 1027: SKIP (gradient_explosion)
#   Task 1028: SKIP (gradient_explosion)
#   Task 1029: target_sharpe_reached (6,144 steps, sharpe=+1369193081.17)
#   Batch timeout: 3 tasks in 917.7s
#
# Meta-iter 154: Outer update (FOMAML) amb 3 tasques
#   Task 1030: target_sharpe_reached (6,144 steps, sharpe=+6908914343.62)
#   Task 1031: performance_plateau (16,384 steps, sharpe=+0.00)
#   Task 1032: target_sharpe_reached (8,192 steps, sharpe=+2568058613.83)
#   Task 1033: SKIP (gradient_explosion)
#   Task 1034: target_sharpe_reached (6,144 steps, sharpe=+75075184.86)
#   Batch timeout: 4 tasks in 314.8s
#
# Meta-iter 155: Outer update (FOMAML) amb 4 tasques
#   Val: sharpe=-21.2085 ret=-19.69% best=-13.5933 [plateau 20/20]
#
# ✗ Meta early stopping: 20 evals sense millora
#
# Restored best meta-agent: val_sharpe=-13.5933
#
# ============================================================
# Meta-entrenament completat: 1895.6 min
#   Total meta-iters: 155
#   Total tasks processades: 1034
#   Best val sharpe: -13.5933
#   Emissions meta: 668.16 g CO2eq
# ============================================================
#
# Meta-checkpoint desat: checkpoints_dense\ppo_fomaml_meta_new_adaptative.pt
#
# Millor val: Sharpe=-13.5933  Ret=-19.19%  iter 55

# %%
# =============================================================================
# CEL·LA 10 — ANÀLISI INNER DIAGNOSTICS
# =============================================================================

if inner_diagnostics:
    print(f'\nInner Loop Diagnostics ({len(inner_diagnostics)} tasques processades)\n')
    print('='*80)
    
    # Estadístiques de convergència
    converged = [d for d in inner_diagnostics if d['converged']]
    reasons = {}
    for d in inner_diagnostics:
        r = d['reason']
        reasons[r] = reasons.get(r, 0) + 1
    
    print(f'Tasques convergides: {len(converged)}/{len(inner_diagnostics)} '
          f'({len(converged)/len(inner_diagnostics)*100:.1f}%)')
    print(f'\nRaons de finalització:')
    for reason, count in sorted(reasons.items(), key=lambda x: -x[1]):
        print(f'  {reason:30s}: {count:4d} ({count/len(inner_diagnostics)*100:5.1f}%)')
    
    # Estadístiques de steps
    steps = [d['steps'] for d in converged]
    if steps:
        print(f'\nSteps per tasca convergida:')
        print(f'  Mean: {np.mean(steps):,.0f}')
        print(f'  Median: {np.median(steps):,.0f}')
        print(f'  Min: {np.min(steps):,.0f}')
        print(f'  Max: {np.max(steps):,.0f}')
    
    # Sharpe final
    sharpes = [d['final_sharpe'] for d in converged]
    if sharpes:
        print(f'\nSharpe final (tasques convergides):')
        print(f'  Mean: {np.mean(sharpes):+.4f}')
        print(f'  Median: {np.median(sharpes):+.4f}')
        print(f'  Min: {np.min(sharpes):+.4f}')
        print(f'  Max: {np.max(sharpes):+.4f}')
    
    print('='*80)
else:
    print('No inner diagnostics disponibles')
# Out:
# Inner Loop Diagnostics (1034 tasques processades)
#
# ================================================================================
# Tasques convergides: 986/1034 (95.4%)
#
# Raons de finalització:
#   gradient_explosion            :  494 ( 47.8%)
#   target_sharpe_reached         :  459 ( 44.4%)
#   max_steps_timeout             :   48 (  4.6%)
#   performance_plateau           :   32 (  3.1%)
#   overfitting                   :    1 (  0.1%)
#
# Steps per tasca convergida:
#   Mean: 8,838
#   Median: 6,144
#   Min: 6,144
#   Max: 30,000
#
# Sharpe final (tasques convergides):
#   Mean: +387927062.6967
#   Median: +0.0000
#   Min: -2843547532.0155
#   Max: +11302831392.4005
# ================================================================================

# %%
# =============================================================================
# CEL·LA 11 — META-TRAINING CURVES
# =============================================================================

if meta_history:
    fig, axes = plt.subplots(2, 2, figsize=(16, 10))
    
    iters = [h['meta_iter'] for h in meta_history]
    ret_v = [h['val_return'] for h in meta_history]
    sh_v  = [h['val_sharpe'] for h in meta_history]
    n_adapted = [h['n_adapted'] for h in meta_history]
    
    # Val Return
    axes[0, 0].plot(iters, ret_v, 'o-', color='#1f77b4', lw=2)
    axes[0, 0].axhline(0, color='gray', ls='--', lw=0.8)
    axes[0, 0].set_title('Reptile Adaptatiu — Retorn mig (val)')
    axes[0, 0].set_xlabel('Meta-iteració')
    axes[0, 0].set_ylabel('Return (%)')
    axes[0, 0].grid(alpha=0.3)
    
    # Val Sharpe
    axes[0, 1].plot(iters, sh_v, 'o-', color='#2ca02c', lw=2)
    axes[0, 1].axhline(0, color='gray', ls='--', lw=0.8)
    if meta_criteria.target_val_sharpe is not None:
        axes[0, 1].axhline(meta_criteria.target_val_sharpe, color='red', ls='--', lw=1.0, alpha=0.5, label=f'Target ({meta_criteria.target_val_sharpe})')
    axes[0, 1].set_title('Reptile Adaptatiu — Sharpe (val)')
    axes[0, 1].set_xlabel('Meta-iteració')
    axes[0, 1].set_ylabel('Sharpe')
    axes[0, 1].legend()
    axes[0, 1].grid(alpha=0.3)
    
    # N tasques adaptades per batch
    axes[1, 0].plot(iters, n_adapted, 'o-', color='#ff7f0e', lw=2)
    axes[1, 0].axhline(outer_trigger.batch_size, color='red', ls='--', lw=1.0, alpha=0.5, label=f'Target batch ({outer_trigger.batch_size})')
    axes[1, 0].set_title('Tasques convergides per outer update')
    axes[1, 0].set_xlabel('Meta-iteració')
    axes[1, 0].set_ylabel('N tasques')
    axes[1, 0].legend()
    axes[1, 0].grid(alpha=0.3)
    
    # Millora acumulada
    if len(sh_v) > 0:
        improvement = [s - sh_v[0] for s in sh_v]
        axes[1, 1].plot(iters, improvement, 'o-', color='#d62728', lw=2)
        axes[1, 1].axhline(0, color='gray', ls='--', lw=0.8)
        axes[1, 1].set_title('Millora Sharpe des inici')
        axes[1, 1].set_xlabel('Meta-iteració')
        axes[1, 1].set_ylabel('Δ Sharpe')
        axes[1, 1].grid(alpha=0.3)
    
    plt.suptitle('NB06d — PPO Reptile Adaptatiu Meta-training', fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.savefig(RESULTS / 'meta_training_curves.png', dpi=120, bbox_inches='tight')
    plt.show()
else:
    print('Sense historial de meta-entrenament')

# %% [markdown]
# ## Continua amb avaluació (rolling-window, etc.)
#
# A partir d'aquí pots copiar les cel·les d'avaluació del notebook original (CEL·LA 12-18):
# - `ppo_walk_forward`
# - `ppo_rolling_meta_eval` (amb fast-adaptation)
# - Equity curves
# - Action distribution
# - Comparative table
#
# Les funcions d'avaluació són idèntiques, només canvia el `meta_policy` que és el resultat del sistema adaptatiu.
