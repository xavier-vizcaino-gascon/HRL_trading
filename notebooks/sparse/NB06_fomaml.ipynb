# %% [markdown]
# # NB06s — FOMAML Meta-Learning ADAPTATIU sobre PPO Agent (Sparse Reward)
#
# **Objectiu**: Entrena un agent PPO amb **FOMAML meta-learning adaptatiu** que:
# - **Inner loops dinàmics**: Cada tasca s'entrena fins que **convergeix** (mètrica ho detecta)
# - **Outer updates automàtics**: Quan s'acumulen N tasques O passa X temps
# - **Early stopping global**: Para quan el meta-agent **convergeix** sobre val
#
# ## Diferències vs. versió clàssica
#
# | Aspecte | Clàssic | Adaptatiu |
# |---------|---------|----------|
# | Inner steps | **Fix** (10k steps) | **Dinàmic** (fins convergir, 5k-30k) |
# | Batch size | **Fix** (10 tasques) | **Dinàmic** (acumula fins 5 o timeout) |
# | Meta iters | **Fix** (15k iters) | **Dinàmic** (para quan val sharpe convergeix) |
# | Filtratge | **Cap** | **Automàtic** (només tasques convergides) |
# | Budget | **1.5B steps** (!!) | **~10-50M steps** (eficient) |
#
# ## Sistema adaptatiu
#
# ```
# ┌─ META-ENTRENAMENT (loop principal) ───────────────────┐
# │                                                       │
# │  ┌─ INNER LOOP BATCH ──────────────────────────┐    │
# │  │  → Tasca 1: entrena fins convergir (Sharpe) │    │
# │  │  → Tasca 2: entrena fins convergir          │    │
# │  │  → Tasca 3: entrena fins convergir          │    │
# │  │  → ... (fins N tasques o timeout)           │    │
# │  └──────────────────────────────────────────────┘    │
# │              ↓                                        │
# │  ┌─ OUTER UPDATE (FOMAML) ───────────────────┐     │
# │  │  θ ← θ + ε·mean(φᵢ - θ)                    │     │
# │  └──────────────────────────────────────────────┘    │
# │              ↓                                        │
# │  ┌─ AVALUACIÓ META (periòdica) ───────────────┐     │
# │  │  Val Sharpe → early stopping?              │     │
# │  └──────────────────────────────────────────────┘    │
# │              ↓                                        │
# │         Convergit? → PARA                             │
# │         NO → REPEAT                                   │
# └───────────────────────────────────────────────────────┘
# ```

# %%
# =============================================================================
# CEL·LA 1 — IMPORTS
# =============================================================================

import copy
import json
import os as _os
import random
import sys
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import polars as pl
import torch
from codecarbon import EmissionsTracker
from tqdm.auto import tqdm

from src.data.manager import DataManager
from src.rl.agents.actor_critic_policy import ActorCriticPolicy
from src.rl.envs.crypto_market_env_consolidated_reward import (
    CryptoMarketEnvConsolidatedReward, INITIAL_BALANCE, MAX_EPISODE_STEPS,
    steps_per_4h_for,
)
from src.rl.metrics import compute_sharpe, compute_max_drawdown

# Import sistema adaptatiu
# sys.path.insert(0, str(Path.cwd()))
from src.rl.meta_learning import (
    AdaptiveFOMAML,
    InnerConvergenceCriteria,
    OuterUpdateTrigger,
    MetaConvergenceCriteria,
)

warnings.filterwarnings('ignore')
print('Imports OK')
# Out:
# Imports OK

# %%
# =============================================================================
# CEL·LA 2 — CONFIGURACIÓ: SEED, DEVICE, PATHS
# =============================================================================

# Reproducibilitat
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {DEVICE}')

# CWD
_cwd = Path.cwd()
if not (_cwd / 'data' / 'processed').exists():
    _root = _cwd.parents[1]
    if (_root / 'data' / 'processed').exists():
        _os.chdir(_root)
        print(f'CWD -> {Path.cwd()}')

# ── SELECTOR: BASE AGENT (MODIFICAR AQUÍ) ────────────────────────────────────
USE_PRETRAINED = False  # True = _adj (ajusta checkpoint), False = _new (fresh init)

# Agents disponibles per meta-learning
AVAILABLE_AGENTS = {
    'ppo_pytorch_dense_final': 'checkpoints_dense/ppo_pytorch_dense_final.pt',
    'ppo_pytorch_sparse_final': 'checkpoints_sparse/ppo_pytorch_sparse_final.pt',
}

BASE_AGENT = 'ppo_pytorch_sparse_final'  # ← CANVIA AIXÒ per seleccionar checkpoint

if BASE_AGENT not in AVAILABLE_AGENTS:
    raise ValueError(f"BASE_AGENT desconegut: '{BASE_AGENT}'")

# ──────────────────────────────────────────────────────────────────────────────

# Paths
BEST_PARAMS_PATH = Path('checkpoints_sparse/ppo_best_params.json')
RESULTS  = Path('results_sparse') / '06s_ppo_fomaml_adaptive_new'
RESULTS.mkdir(parents=True, exist_ok=True)
CODECARBON_DIR = RESULTS / 'codecarbon'
CODECARBON_DIR.mkdir(parents=True, exist_ok=True)

# Variant naming: _adj si pre-trained, _new si fresh init
variant = '_adj' if USE_PRETRAINED else '_new'
META_CKPT = Path(f'checkpoints_sparse/ppo_fomaml_meta{variant}_adaptative.pt')

# Dades
TIMEFRAME = '60m'
STEPS_PER_WEEK = 7 * 24  # 168 passos/setmana a 60m

print(f'Selector: USE_PRETRAINED={USE_PRETRAINED}, BASE_AGENT={BASE_AGENT}')
print(f'Variant: {variant}')
print(f'Meta checkpoint: {META_CKPT.name}')
print(f'Paths OK')
# Out:
# Device: cuda
# CWD -> c:\Users\Xavier\S9_M2.981 - TFM\00_Documentacio\Activitats\Modul_3\quant_rl_trader
# Selector: USE_PRETRAINED=False, BASE_AGENT=ppo_pytorch_sparse_final
# Variant: _new
# Meta checkpoint: ppo_fomaml_meta_new_adaptative.pt
# Paths OK

# %%
# =============================================================================
# CEL·LA 3 — CRITERIS DE CONVERGÈNCIA (sistema adaptatiu)
# =============================================================================

# ── Inner Loop Convergence ───────────────────────────────────────────────────
inner_criteria = InnerConvergenceCriteria(
    min_steps=5_000,                    # Mínim d'steps abans d'avaluar
    max_steps=30_000,                   # Màxim (timeout per tasca)
    eval_every=2_000,                   # Avalua convergència cada 2k steps
    eval_episodes=5,                    # Episodis per avaluar sharpe
    
    # Convergència per performance
    target_sharpe=0.8,                  # Si sharpe >= 0.8 → convergit
    min_sharpe_improvement=0.3,         # Millora mínima des d'inici
    plateau_threshold=0.05,             # Millora <5% → plateau
    plateau_patience=3,                 # 3 evals sense millora → convergit
    
    # Convergència per gradients
    min_grad_norm=0.01,                 # Gradient massa petit → convergit
    max_grad_norm=10.0,                 # Gradient massa gran → divergència
    
    # Convergència per paràmetres
    max_param_distance=15.0,            # ||φ - θ|| massa gran → overfitting
)

# ── Outer Update Trigger ─────────────────────────────────────────────────────
outer_trigger = OuterUpdateTrigger(
    batch_size=5,                       # 5 tasques convergides → outer update
    max_time_seconds=300.0,             # O cada 5 min → outer update
    min_tasks=3,                        # Mínim 3 tasques per update vàlid
)

# ── Meta Convergence (ADAPTATIU segons _new vs _adj) ─────────────────────────
if USE_PRETRAINED:
    # MODE _adj: Model pre-entrenat busca meta-optimalitat
    # → NO target de performance (pot degradar temporalment)
    # → Només plateau detection amb més paciència
    meta_criteria = MetaConvergenceCriteria(
        max_meta_iters=500,
        eval_every=5,
        eval_episodes=25,
        
        target_val_sharpe=None,         # ← NO target absolut (accepta degradació)
        plateau_threshold=0.05,         # ← Més sensible a plateau (5%)
        plateau_patience=30,            # ← Més paciència (30 evals)
        min_val_sharpe=-999.0,          # ← No penalitza degradació
    )
    print('Meta criteria MODE: _adj (sense targets de performance)')
else:
    # MODE _new: Fresh init busca performance alta
    # → Target de performance absolut
    # → Menys paciència, vol arribar a sharpe alt
    meta_criteria = MetaConvergenceCriteria(
        max_meta_iters=500,
        eval_every=5,
        eval_episodes=25,
        
        target_val_sharpe=23.85,         # ← Target absolut (0.75 x Sharpe entrenament estàndard)
        plateau_threshold=0.1,          # ← Menys sensible (10%)
        plateau_patience=20,            # ← Menys paciència (20 evals)
        min_val_sharpe=0.5,             # ← Mínim acceptable (0.5)
    )
    print('Meta criteria MODE: _new (amb targets de performance)')

# ── FOMAML Hyperparameters ───────────────────────────────────────────────────
META_LR = 1e-4                          # Learning rate per outer update
SUPPORT_RATIO = 0.7                     # 70% support, 30% query
TASK_WEEKS = 12                         # Durada de cada tasca (12 setmanes)
TASK_STEPS = TASK_WEEKS * STEPS_PER_WEEK

# ── Adaptation (rolling-window test) ─────────────────────────────────────────
SUPPORT_WEEKS = 6
ADAPT_STEPS = 15_000
N_EVAL_WEEKS = 1

print('\nCriteris de convergència definits:')
print(f'  Inner: {inner_criteria.min_steps:,}-{inner_criteria.max_steps:,} steps, '
      f'target_sharpe={inner_criteria.target_sharpe}')
print(f'  Outer: batch={outer_trigger.batch_size}, timeout={outer_trigger.max_time_seconds}s')
print(f'  Meta:  max_iters={meta_criteria.max_meta_iters}, '
      f'target_val_sharpe={meta_criteria.target_val_sharpe}, '
      f'plateau_patience={meta_criteria.plateau_patience}')
print(f'  FOMAML: meta_lr={META_LR:.0e}, support_ratio={SUPPORT_RATIO}, '
      f'task_weeks={TASK_WEEKS} ({TASK_STEPS:,} files)')
# Out:
# Meta criteria MODE: _new (amb targets de performance)
#
# Criteris de convergència definits:
#   Inner: 5,000-30,000 steps, target_sharpe=0.8
#   Outer: batch=5, timeout=300.0s
#   Meta:  max_iters=500, target_val_sharpe=23.85, plateau_patience=20
#   FOMAML: meta_lr=1e-04, support_ratio=0.7, task_weeks=12 (2,016 files)

# %%
# =============================================================================
# CEL·LA 4 — CÀRREGA DE DADES
# =============================================================================

dm = DataManager(interval=TIMEFRAME, project_root=Path('.'))
FEATURE_COLS = dm.features
N_FEATURES   = len(FEATURE_COLS)

df_train, df_val, df_test = dm.load_all()
df_meta = pl.concat([df_train, df_val])

print(f'Train: {len(df_train):>8,}  ({df_train["timestamp"].min()} → {df_train["timestamp"].max()})')
print(f'Val:   {len(df_val):>8,}  ({df_val["timestamp"].min()} → {df_val["timestamp"].max()})')
print(f'Test:  {len(df_test):>8,}  ({df_test["timestamp"].min()} → {df_test["timestamp"].max()})')
print(f'Meta:  {len(df_meta):>8,}')
print(f'\nTasks possibles (TASK_WEEKS={TASK_WEEKS}): '
      f'{max(0, len(df_meta) - TASK_STEPS):,} finestres')
# Out:
# Train:   43,763  (2018-01-01 00:00:00 → 2022-12-31 23:00:00)
# Val:      8,759  (2023-01-01 00:00:00 → 2023-12-31 23:00:00)
# Test:    17,500  (2024-01-01 00:00:00 → 2025-12-31 00:00:00)
# Meta:    52,522
#
# Tasks possibles (TASK_WEEKS=12): 50,506 finestres

# %%
# =============================================================================
# CEL·LA 5 — FACTORIA D'ENTORN + VERIFICACIÓ
# =============================================================================

def make_env(df: pl.DataFrame, **kwargs) -> CryptoMarketEnvConsolidatedReward:
    '''Factoria per crear l'entorn SPARSE (consolidated reward) amb FEATURE_COLS.'''
    return CryptoMarketEnvConsolidatedReward(
        df=df,
        feature_cols=FEATURE_COLS,
        steps_per_4h=steps_per_4h_for(TIMEFRAME),
        **kwargs,
    )

_env = make_env(df_train)
_obs, _info = _env.reset(seed=SEED)
OBS_DIM   = _env.observation_space.shape[0]
N_ACTIONS = _env.action_space.n
del _env

print(f'make_env OK | OBS_DIM={OBS_DIM}  N_ACTIONS={N_ACTIONS}')
# Out:
# make_env OK | OBS_DIM=71  N_ACTIONS=4

# %%
# =============================================================================
# CEL·LA 6 — CARREGA PPO CONFIG + AGENT BASE (fresh init O pre-entrenat)
# =============================================================================

# ── Hiperparàmetres PPO (defaults) ───────────────────────────────────────────
DEFAULT_PPO_CFG = {
    'learning_rate': 3e-4,
    'n_steps': 2048,
    'batch_size': 256,
    'n_epochs': 5,
    'gamma': 0.99,
    'gae_lambda': 0.95,
    'clip_range': 0.20,
    'ent_coef': 0.01,
    'vf_coef': 0.5,
    'max_grad_norm': 0.5,
    'net_arch': [128, 64],
}

# ── Carrega best params si existeix ──────────────────────────────────────────
if BEST_PARAMS_PATH.exists():
    print(f'Carregant best params des de {BEST_PARAMS_PATH} ...')
    with open(BEST_PARAMS_PATH, encoding='utf-8') as f:
        _bp_data = json.load(f)
    _bp = _bp_data['best_params']
    
    ppo_config = {
        'learning_rate': float(_bp.get('learning_rate', DEFAULT_PPO_CFG['learning_rate'])),
        'n_steps': int(_bp.get('n_steps', DEFAULT_PPO_CFG['n_steps'])),
        'batch_size': int(_bp.get('batch_size', DEFAULT_PPO_CFG['batch_size'])),
        'n_epochs': int(_bp.get('n_epochs', DEFAULT_PPO_CFG['n_epochs'])),
        'gamma': float(_bp.get('gamma', DEFAULT_PPO_CFG['gamma'])),
        'gae_lambda': float(_bp.get('gae_lambda', DEFAULT_PPO_CFG['gae_lambda'])),
        'clip_range': float(_bp.get('clip_range', DEFAULT_PPO_CFG['clip_range'])),
        'ent_coef': float(_bp.get('ent_coef', DEFAULT_PPO_CFG['ent_coef'])),
        'vf_coef': float(_bp.get('vf_coef', DEFAULT_PPO_CFG['vf_coef'])),
        'max_grad_norm': float(DEFAULT_PPO_CFG['max_grad_norm']),
        'net_arch': DEFAULT_PPO_CFG['net_arch'],
    }
    print(f'  Best params carregats: lr={ppo_config["learning_rate"]:.2e}  '
          f'n_steps={ppo_config["n_steps"]}  batch={ppo_config["batch_size"]}  '
          f'epochs={ppo_config["n_epochs"]}')
    print(f'  trial={_bp_data["best_trial"]}  sharpe={_bp_data["final_sharpe"]:.2f}  '
          f'ret={_bp_data["final_return"]:.2f}%')
else:
    print(f'AVÍS: {BEST_PARAMS_PATH} no trobat → usar DEFAULT_PPO_CFG')
    ppo_config = DEFAULT_PPO_CFG

# ── Crea/Carrega agent base ──────────────────────────────────────────────────
PRETRAINED_CKPT = Path(AVAILABLE_AGENTS[BASE_AGENT]) if USE_PRETRAINED else None

if USE_PRETRAINED and PRETRAINED_CKPT and PRETRAINED_CKPT.exists():
    print(f'\nCarregant PRE-ENTRENAT: {PRETRAINED_CKPT}')
    base_policy = ActorCriticPolicy.load(str(PRETRAINED_CKPT), device=DEVICE)
    base_policy.train()
    n_params = base_policy.count_params()
    print(f'  Checkpoint carregat: {n_params:,} params')
else:
    if USE_PRETRAINED:
        print(f'\nAVÍS: Checkpoint {PRETRAINED_CKPT} no trobat → fresh init')
    else:
        print(f'\nCreant agent base (fresh init) ...')
    
    torch.manual_seed(SEED)
    base_policy = ActorCriticPolicy(
        OBS_DIM, N_ACTIONS, ppo_config['net_arch']
    ).to(DEVICE)
    base_policy.train()
    n_params = base_policy.count_params()
    print(f'  Base policy: {n_params:,} params')

print(f'PPO config: {ppo_config}')
# Out:
# Carregant best params des de checkpoints_sparse\ppo_best_params.json ...
#   Best params carregats: lr=1.16e-04  n_steps=2048  batch=64  epochs=8
#   trial=TPE_trial041  sharpe=32.68  ret=163.96%
#
# Creant agent base (fresh init) ...
#   Base policy: 35,269 params
# PPO config: {'learning_rate': 0.00011555223044386541, 'n_steps': 2048, 'batch_size': 64, 'n_epochs': 8, 'gamma': 0.9953571143574206, 'gae_lambda': 0.900504443231778, 'clip_range': 0.14644131814048134, 'ent_coef': 0.04964458040208173, 'vf_coef': 0.3365887943694232, 'max_grad_norm': 0.5, 'net_arch': [128, 64]}

# %%
# =============================================================================
# CEL·LA 7 — TASK SAMPLER
# =============================================================================

rng_meta = np.random.default_rng(SEED)

def sample_task() -> pl.DataFrame:
    '''Mostra una finestra aleatòria de TASK_STEPS files de df_meta.'''
    max_start = len(df_meta) - TASK_STEPS
    if max_start <= 0:
        return df_meta
    start = int(rng_meta.integers(0, max_start))
    return df_meta[start: start + TASK_STEPS]

# Test
_task = sample_task()
print(f'sample_task OK  → {len(_task)} files  (TASK_STEPS={TASK_STEPS})')
print(f'Tasks possibles: {max(0, len(df_meta) - TASK_STEPS):,}')
# Out:
# sample_task OK  → 2016 files  (TASK_STEPS=2016)
# Tasks possibles: 50,506

# %%
# =============================================================================
# CEL·LA 8 — CREA SISTEMA FOMAML ADAPTATIU
# =============================================================================

# n_steps del PPO base és massa gran per a finestres de tasca curtes
# (TASK_STEPS=2016 → support=1411 files < n_steps*2 → totes les tasques es descarten).
# Per meta-learning, l'inner loop fa pocs passos sobre una finestra curta;
# n_steps=512 és suficient per capturar gradients locals sense excedir el support.
meta_ppo_config = {**ppo_config, 'n_steps': 512}

fomaml = AdaptiveFOMAML(
    inner_criteria=inner_criteria,
    outer_trigger=outer_trigger,
    meta_criteria=meta_criteria,
    device=DEVICE,
    ppo_config=meta_ppo_config,
    meta_lr=META_LR,
    support_ratio=SUPPORT_RATIO,
    tensorboard_log=str(RESULTS / 'tensorboard'),
)

print('AdaptiveFOMAML system creat.')
print(f'  Inner: {inner_criteria.min_steps:,}-{inner_criteria.max_steps:,} steps')
print(f'  Outer: batch={outer_trigger.batch_size}')
print(f'  Meta:  max_iters={meta_criteria.max_meta_iters}')
print(f'  PPO n_steps (meta): {meta_ppo_config["n_steps"]} (base: {ppo_config["n_steps"]})')
print(f'  TensorBoard: {RESULTS / "tensorboard"}')
# Out:
# AdaptiveFOMAML system creat.
#   Inner: 5,000-30,000 steps
#   Outer: batch=5
#   Meta:  max_iters=500
#   PPO n_steps (meta): 512 (base: 2048)
#   TensorBoard: results_sparse\06s_ppo_fomaml_adaptive_new\tensorboard

# %%
# =============================================================================
# CEL·LA 9 — RUN ADAPTIVE META-TRAINING
# =============================================================================

import time as _time

if META_CKPT.exists():
    print(f'Carregant meta-checkpoint des de {META_CKPT} ...')
    meta_policy = ActorCriticPolicy.load(META_CKPT, device=DEVICE)
    meta_policy.train()
    _d = torch.load(str(META_CKPT), map_location=DEVICE, weights_only=False)
    meta_history = _d.get('meta_history', [])
    inner_diagnostics = _d.get('inner_diagnostics', [])
    emissions_meta = _d.get('emissions_meta_g_co2', 0.0)
    train_time_s = _d.get('train_time_s', 0.0)
    total_tasks = _d.get('total_tasks_processed', 0)
    total_meta_iters = _d.get('total_meta_iters', 0)
    best_val_sharpe = _d.get('best_val_sharpe', -np.inf)
    print(f'  Meta-checkpoint carregat.')
    print(f'  Meta iters: {total_meta_iters}  Tasks: {total_tasks}  '
          f'Best val sharpe: {best_val_sharpe:+.4f}')
else:
    print(f'Iniciant FOMAML ADAPTATIU meta-entrenament ...')
    print(f'Sistema pararà automàticament quan convergeixin inner loops i meta-agent.\n')

    t0 = _time.time()
    tracker = EmissionsTracker(
        project_name='06s_ppo_fomaml_adaptive',
        output_dir=str(CODECARBON_DIR),
        log_level='error'
    )
    tracker.start()

    result = fomaml.meta_train(
        base_policy=copy.deepcopy(base_policy),
        task_sampler=sample_task,
        env_factory=make_env,
        val_df=df_val,
        verbose=True,
        checkpoint_path=META_CKPT,
        checkpoint_every=50,
    )

    emissions_meta = (tracker.stop() or 0.0) * 1000  # grams CO2
    train_time_s = _time.time() - t0

    meta_policy = result['meta_policy']
    meta_history = result['meta_history']
    inner_diagnostics = result['inner_diagnostics']
    total_tasks = result['total_tasks_processed']
    total_meta_iters = result['total_meta_iters']
    best_val_sharpe = result['best_val_sharpe']

    print(f'\n' + '='*60)
    print(f'Meta-entrenament completat: {train_time_s/60:.1f} min')
    print(f'  Total meta-iters: {total_meta_iters}')
    print(f'  Total tasks processades: {total_tasks}')
    print(f'  Best val sharpe: {best_val_sharpe:+.4f}')
    print(f'  Emissions meta: {emissions_meta:.2f} g CO2eq')
    print('='*60)

    # Desa checkpoint
    META_CKPT.parent.mkdir(parents=True, exist_ok=True)
    torch.save({
        'policy_state_dict': meta_policy.state_dict(),
        'hyperparams': ppo_config,
        'meta_history': meta_history,
        'inner_diagnostics': inner_diagnostics,
        'emissions_meta_g_co2': emissions_meta,
        'train_time_s': train_time_s,
        'total_tasks_processed': total_tasks,
        'total_meta_iters': total_meta_iters,
        'best_val_sharpe': best_val_sharpe,
        'inner_criteria': inner_criteria.__dict__,
        'outer_trigger': outer_trigger.__dict__,
        'meta_criteria': meta_criteria.__dict__,
    }, META_CKPT)
    print(f'\nMeta-checkpoint desat: {META_CKPT}')

if meta_history:
    best = max(meta_history, key=lambda h: h['val_sharpe'])
    print(f'\nMillor val: Sharpe={best["val_sharpe"]:+.4f}  '
          f'Ret={best["val_return"]:+.2f}%  iter {best["meta_iter"]}')
# Out:
# [codecarbon WARNING @ 08:24:32] Multiple instances of codecarbon are allowed to run at the same time.
# Iniciant FOMAML ADAPTATIU meta-entrenament ...
# Sistema pararà automàticament quan convergeixin inner loops i meta-agent.
#
#   Task 1: target_sharpe_reached (12,288 steps, sharpe=+533953366.64)
#   Task 2: SKIP (gradient_explosion)
#   Task 3: target_sharpe_reached (6,144 steps, sharpe=+56834149.04)
#   Task 4: target_sharpe_reached (6,144 steps, sharpe=+1742841044.85)
#   Batch timeout: 3 tasks in 386.7s
#
# Meta-iter 1: Outer update (FOMAML) amb 3 tasques
#   Task 5: target_sharpe_reached (16,384 steps, sharpe=+1289909381.42)
#   Task 6: performance_plateau (16,384 steps, sharpe=-1540363026.43)
#   Task 7: FAIL (max_steps_timeout)
#   Task 8: target_sharpe_reached (16,384 steps, sharpe=+2651919702.46)
#   Batch timeout: 3 tasks in 929.3s
#
# Meta-iter 2: Outer update (FOMAML) amb 3 tasques
#   Task 9: performance_plateau (16,384 steps, sharpe=-1098967251.40)
#   Task 10: target_sharpe_reached (14,336 steps, sharpe=+95522458.98)
#   Task 11: FAIL (max_steps_timeout)
#   Task 12: target_sharpe_reached (26,112 steps, sharpe=+3441326693.22)
#   Batch timeout: 3 tasks in 1106.1s
#
# Meta-iter 3: Outer update (FOMAML) amb 3 tasques
#   Task 13: FAIL (max_steps_timeout)
#   Task 14: FAIL (max_steps_timeout)
#   Task 15: performance_plateau (20,480 steps, sharpe=-794473719.63)
#   Task 16: target_sharpe_reached (30,000 steps, sharpe=+3796106891.63)
#   Task 17: target_sharpe_reached (8,192 steps, sharpe=+4076989843.46)
#   Batch timeout: 3 tasks in 1277.4s
#
# Meta-iter 4: Outer update (FOMAML) amb 3 tasques
#   Task 18: SKIP (gradient_explosion)
#   Task 19: target_sharpe_reached (6,144 steps, sharpe=+402022513.89)
#   Task 20: target_sharpe_reached (26,112 steps, sharpe=+8932153912.61)
#   Task 21: target_sharpe_reached (6,144 steps, sharpe=+2377123898.56)
#   Batch timeout: 3 tasks in 591.9s
#
# Meta-iter 5: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-32.6543 ret=-20.10% best=-32.6543 [✓ NEW BEST]
#
#   Task 22: target_sharpe_reached (10,240 steps, sharpe=+324788944.58)
#   Task 23: target_sharpe_reached (6,144 steps, sharpe=+53043822.99)
#   Task 24: SKIP (gradient_explosion)
#   Task 25: target_sharpe_reached (8,192 steps, sharpe=+1513919876.75)
#   Batch timeout: 3 tasks in 317.7s
#
# Meta-iter 6: Outer update (FOMAML) amb 3 tasques
#   Task 26: SKIP (gradient_explosion)
#   Task 27: target_sharpe_reached (10,240 steps, sharpe=+1503203845.38)
#   Task 28: FAIL (max_steps_timeout)
#   Task 29: target_sharpe_reached (12,288 steps, sharpe=+2482729572.70)
#   Task 30: target_sharpe_reached (10,240 steps, sharpe=+340559299.92)
#   Batch timeout: 3 tasks in 725.8s
#
# Meta-iter 7: Outer update (FOMAML) amb 3 tasques
#   Task 31: target_sharpe_reached (20,480 steps, sharpe=+9105270769.26)
#   Task 32: target_sharpe_reached (6,144 steps, sharpe=+367317955.09)
#   Task 33: FAIL (max_steps_timeout)
#   Task 34: SKIP (gradient_explosion)
#   Task 35: target_sharpe_reached (6,144 steps, sharpe=+2109309175.31)
#   Batch timeout: 3 tasks in 651.7s
#
# Meta-iter 8: Outer update (FOMAML) amb 3 tasques
#   Task 36: target_sharpe_reached (10,240 steps, sharpe=+985922519.55)
#   Task 37: target_sharpe_reached (24,064 steps, sharpe=+1217340201.86)
#   Task 38: target_sharpe_reached (6,144 steps, sharpe=+2676613557.38)
#   Batch timeout: 3 tasks in 448.1s
#
# Meta-iter 9: Outer update (FOMAML) amb 3 tasques
#   Task 39: FAIL (max_steps_timeout)
#   Task 40: SKIP (gradient_explosion)
#   Task 41: SKIP (gradient_explosion)
#   Task 42: FAIL (max_steps_timeout)
#   Task 43: performance_plateau (14,336 steps, sharpe=-1118640218.86)
#   Task 44: FAIL (max_steps_timeout)
#   Task 45: target_sharpe_reached (8,192 steps, sharpe=+188778591.48)
#   Task 46: performance_plateau (26,112 steps, sharpe=-184287675.35)
#   Batch timeout: 3 tasks in 1684.8s
#
# Meta-iter 10: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-15.9751 ret=-19.66% best=-15.9751 [✓ NEW BEST]
#
#   Task 47: target_sharpe_reached (12,288 steps, sharpe=+883272483.17)
#   Task 48: target_sharpe_reached (6,144 steps, sharpe=+3340338186.22)
#   Task 49: FAIL (max_steps_timeout)
#   Task 50: target_sharpe_reached (8,192 steps, sharpe=+2221248588.87)
#   Batch timeout: 3 tasks in 629.8s
#
# Meta-iter 11: Outer update (FOMAML) amb 3 tasques
#   Task 51: target_sharpe_reached (6,144 steps, sharpe=+3024708520.39)
#   Task 52: target_sharpe_reached (20,480 steps, sharpe=+2357793515.70)
#   Task 53: target_sharpe_reached (6,144 steps, sharpe=+3962930568.21)
#   Batch timeout: 3 tasks in 320.4s
#
# Meta-iter 12: Outer update (FOMAML) amb 3 tasques
#   Task 54: SKIP (gradient_explosion)
#   Task 55: target_sharpe_reached (6,144 steps, sharpe=+1261702517.31)
#   Task 56: target_sharpe_reached (6,144 steps, sharpe=+472249393.23)
#   Task 57: SKIP (gradient_explosion)
#   Task 58: target_sharpe_reached (14,336 steps, sharpe=+4071068447.96)
#   Batch timeout: 3 tasks in 368.2s
#
# Meta-iter 13: Outer update (FOMAML) amb 3 tasques
#   Task 59: target_sharpe_reached (6,144 steps, sharpe=+261263319.52)
#   Task 60: performance_plateau (30,000 steps, sharpe=-635362929.21)
#   Task 61: target_sharpe_reached (6,144 steps, sharpe=+4673555890.36)
#   Batch timeout: 3 tasks in 495.7s
#
# Meta-iter 14: Outer update (FOMAML) amb 3 tasques
#   Task 62: target_sharpe_reached (8,192 steps, sharpe=+2486513969.87)
#   Task 63: target_sharpe_reached (6,144 steps, sharpe=+281083865.86)
#   Task 64: performance_plateau (20,480 steps, sharpe=-179952980.41)
#   Batch timeout: 3 tasks in 397.5s
#
# Meta-iter 15: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-40.3968 ret=-20.09% best=-15.9751 [plateau 1/20]
#
#   Task 65: FAIL (max_steps_timeout)
#   Task 66: target_sharpe_reached (6,144 steps, sharpe=+131353221.63)
#   Task 67: target_sharpe_reached (6,144 steps, sharpe=+2394955065.20)
#   Task 68: target_sharpe_reached (12,288 steps, sharpe=+1157118634.52)
#   Batch timeout: 3 tasks in 582.7s
#
# Meta-iter 16: Outer update (FOMAML) amb 3 tasques
#   Task 69: target_sharpe_reached (10,240 steps, sharpe=+1090051377.39)
#   Task 70: FAIL (max_steps_timeout)
#   Task 71: performance_plateau (16,384 steps, sharpe=+0.00)
#   Task 72: target_sharpe_reached (8,192 steps, sharpe=+2653314881.94)
#   Batch timeout: 3 tasks in 691.3s
#
# Meta-iter 17: Outer update (FOMAML) amb 3 tasques
#   Task 73: target_sharpe_reached (10,240 steps, sharpe=+3537484533.20)
#   Task 74: performance_plateau (18,432 steps, sharpe=-199368.78)
#   Task 75: target_sharpe_reached (8,192 steps, sharpe=+4684879605.97)
#   Batch timeout: 3 tasks in 359.3s
#
# Meta-iter 18: Outer update (FOMAML) amb 3 tasques
#   Task 76: target_sharpe_reached (26,112 steps, sharpe=+429751777.32)
#   Task 77: target_sharpe_reached (16,384 steps, sharpe=+2896781728.30)
#   Task 78: target_sharpe_reached (6,144 steps, sharpe=+3087555873.82)
#   Batch timeout: 3 tasks in 532.2s
#
# Meta-iter 19: Outer update (FOMAML) amb 3 tasques
#   Task 79: target_sharpe_reached (6,144 steps, sharpe=+3128508150.71)
#   Task 80: performance_plateau (14,336 steps, sharpe=+0.00)
#   Task 81: performance_plateau (22,016 steps, sharpe=-12115738.23)
#   Batch timeout: 3 tasks in 391.7s
#
# Meta-iter 20: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-17.7054 ret=-19.62% best=-15.9751 [plateau 2/20]
#
#   Task 82: target_sharpe_reached (14,336 steps, sharpe=+698096201.35)
#   Task 83: target_sharpe_reached (8,192 steps, sharpe=+177439234.94)
#   Task 84: performance_plateau (26,112 steps, sharpe=-884951334.92)
#   Batch timeout: 3 tasks in 491.0s
#
# Meta-iter 21: Outer update (FOMAML) amb 3 tasques
#   Task 85: FAIL (max_steps_timeout)
#   Task 86: target_sharpe_reached (10,240 steps, sharpe=+195624870.90)
#   Task 87: SKIP (gradient_explosion)
#   Task 88: target_sharpe_reached (6,144 steps, sharpe=+58694074.40)
#   Task 89: FAIL (max_steps_timeout)
#   Task 90: target_sharpe_reached (8,192 steps, sharpe=+367086784.53)
#   Batch timeout: 3 tasks in 864.4s
#
# Meta-iter 22: Outer update (FOMAML) amb 3 tasques
#   Task 91: target_sharpe_reached (6,144 steps, sharpe=+580673698.27)
#   Task 92: target_sharpe_reached (18,432 steps, sharpe=+104306379.15)
#   Task 93: target_sharpe_reached (6,144 steps, sharpe=+3075647937.38)
#   Batch timeout: 3 tasks in 342.3s
#
# Meta-iter 23: Outer update (FOMAML) amb 3 tasques
#   Task 94: target_sharpe_reached (6,144 steps, sharpe=+2781782943.68)
#   Task 95: FAIL (max_steps_timeout)
#   Task 96: target_sharpe_reached (6,144 steps, sharpe=+3432828920.85)
#   Task 97: target_sharpe_reached (8,192 steps, sharpe=+883180641.89)
#   Batch timeout: 3 tasks in 558.0s
#
# Meta-iter 24: Outer update (FOMAML) amb 3 tasques
#   Task 98: SKIP (gradient_explosion)
#   Task 99: target_sharpe_reached (10,240 steps, sharpe=+3729750574.75)
#   Task 100: target_sharpe_reached (22,016 steps, sharpe=+1251807564.09)
#   Task 101: target_sharpe_reached (8,192 steps, sharpe=+2564516798.14)
#   Batch timeout: 3 tasks in 455.8s
#
# Meta-iter 25: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-12.1818 ret=-19.84% best=-12.1818 [✓ NEW BEST]
#
#   Task 102: target_sharpe_reached (16,384 steps, sharpe=+644631525.85)
#   Task 103: SKIP (gradient_explosion)
#   Task 104: target_sharpe_reached (28,160 steps, sharpe=+889648390.49)
#   Task 105: target_sharpe_reached (16,384 steps, sharpe=+1346328401.57)
#   Batch timeout: 3 tasks in 657.4s
#
# Meta-iter 26: Outer update (FOMAML) amb 3 tasques
#   Task 106: FAIL (max_steps_timeout)
#   Task 107: target_sharpe_reached (6,144 steps, sharpe=+2116902368.07)
#   Task 108: target_sharpe_reached (8,192 steps, sharpe=+5606080093.68)
#   Task 109: target_sharpe_reached (6,144 steps, sharpe=+208934353.89)
#   Batch timeout: 3 tasks in 537.0s
#
# Meta-iter 27: Outer update (FOMAML) amb 3 tasques
#   Task 110: target_sharpe_reached (6,144 steps, sharpe=+1601603998.11)
#   Task 111: performance_plateau (30,000 steps, sharpe=-422915810.61)
#   Task 112: FAIL (max_steps_timeout)
#   Task 113: target_sharpe_reached (18,432 steps, sharpe=+391939850.46)
#   Batch timeout: 3 tasks in 886.1s
#
# Meta-iter 28: Outer update (FOMAML) amb 3 tasques
#   Task 114: target_sharpe_reached (30,000 steps, sharpe=+6185965444.28)
#   Task 115: SKIP (gradient_explosion)
#   Task 116: target_sharpe_reached (6,144 steps, sharpe=+89251147.53)
#   Task 117: target_sharpe_reached (6,144 steps, sharpe=+3692043498.24)
#   Batch timeout: 3 tasks in 492.3s
#
# Meta-iter 29: Outer update (FOMAML) amb 3 tasques
#   Task 118: target_sharpe_reached (6,144 steps, sharpe=+2953592398.56)
#   Task 119: target_sharpe_reached (10,240 steps, sharpe=+797701485.35)
#   Task 120: target_sharpe_reached (12,288 steps, sharpe=+285753778.36)
#   Task 121: target_sharpe_reached (6,144 steps, sharpe=+3277309829.72)
#   Batch timeout: 4 tasks in 330.9s
#
# Meta-iter 30: Outer update (FOMAML) amb 4 tasques
#   Val: sharpe=-17.2784 ret=-20.05% best=-12.1818 [plateau 1/20]
#
#   Task 122: performance_plateau (22,016 steps, sharpe=-889704827.62)
#   Task 123: target_sharpe_reached (8,192 steps, sharpe=+5707945313.63)
#   Task 124: target_sharpe_reached (6,144 steps, sharpe=+2876271670.15)
#   Batch timeout: 3 tasks in 356.2s
#
# Meta-iter 31: Outer update (FOMAML) amb 3 tasques
#   Task 125: FAIL (max_steps_timeout)
#   Task 126: FAIL (max_steps_timeout)
#   Task 127: target_sharpe_reached (22,016 steps, sharpe=+2184927060.67)
#   Task 128: target_sharpe_reached (16,384 steps, sharpe=+3532660043.50)
#   Task 129: FAIL (max_steps_timeout)
#   Task 130: target_sharpe_reached (22,016 steps, sharpe=+3251241834.06)
#   Batch timeout: 3 tasks in 1581.8s
#
# Meta-iter 32: Outer update (FOMAML) amb 3 tasques
#   Task 131: FAIL (max_steps_timeout)
#   Task 132: target_sharpe_reached (20,480 steps, sharpe=+704702007.91)
#   Task 133: FAIL (max_steps_timeout)
#   Task 134: target_sharpe_reached (22,016 steps, sharpe=+1173380191.67)
#   Task 135: FAIL (max_steps_timeout)
#   Task 136: FAIL (max_steps_timeout)
#   Task 137: SKIP (gradient_explosion)
#   Task 138: target_sharpe_reached (8,192 steps, sharpe=+786525468.00)
#   Batch timeout: 3 tasks in 2107.0s
#
# Meta-iter 33: Outer update (FOMAML) amb 3 tasques
#   Task 139: FAIL (max_steps_timeout)
#   Task 140: target_sharpe_reached (6,144 steps, sharpe=+2315390040.17)
#   Task 141: target_sharpe_reached (6,144 steps, sharpe=+9947864271.05)
#   Task 142: target_sharpe_reached (6,144 steps, sharpe=+1963933165.38)
#   Batch timeout: 3 tasks in 590.2s
#
# Meta-iter 34: Outer update (FOMAML) amb 3 tasques
#   Task 143: performance_plateau (26,112 steps, sharpe=-259486973.60)
#   Task 144: target_sharpe_reached (10,240 steps, sharpe=+2931509626.47)
#   Task 145: target_sharpe_reached (8,192 steps, sharpe=+2589632348.50)
#   Batch timeout: 3 tasks in 609.9s
#
# Meta-iter 35: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-16.8532 ret=-19.70% best=-12.1818 [plateau 2/20]
#
#   Task 146: SKIP (gradient_explosion)
#   Task 147: target_sharpe_reached (6,144 steps, sharpe=+5006619813.01)
#   Task 148: target_sharpe_reached (12,288 steps, sharpe=+1108512191.62)
#   Task 149: SKIP (gradient_explosion)
#   Task 150: FAIL (max_steps_timeout)
#   Task 151: target_sharpe_reached (6,144 steps, sharpe=+1786418652.97)
#   Batch timeout: 3 tasks in 973.1s
#
# Meta-iter 36: Outer update (FOMAML) amb 3 tasques
#   Task 152: FAIL (max_steps_timeout)
#   Task 153: target_sharpe_reached (6,144 steps, sharpe=+15669473.89)
#   Task 154: target_sharpe_reached (6,144 steps, sharpe=+2057584790.97)
#   Task 155: target_sharpe_reached (6,144 steps, sharpe=+931910823.82)
#   Batch timeout: 3 tasks in 641.9s
#
# Meta-iter 37: Outer update (FOMAML) amb 3 tasques
#   Task 156: target_sharpe_reached (14,336 steps, sharpe=+2905036896.79)
#   Task 157: FAIL (max_steps_timeout)
#   Task 158: target_sharpe_reached (6,144 steps, sharpe=+6902191975.00)
#   Task 159: SKIP (gradient_explosion)
#   Task 160: FAIL (max_steps_timeout)
#   Task 161: target_sharpe_reached (12,288 steps, sharpe=+2059925937.84)
#   Batch timeout: 3 tasks in 1331.0s
#
# Meta-iter 38: Outer update (FOMAML) amb 3 tasques
#   Task 162: performance_plateau (18,432 steps, sharpe=-563841389.48)
#   Task 163: SKIP (gradient_explosion)
#   Task 164: target_sharpe_reached (8,192 steps, sharpe=+807345819.12)
#   Task 165: target_sharpe_reached (6,144 steps, sharpe=+2127255553.06)
#   Batch timeout: 3 tasks in 675.0s
#
# Meta-iter 39: Outer update (FOMAML) amb 3 tasques
#   Task 166: target_sharpe_reached (6,144 steps, sharpe=+433905512.97)
#   Task 167: target_sharpe_reached (12,288 steps, sharpe=+138664911.91)
#   Task 168: target_sharpe_reached (6,144 steps, sharpe=+1222566727.75)
#   Batch timeout: 3 tasks in 309.5s
#
# Meta-iter 40: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-18.5225 ret=-19.80% best=-12.1818 [plateau 3/20]
#
#   Task 169: target_sharpe_reached (6,144 steps, sharpe=+2294466475.24)
#   Task 170: FAIL (max_steps_timeout)
#   Task 171: SKIP (gradient_explosion)
#   Task 172: SKIP (gradient_explosion)
#   Task 173: target_sharpe_reached (18,432 steps, sharpe=+429585663.24)
#   Task 174: FAIL (max_steps_timeout)
#   Task 175: performance_plateau (14,336 steps, sharpe=-809986769.45)
#   Batch timeout: 3 tasks in 1608.9s
#
# Meta-iter 41: Outer update (FOMAML) amb 3 tasques
#   Task 176: SKIP (gradient_explosion)
#   Task 177: FAIL (max_steps_timeout)
#   Task 178: target_sharpe_reached (20,480 steps, sharpe=+86677359.54)
#   Task 179: target_sharpe_reached (18,432 steps, sharpe=+7121737196.94)
#   Task 180: performance_plateau (16,384 steps, sharpe=+0.00)
#   Batch timeout: 3 tasks in 1299.3s
#
# Meta-iter 42: Outer update (FOMAML) amb 3 tasques
#   Task 181: SKIP (gradient_explosion)
#   Task 182: target_sharpe_reached (6,144 steps, sharpe=+9401821179.53)
#   Task 183: FAIL (max_steps_timeout)
#   Task 184: target_sharpe_reached (6,144 steps, sharpe=+12733770023.82)
#   Task 185: target_sharpe_reached (10,240 steps, sharpe=+599137176.97)
#   Batch timeout: 3 tasks in 751.9s
#
# Meta-iter 43: Outer update (FOMAML) amb 3 tasques
#   Task 186: SKIP (gradient_explosion)
#   Task 187: SKIP (gradient_explosion)
#   Task 188: target_sharpe_reached (8,192 steps, sharpe=+3381031525.54)
#   Task 189: target_sharpe_reached (14,336 steps, sharpe=+735502943.10)
#   Task 190: FAIL (max_steps_timeout)
#   Task 191: target_sharpe_reached (20,480 steps, sharpe=+424789110.74)
#   Batch timeout: 3 tasks in 1362.3s
#
# Meta-iter 44: Outer update (FOMAML) amb 3 tasques
#   Task 192: FAIL (max_steps_timeout)
#   Task 193: performance_plateau (18,432 steps, sharpe=-1026072257.33)
#   Task 194: target_sharpe_reached (10,240 steps, sharpe=+1054612682.27)
#   Task 195: target_sharpe_reached (10,240 steps, sharpe=+1268625.92)
#   Batch timeout: 3 tasks in 863.9s
#
# Meta-iter 45: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-17.9567 ret=-19.52% best=-12.1818 [plateau 4/20]
#
#   Task 196: target_sharpe_reached (10,240 steps, sharpe=+1385368678.31)
#   Task 197: FAIL (max_steps_timeout)
#   Task 198: target_sharpe_reached (10,240 steps, sharpe=+2663038924.38)
#   Task 199: target_sharpe_reached (6,144 steps, sharpe=+705462756.76)
#   Batch timeout: 3 tasks in 861.0s
#
# Meta-iter 46: Outer update (FOMAML) amb 3 tasques
#   Task 200: target_sharpe_reached (8,192 steps, sharpe=+1585092129.27)
#   Task 201: performance_plateau (14,336 steps, sharpe=-1389402056.92)
#   Task 202: target_sharpe_reached (6,144 steps, sharpe=+9783444090.43)
#   Batch timeout: 3 tasks in 403.5s
#
# Meta-iter 47: Outer update (FOMAML) amb 3 tasques
#   Task 203: FAIL (max_steps_timeout)
#   Task 204: FAIL (max_steps_timeout)
#   Task 205: SKIP (gradient_explosion)
#   Task 206: target_sharpe_reached (14,336 steps, sharpe=+2234082314.18)
#   Task 207: performance_plateau (16,384 steps, sharpe=-1894844342.19)
#   Task 208: FAIL (max_steps_timeout)
#   Task 209: FAIL (max_steps_timeout)
#   Task 210: SKIP (gradient_explosion)
#   Task 211: SKIP (gradient_explosion)
#   Task 212: performance_plateau (22,016 steps, sharpe=-1601594421.22)
#   Batch timeout: 3 tasks in 2845.2s
#
# Meta-iter 48: Outer update (FOMAML) amb 3 tasques
#   Task 213: target_sharpe_reached (6,144 steps, sharpe=+732326670.73)
#   Task 214: target_sharpe_reached (6,144 steps, sharpe=+2806602295.32)
#   Task 215: target_sharpe_reached (28,160 steps, sharpe=+42773197.98)
#   Batch timeout: 3 tasks in 497.4s
#
# Meta-iter 49: Outer update (FOMAML) amb 3 tasques
#   Task 216: SKIP (gradient_explosion)
#   Task 217: target_sharpe_reached (6,144 steps, sharpe=+181372631.81)
#   Task 218: performance_plateau (20,480 steps, sharpe=+0.00)
#   Task 219: FAIL (max_steps_timeout)
#   Task 220: target_sharpe_reached (8,192 steps, sharpe=+3561087479.33)
#   Batch timeout: 3 tasks in 1100.2s
#
# Meta-iter 50: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-25.4521 ret=-20.28% best=-12.1818 [plateau 5/20]
#
#   [ckpt] Desat checkpoint @ iter 50 → ppo_fomaml_meta_new_adaptative.pt
#   Task 221: target_sharpe_reached (8,192 steps, sharpe=+56288258.00)
#   Task 222: performance_plateau (20,480 steps, sharpe=+0.00)
#   Task 223: target_sharpe_reached (22,016 steps, sharpe=+3419767426.24)
#   Batch timeout: 3 tasks in 754.1s
#
# Meta-iter 51: Outer update (FOMAML) amb 3 tasques
#   Task 224: FAIL (max_steps_timeout)
#   Task 225: FAIL (max_steps_timeout)
#   Task 226: FAIL (max_steps_timeout)
#   Task 227: target_sharpe_reached (6,144 steps, sharpe=+3618465225.69)
#   Task 228: target_sharpe_reached (10,240 steps, sharpe=+284133888.71)
#   Task 229: performance_plateau (14,336 steps, sharpe=+0.00)
#   Batch timeout: 3 tasks in 1724.5s
#
# Meta-iter 52: Outer update (FOMAML) amb 3 tasques
#   Task 230: target_sharpe_reached (6,144 steps, sharpe=+2413504480.36)
#   Task 231: FAIL (max_steps_timeout)
#   Task 232: SKIP (gradient_explosion)
#   Task 233: target_sharpe_reached (6,144 steps, sharpe=+2572262650.91)
#   Task 234: target_sharpe_reached (6,144 steps, sharpe=+10675911900.34)
#   Batch timeout: 3 tasks in 784.4s
#
# Meta-iter 53: Outer update (FOMAML) amb 3 tasques
#   Task 235: SKIP (gradient_explosion)
#   Task 236: target_sharpe_reached (12,288 steps, sharpe=+651531018.51)
#   Task 237: target_sharpe_reached (10,240 steps, sharpe=+501950308.55)
#   Task 238: target_sharpe_reached (12,288 steps, sharpe=+244603789.10)
#   Batch timeout: 3 tasks in 656.9s
#
# Meta-iter 54: Outer update (FOMAML) amb 3 tasques
#   Task 239: FAIL (max_steps_timeout)
#   Task 240: target_sharpe_reached (18,432 steps, sharpe=+3466663716.12)
#   Task 241: target_sharpe_reached (6,144 steps, sharpe=+3153707399.31)
#   Task 242: target_sharpe_reached (10,240 steps, sharpe=+1226841682.72)
#   Batch timeout: 3 tasks in 992.7s
#
# Meta-iter 55: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-16.1552 ret=-19.40% best=-12.1818 [plateau 6/20]
#
#   Task 243: target_sharpe_reached (8,192 steps, sharpe=+699508853.62)
#   Task 244: performance_plateau (14,336 steps, sharpe=-900642570.17)
#   Task 245: target_sharpe_reached (6,144 steps, sharpe=+1054797467.21)
#   Batch timeout: 3 tasks in 366.6s
#
# Meta-iter 56: Outer update (FOMAML) amb 3 tasques
#   Task 246: target_sharpe_reached (8,192 steps, sharpe=+3191978178.51)
#   Task 247: FAIL (max_steps_timeout)
#   Task 248: performance_plateau (16,384 steps, sharpe=-1057054998.79)
#   Task 249: SKIP (gradient_explosion)
#   Task 250: performance_plateau (18,432 steps, sharpe=-236809228.47)
#   Batch timeout: 3 tasks in 1278.0s
#
# Meta-iter 57: Outer update (FOMAML) amb 3 tasques
#   Task 251: target_sharpe_reached (14,336 steps, sharpe=+10469716323.78)
#   Task 252: target_sharpe_reached (12,288 steps, sharpe=+3275625889.24)
#   Task 253: target_sharpe_reached (14,336 steps, sharpe=+262838973.15)
#   Batch timeout: 3 tasks in 519.0s
#
# Meta-iter 58: Outer update (FOMAML) amb 3 tasques
#   Task 254: SKIP (gradient_explosion)
#   Task 255: target_sharpe_reached (6,144 steps, sharpe=+3882147514.60)
#   Task 256: target_sharpe_reached (8,192 steps, sharpe=+3423640106.80)
#   Task 257: performance_plateau (18,432 steps, sharpe=-731041391.31)
#   Batch timeout: 3 tasks in 569.9s
#
# Meta-iter 59: Outer update (FOMAML) amb 3 tasques
#   Task 258: target_sharpe_reached (6,144 steps, sharpe=+95037503.72)
#   Task 259: SKIP (gradient_explosion)
#   Task 260: FAIL (max_steps_timeout)
#   Task 261: FAIL (max_steps_timeout)
#   Task 262: target_sharpe_reached (26,112 steps, sharpe=+1448842487.79)
#   Task 263: FAIL (max_steps_timeout)
#   Task 264: target_sharpe_reached (6,144 steps, sharpe=+2327725479.62)
#   Batch timeout: 3 tasks in 2058.4s
#
# Meta-iter 60: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-39.1303 ret=-19.98% best=-12.1818 [plateau 7/20]
#
#   Task 265: target_sharpe_reached (6,144 steps, sharpe=+1765131421.77)
#   Task 266: SKIP (gradient_explosion)
#   Task 267: target_sharpe_reached (6,144 steps, sharpe=+914368867.35)
#   Task 268: target_sharpe_reached (8,192 steps, sharpe=+2661633893.89)
#   Batch timeout: 3 tasks in 395.0s
#
# Meta-iter 61: Outer update (FOMAML) amb 3 tasques
#   Task 269: target_sharpe_reached (8,192 steps, sharpe=+446446796.11)
#   Task 270: performance_plateau (20,480 steps, sharpe=-22018442.11)
#   Task 271: target_sharpe_reached (6,144 steps, sharpe=+2514812112.81)
#   Batch timeout: 3 tasks in 489.4s
#
# Meta-iter 62: Outer update (FOMAML) amb 3 tasques
#   Task 272: SKIP (gradient_explosion)
#   Task 273: target_sharpe_reached (6,144 steps, sharpe=+1392949992.81)
#   Task 274: performance_plateau (18,432 steps, sharpe=-1795010708.13)
#   Task 275: target_sharpe_reached (6,144 steps, sharpe=+4797482448.76)
#   Batch timeout: 3 tasks in 540.4s
#
# Meta-iter 63: Outer update (FOMAML) amb 3 tasques
#   Task 276: target_sharpe_reached (6,144 steps, sharpe=+3700585777.93)
#   Task 277: FAIL (max_steps_timeout)
#   Task 278: target_sharpe_reached (6,144 steps, sharpe=+1613644620.94)
#   Task 279: target_sharpe_reached (8,192 steps, sharpe=+359412581.32)
#   Batch timeout: 3 tasks in 766.6s
#
# Meta-iter 64: Outer update (FOMAML) amb 3 tasques
#   Task 280: target_sharpe_reached (12,288 steps, sharpe=+2686236280.03)
#   Task 281: target_sharpe_reached (6,144 steps, sharpe=+7022482411.13)
#   Task 282: target_sharpe_reached (6,144 steps, sharpe=+2767368819.04)
#   Batch timeout: 3 tasks in 316.4s
#
# Meta-iter 65: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-38.8235 ret=-20.31% best=-12.1818 [plateau 8/20]
#
#   Task 283: target_sharpe_reached (10,240 steps, sharpe=+7760467024.16)
#   Task 284: target_sharpe_reached (8,192 steps, sharpe=+122544864.35)
#   Task 285: FAIL (max_steps_timeout)
#   Task 286: target_sharpe_reached (10,240 steps, sharpe=+2387814661.11)
#   Batch timeout: 3 tasks in 816.9s
#
# Meta-iter 66: Outer update (FOMAML) amb 3 tasques
#   Task 287: target_sharpe_reached (24,064 steps, sharpe=+322236970.23)
#   Task 288: SKIP (gradient_explosion)
#   Task 289: performance_plateau (14,336 steps, sharpe=+0.00)
#   Task 290: FAIL (max_steps_timeout)
#   Task 291: FAIL (max_steps_timeout)
#   Task 292: target_sharpe_reached (8,192 steps, sharpe=+881953346.91)
#   Batch timeout: 3 tasks in 1694.7s
#
# Meta-iter 67: Outer update (FOMAML) amb 3 tasques
#   Task 293: FAIL (max_steps_timeout)
#   Task 294: target_sharpe_reached (6,144 steps, sharpe=+147205329.47)
#   Task 295: target_sharpe_reached (8,192 steps, sharpe=+13099384.45)
#   Task 296: FAIL (max_steps_timeout)
#   Task 297: target_sharpe_reached (6,144 steps, sharpe=+56834149.04)
#   Batch timeout: 3 tasks in 1081.8s
#
# Meta-iter 68: Outer update (FOMAML) amb 3 tasques
#   Task 298: SKIP (gradient_explosion)
#   Task 299: SKIP (gradient_explosion)
#   Task 300: SKIP (gradient_explosion)
#   Task 301: target_sharpe_reached (16,384 steps, sharpe=+81920978.97)
#   Task 302: SKIP (gradient_explosion)
#   Task 303: target_sharpe_reached (12,288 steps, sharpe=+1376541679.52)
#   Task 304: SKIP (gradient_explosion)
#   Task 305: target_sharpe_reached (16,384 steps, sharpe=+3450855084.59)
#   Batch timeout: 3 tasks in 836.0s
#
# Meta-iter 69: Outer update (FOMAML) amb 3 tasques
#   Task 306: FAIL (max_steps_timeout)
#   Task 307: performance_plateau (18,432 steps, sharpe=+0.00)
#   Task 308: target_sharpe_reached (8,192 steps, sharpe=+1431593542.65)
#   Task 309: FAIL (max_steps_timeout)
#   Task 310: target_sharpe_reached (6,144 steps, sharpe=+2050844315.68)
#   Batch timeout: 3 tasks in 1116.5s
#
# Meta-iter 70: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-16.2541 ret=-19.62% best=-12.1818 [plateau 9/20]
#
#   Task 311: target_sharpe_reached (6,144 steps, sharpe=+1189564189.60)
#   Task 312: FAIL (max_steps_timeout)
#   Task 313: target_sharpe_reached (6,144 steps, sharpe=+2075043633.31)
#   Task 314: target_sharpe_reached (24,064 steps, sharpe=+1641956019.35)
#   Batch timeout: 3 tasks in 820.8s
#
# Meta-iter 71: Outer update (FOMAML) amb 3 tasques
#   Task 315: target_sharpe_reached (6,144 steps, sharpe=+2229625021.42)
#   Task 316: FAIL (max_steps_timeout)
#   Task 317: FAIL (max_steps_timeout)
#   Task 318: performance_plateau (18,432 steps, sharpe=-166133082.55)
#   Task 319: target_sharpe_reached (6,144 steps, sharpe=+1135649750.73)
#   Batch timeout: 3 tasks in 1022.7s
#
# Meta-iter 72: Outer update (FOMAML) amb 3 tasques
#   Task 320: target_sharpe_reached (6,144 steps, sharpe=+998473872.31)
#   Task 321: FAIL (max_steps_timeout)
#   Task 322: target_sharpe_reached (6,144 steps, sharpe=+4177345183.32)
#   Task 323: target_sharpe_reached (8,192 steps, sharpe=+1146102339.68)
#   Batch timeout: 3 tasks in 630.7s
#
# Meta-iter 73: Outer update (FOMAML) amb 3 tasques
#   Task 324: FAIL (max_steps_timeout)
#   Task 325: target_sharpe_reached (6,144 steps, sharpe=+8851478156.61)
#   Task 326: SKIP (gradient_explosion)
#   Task 327: FAIL (max_steps_timeout)
#   Task 328: target_sharpe_reached (26,112 steps, sharpe=+3872739321.18)
#   Task 329: target_sharpe_reached (26,112 steps, sharpe=+47789686.61)
#   Batch timeout: 3 tasks in 1513.6s
#
# Meta-iter 74: Outer update (FOMAML) amb 3 tasques
#   Task 330: target_sharpe_reached (6,144 steps, sharpe=+860244548.02)
#   Task 331: target_sharpe_reached (6,144 steps, sharpe=+2396366964.15)
#   Task 332: target_sharpe_reached (22,016 steps, sharpe=+2183303448.42)
#   Batch timeout: 3 tasks in 387.5s
#
# Meta-iter 75: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-33.7479 ret=-20.04% best=-12.1818 [plateau 10/20]
#
#   Task 333: target_sharpe_reached (6,144 steps, sharpe=+515169651.82)
#   Task 334: performance_plateau (30,000 steps, sharpe=-1061567566.62)
#   Task 335: performance_plateau (24,064 steps, sharpe=+0.00)
#   Batch timeout: 3 tasks in 815.6s
#
# Meta-iter 76: Outer update (FOMAML) amb 3 tasques
#   Task 336: target_sharpe_reached (18,432 steps, sharpe=+698775730.38)
#   Task 337: target_sharpe_reached (6,144 steps, sharpe=+1619367472.53)
#   Task 338: target_sharpe_reached (6,144 steps, sharpe=+3746640680.91)
#   Batch timeout: 3 tasks in 370.1s
#
# Meta-iter 77: Outer update (FOMAML) amb 3 tasques
#   Task 339: target_sharpe_reached (6,144 steps, sharpe=+653640919.42)
#   Task 340: FAIL (max_steps_timeout)
#   Task 341: target_sharpe_reached (6,144 steps, sharpe=+37867088.91)
#   Task 342: SKIP (gradient_explosion)
#   Task 343: target_sharpe_reached (6,144 steps, sharpe=+3963714278.37)
#   Batch timeout: 3 tasks in 598.6s
#
# Meta-iter 78: Outer update (FOMAML) amb 3 tasques
#   Task 344: SKIP (gradient_explosion)
#   Task 345: SKIP (gradient_explosion)
#   Task 346: target_sharpe_reached (10,240 steps, sharpe=+2505572330.25)
#   Task 347: FAIL (max_steps_timeout)
#   Task 348: FAIL (max_steps_timeout)
#   Task 349: target_sharpe_reached (6,144 steps, sharpe=+463821999.83)
#   Task 350: SKIP (gradient_explosion)
#   Task 351: target_sharpe_reached (8,192 steps, sharpe=+869817229.10)
#   Batch timeout: 3 tasks in 1182.9s
#
# Meta-iter 79: Outer update (FOMAML) amb 3 tasques
#   Task 352: target_sharpe_reached (6,144 steps, sharpe=+1788193866.93)
#   Task 353: target_sharpe_reached (30,000 steps, sharpe=+457044740.62)
#   Task 354: target_sharpe_reached (8,192 steps, sharpe=+131973477.59)
#   Batch timeout: 3 tasks in 493.9s
#
# Meta-iter 80: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-22.7315 ret=-19.79% best=-12.1818 [plateau 11/20]
#
#   Task 355: target_sharpe_reached (6,144 steps, sharpe=+2925157161.57)
#   Task 356: SKIP (gradient_explosion)
#   Task 357: target_sharpe_reached (6,144 steps, sharpe=+792329044.12)
#   Task 358: SKIP (gradient_explosion)
#   Task 359: target_sharpe_reached (6,144 steps, sharpe=+343417293.64)
#   Task 360: target_sharpe_reached (14,336 steps, sharpe=+1472900418.18)
#   Batch timeout: 4 tasks in 491.4s
#
# Meta-iter 81: Outer update (FOMAML) amb 4 tasques
#   Task 361: performance_plateau (30,000 steps, sharpe=+0.00)
#   Task 362: target_sharpe_reached (14,336 steps, sharpe=+5515067369.89)
#   Task 363: FAIL (max_steps_timeout)
#   Task 364: SKIP (gradient_explosion)
#   Task 365: target_sharpe_reached (6,144 steps, sharpe=+1600377659.14)
#   Batch timeout: 3 tasks in 979.3s
#
# Meta-iter 82: Outer update (FOMAML) amb 3 tasques
#   Task 366: target_sharpe_reached (14,336 steps, sharpe=+3597038572.84)
#   Task 367: target_sharpe_reached (12,288 steps, sharpe=+1848735722.79)
#   Task 368: SKIP (gradient_explosion)
#   Task 369: SKIP (gradient_explosion)
#   Task 370: target_sharpe_reached (6,144 steps, sharpe=+2794646446.90)
#   Batch timeout: 3 tasks in 541.8s
#
# Meta-iter 83: Outer update (FOMAML) amb 3 tasques
#   Task 371: target_sharpe_reached (18,432 steps, sharpe=+1176393935.68)
#   Task 372: FAIL (max_steps_timeout)
#   Task 373: FAIL (max_steps_timeout)
#   Task 374: FAIL (max_steps_timeout)
#   Task 375: target_sharpe_reached (6,144 steps, sharpe=+1114945795.92)
#   Task 376: target_sharpe_reached (10,240 steps, sharpe=+2782576517.01)
#   Batch timeout: 3 tasks in 1515.1s
#
# Meta-iter 84: Outer update (FOMAML) amb 3 tasques
#   Task 377: target_sharpe_reached (10,240 steps, sharpe=+3680935574.58)
#   Task 378: SKIP (gradient_explosion)
#   Task 379: SKIP (gradient_explosion)
#   Task 380: SKIP (gradient_explosion)
#   Task 381: target_sharpe_reached (6,144 steps, sharpe=+431058838.16)
#   Task 382: target_sharpe_reached (8,192 steps, sharpe=+1088822639.33)
#   Batch timeout: 3 tasks in 510.6s
#
# Meta-iter 85: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-21.6307 ret=-20.24% best=-12.1818 [plateau 12/20]
#
#   Task 383: SKIP (gradient_explosion)
#   Task 384: SKIP (gradient_explosion)
#   Task 385: SKIP (gradient_explosion)
#   Task 386: target_sharpe_reached (26,112 steps, sharpe=+69567907.91)
#   Task 387: target_sharpe_reached (16,384 steps, sharpe=+2423606499.51)
#   Task 388: FAIL (max_steps_timeout)
#   Task 389: target_sharpe_reached (6,144 steps, sharpe=+409431107.95)
#   Batch timeout: 3 tasks in 1124.2s
#
# Meta-iter 86: Outer update (FOMAML) amb 3 tasques
#   Task 390: target_sharpe_reached (8,192 steps, sharpe=+4340667556.01)
#   Task 391: FAIL (max_steps_timeout)
#   Task 392: target_sharpe_reached (8,192 steps, sharpe=+2536493474.63)
#   Task 393: target_sharpe_reached (16,384 steps, sharpe=+276916858.17)
#   Batch timeout: 3 tasks in 755.0s
#
# Meta-iter 87: Outer update (FOMAML) amb 3 tasques
#   Task 394: FAIL (max_steps_timeout)
#   Task 395: FAIL (max_steps_timeout)
#   Task 396: target_sharpe_reached (14,336 steps, sharpe=+1061526985.82)
#   Task 397: target_sharpe_reached (14,336 steps, sharpe=+2085003770.65)
#   Task 398: target_sharpe_reached (12,288 steps, sharpe=+1419355873.54)
#   Batch timeout: 3 tasks in 1240.4s
#
# Meta-iter 88: Outer update (FOMAML) amb 3 tasques
#   Task 399: target_sharpe_reached (28,160 steps, sharpe=+57571436.96)
#   Task 400: target_sharpe_reached (28,160 steps, sharpe=+2902406206.53)
#   Task 401: target_sharpe_reached (14,336 steps, sharpe=+1217110245.35)
#   Batch timeout: 3 tasks in 703.1s
#
# Meta-iter 89: Outer update (FOMAML) amb 3 tasques
#   Task 402: target_sharpe_reached (18,432 steps, sharpe=+1318283226.28)
#   Task 403: target_sharpe_reached (6,144 steps, sharpe=+166097990.08)
#   Task 404: target_sharpe_reached (16,384 steps, sharpe=+8086435841.32)
#   Batch timeout: 3 tasks in 430.6s
#
# Meta-iter 90: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-17.2451 ret=-20.12% best=-12.1818 [plateau 13/20]
#
#   Task 405: SKIP (gradient_explosion)
#   Task 406: target_sharpe_reached (8,192 steps, sharpe=+1819043044.07)
#   Task 407: target_sharpe_reached (6,144 steps, sharpe=+3708780811.11)
#   Task 408: target_sharpe_reached (6,144 steps, sharpe=+14479729.70)
#   Task 409: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 300.6s
#
# Meta-iter 91: Outer update (FOMAML) amb 3 tasques
#   Task 410: target_sharpe_reached (10,240 steps, sharpe=+36058259.72)
#   Task 411: target_sharpe_reached (6,144 steps, sharpe=+255338681.16)
#   Task 412: target_sharpe_reached (8,192 steps, sharpe=+1891585329.29)
#   Task 413: target_sharpe_reached (22,016 steps, sharpe=+3742651025.45)
#   Batch timeout: 4 tasks in 486.9s
#
# Meta-iter 92: Outer update (FOMAML) amb 4 tasques
#   Task 414: SKIP (gradient_explosion)
#   Task 415: target_sharpe_reached (22,016 steps, sharpe=+1373307456.31)
#   Task 416: target_sharpe_reached (8,192 steps, sharpe=+122129162.52)
#   Task 417: target_sharpe_reached (6,144 steps, sharpe=+35900826.70)
#   Batch timeout: 3 tasks in 423.6s
#
# Meta-iter 93: Outer update (FOMAML) amb 3 tasques
#   Task 418: FAIL (max_steps_timeout)
#   Task 419: FAIL (max_steps_timeout)
#   Task 420: FAIL (max_steps_timeout)
#   Task 421: target_sharpe_reached (6,144 steps, sharpe=+251414072.97)
#   Task 422: target_sharpe_reached (8,192 steps, sharpe=+1872799759.44)
#   Task 423: target_sharpe_reached (22,016 steps, sharpe=+1244538616.48)
#   Batch timeout: 3 tasks in 1400.4s
#
# Meta-iter 94: Outer update (FOMAML) amb 3 tasques
#   Task 424: performance_plateau (20,480 steps, sharpe=-1473206285.63)
#   Task 425: target_sharpe_reached (10,240 steps, sharpe=+2465235137.62)
#   Task 426: target_sharpe_reached (6,144 steps, sharpe=+3057432368.62)
#   Batch timeout: 3 tasks in 419.0s
#
# Meta-iter 95: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-11.9647 ret=-19.76% best=-11.9647 [✓ NEW BEST]
#
#   Task 427: target_sharpe_reached (6,144 steps, sharpe=+403343736.76)
#   Task 428: SKIP (gradient_explosion)
#   Task 429: FAIL (max_steps_timeout)
#   Task 430: target_sharpe_reached (20,480 steps, sharpe=+571683129.09)
#   Task 431: target_sharpe_reached (8,192 steps, sharpe=+2862648739.88)
#   Batch timeout: 3 tasks in 744.4s
#
# Meta-iter 96: Outer update (FOMAML) amb 3 tasques
#   Task 432: target_sharpe_reached (6,144 steps, sharpe=+779029205.67)
#   Task 433: target_sharpe_reached (6,144 steps, sharpe=+3840467364.04)
#   Task 434: target_sharpe_reached (6,144 steps, sharpe=+1742414191.81)
#   Task 435: performance_plateau (16,384 steps, sharpe=+0.00)
#   Batch timeout: 4 tasks in 370.9s
#
# Meta-iter 97: Outer update (FOMAML) amb 4 tasques
#   Task 436: target_sharpe_reached (6,144 steps, sharpe=+4112726650.33)
#   Task 437: target_sharpe_reached (8,192 steps, sharpe=+949607099.49)
#   Task 438: performance_plateau (16,384 steps, sharpe=-1233445816.48)
#   Task 439: target_sharpe_reached (6,144 steps, sharpe=+1387367302.57)
#   Batch timeout: 4 tasks in 354.6s
#
# Meta-iter 98: Outer update (FOMAML) amb 4 tasques
#   Task 440: target_sharpe_reached (8,192 steps, sharpe=+412167726.63)
#   Task 441: FAIL (max_steps_timeout)
#   Task 442: target_sharpe_reached (6,144 steps, sharpe=+675145726.32)
#   Task 443: target_sharpe_reached (18,432 steps, sharpe=+6287288308.30)
#   Batch timeout: 3 tasks in 659.4s
#
# Meta-iter 99: Outer update (FOMAML) amb 3 tasques
#   Task 444: target_sharpe_reached (6,144 steps, sharpe=+6478007866.73)
#   Task 445: performance_plateau (24,064 steps, sharpe=-1183979784.88)
#   Task 446: SKIP (gradient_explosion)
#   Task 447: target_sharpe_reached (12,288 steps, sharpe=+1071730066.30)
#   Batch timeout: 3 tasks in 500.0s
#
# Meta-iter 100: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-25.2557 ret=-20.05% best=-11.9647 [plateau 1/20]
#
#   [ckpt] Desat checkpoint @ iter 100 → ppo_fomaml_meta_new_adaptative.pt
#   Task 448: FAIL (max_steps_timeout)
#   Task 449: target_sharpe_reached (16,384 steps, sharpe=+1240259447.95)
#   Task 450: target_sharpe_reached (10,240 steps, sharpe=+909328790.92)
#   Task 451: target_sharpe_reached (6,144 steps, sharpe=+488497448.77)
#   Batch timeout: 3 tasks in 738.8s
#
# Meta-iter 101: Outer update (FOMAML) amb 3 tasques
#   Task 452: target_sharpe_reached (22,016 steps, sharpe=+6297705173.97)
#   Task 453: SKIP (gradient_explosion)
#   Task 454: FAIL (max_steps_timeout)
#   Task 455: FAIL (max_steps_timeout)
#   Task 456: target_sharpe_reached (6,144 steps, sharpe=+3436882202.16)
#   Task 457: FAIL (max_steps_timeout)
#   Task 458: target_sharpe_reached (6,144 steps, sharpe=+1447666108.06)
#   Batch timeout: 3 tasks in 1700.7s
#
# Meta-iter 102: Outer update (FOMAML) amb 3 tasques
#   Task 459: SKIP (gradient_explosion)
#   Task 460: FAIL (max_steps_timeout)
#   Task 461: target_sharpe_reached (22,016 steps, sharpe=+3440215112.46)
#   Task 462: target_sharpe_reached (6,144 steps, sharpe=+4315921489.17)
#   Task 463: target_sharpe_reached (14,336 steps, sharpe=+1012710241.25)
#   Batch timeout: 3 tasks in 1102.0s
#
# Meta-iter 103: Outer update (FOMAML) amb 3 tasques
#   Task 464: SKIP (gradient_explosion)
#   Task 465: target_sharpe_reached (6,144 steps, sharpe=+697516177.82)
#   Task 466: SKIP (gradient_explosion)
#   Task 467: SKIP (gradient_explosion)
#   Task 468: target_sharpe_reached (6,144 steps, sharpe=+172293383.16)
#   Task 469: target_sharpe_reached (12,288 steps, sharpe=+6707819.73)
#   Batch timeout: 3 tasks in 543.2s
#
# Meta-iter 104: Outer update (FOMAML) amb 3 tasques
#   Task 470: target_sharpe_reached (6,144 steps, sharpe=+2943797001.88)
#   Task 471: SKIP (gradient_explosion)
#   Task 472: target_sharpe_reached (6,144 steps, sharpe=+1484306402.94)
#   Task 473: target_sharpe_reached (6,144 steps, sharpe=+3503213511.25)
#   Batch timeout: 3 tasks in 310.8s
#
# Meta-iter 105: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-18.8789 ret=-20.00% best=-11.9647 [plateau 2/20]
#
#   Task 474: target_sharpe_reached (10,240 steps, sharpe=+3295916472.69)
#   Task 475: SKIP (gradient_explosion)
#   Task 476: target_sharpe_reached (26,112 steps, sharpe=+1836287790.70)
#   Task 477: SKIP (gradient_explosion)
#   Task 478: target_sharpe_reached (10,240 steps, sharpe=+1611234798.47)
#   Batch timeout: 3 tasks in 808.7s
#
# Meta-iter 106: Outer update (FOMAML) amb 3 tasques
#   Task 479: target_sharpe_reached (24,064 steps, sharpe=+285961865.02)
#   Task 480: FAIL (max_steps_timeout)
#   Task 481: performance_plateau (14,336 steps, sharpe=-1483937735.91)
#   Task 482: SKIP (gradient_explosion)
#   Task 483: target_sharpe_reached (14,336 steps, sharpe=+1150611145.50)
#   Batch timeout: 3 tasks in 1109.3s
#
# Meta-iter 107: Outer update (FOMAML) amb 3 tasques
#   Task 484: target_sharpe_reached (6,144 steps, sharpe=+1185312505.63)
#   Task 485: target_sharpe_reached (8,192 steps, sharpe=+658376311.57)
#   Task 486: target_sharpe_reached (30,000 steps, sharpe=+358455664.02)
#   Batch timeout: 3 tasks in 561.1s
#
# Meta-iter 108: Outer update (FOMAML) amb 3 tasques
#   Task 487: SKIP (gradient_explosion)
#   Task 488: performance_plateau (18,432 steps, sharpe=+0.00)
#   Task 489: FAIL (max_steps_timeout)
#   Task 490: target_sharpe_reached (8,192 steps, sharpe=+76913788.10)
#   Task 491: target_sharpe_reached (6,144 steps, sharpe=+2209339243.24)
#   Batch timeout: 3 tasks in 936.0s
#
# Meta-iter 109: Outer update (FOMAML) amb 3 tasques
#   Task 492: FAIL (max_steps_timeout)
#   Task 493: performance_plateau (16,384 steps, sharpe=-1457305914.80)
#   Task 494: target_sharpe_reached (6,144 steps, sharpe=+122332912.71)
#   Task 495: SKIP (gradient_explosion)
#   Task 496: target_sharpe_reached (10,240 steps, sharpe=+353983106.17)
#   Batch timeout: 3 tasks in 818.4s
#
# Meta-iter 110: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-15.5890 ret=-19.61% best=-11.9647 [plateau 3/20]
#
#   Task 497: target_sharpe_reached (8,192 steps, sharpe=+1904386404.53)
#   Task 498: FAIL (max_steps_timeout)
#   Task 499: target_sharpe_reached (6,144 steps, sharpe=+1799117631.99)
#   Task 500: target_sharpe_reached (8,192 steps, sharpe=+286016925.21)
#   Batch timeout: 3 tasks in 710.5s
#
# Meta-iter 111: Outer update (FOMAML) amb 3 tasques
#   Task 501: target_sharpe_reached (8,192 steps, sharpe=+106564403.58)
#   Task 502: target_sharpe_reached (12,288 steps, sharpe=+202083149.22)
#   Task 503: target_sharpe_reached (10,240 steps, sharpe=+2866609788.98)
#   Batch timeout: 3 tasks in 379.1s
#
# Meta-iter 112: Outer update (FOMAML) amb 3 tasques
#   Task 504: target_sharpe_reached (6,144 steps, sharpe=+2915702110.28)
#   Task 505: performance_plateau (18,432 steps, sharpe=+0.00)
#   Task 506: SKIP (gradient_explosion)
#   Task 507: target_sharpe_reached (16,384 steps, sharpe=+3425259602.19)
#   Batch timeout: 3 tasks in 550.6s
#
# Meta-iter 113: Outer update (FOMAML) amb 3 tasques
#   Task 508: FAIL (max_steps_timeout)
#   Task 509: SKIP (gradient_explosion)
#   Task 510: target_sharpe_reached (6,144 steps, sharpe=+3240216700.56)
#   Task 511: target_sharpe_reached (6,144 steps, sharpe=+4616585131.12)
#   Task 512: SKIP (gradient_explosion)
#   Task 513: target_sharpe_reached (8,192 steps, sharpe=+829442179.20)
#   Batch timeout: 3 tasks in 765.7s
#
# Meta-iter 114: Outer update (FOMAML) amb 3 tasques
#   Task 514: target_sharpe_reached (20,480 steps, sharpe=+386912809.25)
#   Task 515: SKIP (gradient_explosion)
#   Task 516: FAIL (max_steps_timeout)
#   Task 517: target_sharpe_reached (6,144 steps, sharpe=+400912053.59)
#   Task 518: performance_plateau (30,000 steps, sharpe=-2046889133.27)
#   Batch timeout: 3 tasks in 1197.9s
#
# Meta-iter 115: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-24.1322 ret=-19.82% best=-11.9647 [plateau 4/20]
#
#   Task 519: performance_plateau (30,000 steps, sharpe=-1173026087.91)
#   Task 520: FAIL (max_steps_timeout)
#   Task 521: target_sharpe_reached (12,288 steps, sharpe=+3838356024.53)
#   Task 522: target_sharpe_reached (6,144 steps, sharpe=+2926914555.86)
#   Batch timeout: 3 tasks in 1022.5s
#
# Meta-iter 116: Outer update (FOMAML) amb 3 tasques
#   Task 523: target_sharpe_reached (12,288 steps, sharpe=+1311668147.57)
#   Task 524: target_sharpe_reached (6,144 steps, sharpe=+2127781010.87)
#   Task 525: FAIL (max_steps_timeout)
#   Task 526: target_sharpe_reached (30,000 steps, sharpe=+1402452977.47)
#   Batch timeout: 3 tasks in 993.3s
#
# Meta-iter 117: Outer update (FOMAML) amb 3 tasques
#   Task 527: target_sharpe_reached (6,144 steps, sharpe=+3861133119.25)
#   Task 528: target_sharpe_reached (6,144 steps, sharpe=+1172428749.13)
#   Task 529: FAIL (max_steps_timeout)
#   Task 530: target_sharpe_reached (6,144 steps, sharpe=+21885605.17)
#   Batch timeout: 3 tasks in 634.2s
#
# Meta-iter 118: Outer update (FOMAML) amb 3 tasques
#   Task 531: SKIP (gradient_explosion)
#   Task 532: FAIL (max_steps_timeout)
#   Task 533: target_sharpe_reached (30,000 steps, sharpe=+1790726848.89)
#   Task 534: target_sharpe_reached (14,336 steps, sharpe=+3589189755.77)
#   Task 535: target_sharpe_reached (6,144 steps, sharpe=+1253669623.56)
#   Batch timeout: 3 tasks in 966.1s
#
# Meta-iter 119: Outer update (FOMAML) amb 3 tasques
#   Task 536: target_sharpe_reached (12,288 steps, sharpe=+57725735.23)
#   Task 537: performance_plateau (14,336 steps, sharpe=-1926285127.89)
#   Task 538: FAIL (max_steps_timeout)
#   Task 539: FAIL (max_steps_timeout)
#   Task 540: FAIL (max_steps_timeout)
#   Task 541: target_sharpe_reached (6,144 steps, sharpe=+2869146113.70)
#   Batch timeout: 3 tasks in 1173.2s
#
# Meta-iter 120: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-31.1144 ret=-20.02% best=-11.9647 [plateau 5/20]
#
#   Task 542: target_sharpe_reached (18,432 steps, sharpe=+3364018690.96)
#   Task 543: FAIL (max_steps_timeout)
#   Task 544: FAIL (max_steps_timeout)
#   Task 545: target_sharpe_reached (6,144 steps, sharpe=+2862365506.10)
#   Task 546: target_sharpe_reached (24,064 steps, sharpe=+1438305038.67)
#   Batch timeout: 3 tasks in 970.5s
#
# Meta-iter 121: Outer update (FOMAML) amb 3 tasques
#   Task 547: target_sharpe_reached (16,384 steps, sharpe=+282589220.74)
#   Task 548: target_sharpe_reached (6,144 steps, sharpe=+4036599358.29)
#   Task 549: target_sharpe_reached (6,144 steps, sharpe=+1954832930.01)
#   Task 550: SKIP (gradient_explosion)
#   Task 551: target_sharpe_reached (6,144 steps, sharpe=+2942541590.40)
#   Task 552: target_sharpe_reached (6,144 steps, sharpe=+15925407.19)
#
# Meta-iter 122: Outer update (FOMAML) amb 5 tasques
#   Task 553: target_sharpe_reached (26,112 steps, sharpe=+1799802708.67)
#   Task 554: target_sharpe_reached (8,192 steps, sharpe=+2028672317.63)
#   Task 555: target_sharpe_reached (16,384 steps, sharpe=+528690839.99)
#   Batch timeout: 3 tasks in 384.5s
#
# Meta-iter 123: Outer update (FOMAML) amb 3 tasques
#   Task 556: target_sharpe_reached (6,144 steps, sharpe=+2976201846.48)
#   Task 557: FAIL (max_steps_timeout)
#   Task 558: target_sharpe_reached (6,144 steps, sharpe=+1629759548.30)
#   Task 559: target_sharpe_reached (14,336 steps, sharpe=+2902347295.54)
#   Batch timeout: 3 tasks in 424.3s
#
# Meta-iter 124: Outer update (FOMAML) amb 3 tasques
#   Task 560: target_sharpe_reached (6,144 steps, sharpe=+2128111735.25)
#   Task 561: target_sharpe_reached (10,240 steps, sharpe=+694247627.19)
#   Task 562: target_sharpe_reached (30,000 steps, sharpe=+8942455699.16)
#   Task 563: target_sharpe_reached (12,288 steps, sharpe=+240288939.45)
#   Batch timeout: 4 tasks in 379.3s
#
# Meta-iter 125: Outer update (FOMAML) amb 4 tasques
#   Val: sharpe=-16.1270 ret=-19.81% best=-11.9647 [plateau 6/20]
#
#   Task 564: FAIL (max_steps_timeout)
#   Task 565: target_sharpe_reached (14,336 steps, sharpe=+2903056491.40)
#   Task 566: target_sharpe_reached (8,192 steps, sharpe=+10725681075.53)
#   Task 567: target_sharpe_reached (6,144 steps, sharpe=+3343560008.60)
#   Batch timeout: 3 tasks in 401.7s
#
# Meta-iter 126: Outer update (FOMAML) amb 3 tasques
#   Task 568: target_sharpe_reached (30,000 steps, sharpe=+2496875281.70)
#   Task 569: target_sharpe_reached (6,144 steps, sharpe=+2811447120.68)
#   Task 570: target_sharpe_reached (10,240 steps, sharpe=+544744150.20)
#   Task 571: FAIL (max_steps_timeout)
#   Batch timeout: 3 tasks in 556.9s
#
# Meta-iter 127: Outer update (FOMAML) amb 3 tasques
#   Task 572: target_sharpe_reached (8,192 steps, sharpe=+2166820517.80)
#   Task 573: FAIL (max_steps_timeout)
#   Task 574: SKIP (gradient_explosion)
#   Task 575: target_sharpe_reached (12,288 steps, sharpe=+133638300.73)
#   Task 576: target_sharpe_reached (18,432 steps, sharpe=+152935787.90)
#   Batch timeout: 3 tasks in 529.0s
#
# Meta-iter 128: Outer update (FOMAML) amb 3 tasques
#   Task 577: SKIP (gradient_explosion)
#   Task 578: target_sharpe_reached (14,336 steps, sharpe=+215929246.25)
#   Task 579: target_sharpe_reached (18,432 steps, sharpe=+93309085.94)
#   Task 580: target_sharpe_reached (8,192 steps, sharpe=+792314038.40)
#   Batch timeout: 3 tasks in 322.1s
#
# Meta-iter 129: Outer update (FOMAML) amb 3 tasques
#   Task 581: target_sharpe_reached (8,192 steps, sharpe=+842063220.16)
#   Task 582: FAIL (max_steps_timeout)
#   Task 583: target_sharpe_reached (8,192 steps, sharpe=+2566686635.25)
#   Task 584: FAIL (max_steps_timeout)
# ...
#   Task 706: SKIP (gradient_explosion)
#   Task 707: FAIL (max_steps_timeout)
#   Task 708: target_sharpe_reached (20,480 steps, sharpe=+2406929726.70)
#   Task 709: performance_plateau (14,336 steps, sharpe=-1942572238.26)
#   Batch timeout: 3 tasks in 466.7s
#
# Meta-iter 156: Outer update (FOMAML) amb 3 tasques
#   Task 710: target_sharpe_reached (6,144 steps, sharpe=+2992419675.87)
#   Task 711: SKIP (gradient_explosion)
#   Task 712: performance_plateau (20,480 steps, sharpe=-549587815.65)
#   Task 713: target_sharpe_reached (26,112 steps, sharpe=+588741779.11)
#   Batch timeout: 3 tasks in 315.7s
#
# Meta-iter 157: Outer update (FOMAML) amb 3 tasques
#   Task 714: FAIL (max_steps_timeout)
#   Task 715: target_sharpe_reached (6,144 steps, sharpe=+1459894813.71)
#   Task 716: target_sharpe_reached (8,192 steps, sharpe=+2314541696.02)
#   Task 717: target_sharpe_reached (12,288 steps, sharpe=+109888237.18)
#   Batch timeout: 3 tasks in 361.8s
#
# Meta-iter 158: Outer update (FOMAML) amb 3 tasques
#   Task 718: target_sharpe_reached (6,144 steps, sharpe=+2884834575.19)
#   Task 719: target_sharpe_reached (22,016 steps, sharpe=+1121642025.03)
#   Task 720: target_sharpe_reached (6,144 steps, sharpe=+3238925780.27)
#   Task 721: target_sharpe_reached (12,288 steps, sharpe=+335170087.86)
#   Task 722: target_sharpe_reached (14,336 steps, sharpe=+1624832127.69)
#
# Meta-iter 159: Outer update (FOMAML) amb 5 tasques
#   Task 723: FAIL (max_steps_timeout)
#   Task 724: performance_plateau (18,432 steps, sharpe=-879236916.40)
#   Task 725: FAIL (max_steps_timeout)
#   Task 726: FAIL (max_steps_timeout)
#   Task 727: target_sharpe_reached (6,144 steps, sharpe=+4380485.15)
#   Task 728: FAIL (max_steps_timeout)
#   Task 729: target_sharpe_reached (6,144 steps, sharpe=+1795741924.88)
#   Batch timeout: 3 tasks in 1036.7s
#
# Meta-iter 160: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-20.0468 ret=-19.66% best=-11.9647 [plateau 13/20]
#
#   Task 730: FAIL (max_steps_timeout)
#   Task 731: target_sharpe_reached (10,240 steps, sharpe=+209835311.44)
#   Task 732: target_sharpe_reached (20,480 steps, sharpe=+806701210.17)
#   Task 733: target_sharpe_reached (26,112 steps, sharpe=+312577495.90)
#   Batch timeout: 3 tasks in 547.2s
#
# Meta-iter 161: Outer update (FOMAML) amb 3 tasques
#   Task 734: target_sharpe_reached (30,000 steps, sharpe=+9186529399.74)
#   Task 735: target_sharpe_reached (6,144 steps, sharpe=+2743661615.32)
#   Task 736: target_sharpe_reached (14,336 steps, sharpe=+2718518976.43)
#   Batch timeout: 3 tasks in 309.1s
#
# Meta-iter 162: Outer update (FOMAML) amb 3 tasques
#   Task 737: target_sharpe_reached (12,288 steps, sharpe=+1738446815.18)
#   Task 738: target_sharpe_reached (6,144 steps, sharpe=+3123778316.93)
#   Task 739: target_sharpe_reached (6,144 steps, sharpe=+15966028.74)
#   Task 740: SKIP (gradient_explosion)
#   Task 741: target_sharpe_reached (6,144 steps, sharpe=+1819489858.15)
#   Task 742: FAIL (max_steps_timeout)
#   Batch timeout: 4 tasks in 406.0s
#
# Meta-iter 163: Outer update (FOMAML) amb 4 tasques
#   Task 743: SKIP (gradient_explosion)
#   Task 744: target_sharpe_reached (16,384 steps, sharpe=+752099738.83)
#   Task 745: target_sharpe_reached (6,144 steps, sharpe=+2329498630.02)
#   Task 746: target_sharpe_reached (8,192 steps, sharpe=+4085686533.29)
#   Task 747: target_sharpe_reached (28,160 steps, sharpe=+1850044814.33)
#   Batch timeout: 4 tasks in 379.4s
#
# Meta-iter 164: Outer update (FOMAML) amb 4 tasques
#   Task 748: target_sharpe_reached (10,240 steps, sharpe=+731641160.52)
#   Task 749: FAIL (max_steps_timeout)
#   Task 750: target_sharpe_reached (10,240 steps, sharpe=+801637798.40)
#   Task 751: target_sharpe_reached (6,144 steps, sharpe=+3446130453.88)
#   Batch timeout: 3 tasks in 316.9s
#
# Meta-iter 165: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-24.9322 ret=-20.07% best=-11.9647 [plateau 14/20]
#
#   Task 752: FAIL (max_steps_timeout)
#   Task 753: performance_plateau (18,432 steps, sharpe=-51474085.13)
#   Task 754: SKIP (gradient_explosion)
#   Task 755: FAIL (max_steps_timeout)
#   Task 756: target_sharpe_reached (6,144 steps, sharpe=+3287187959.19)
#   Task 757: target_sharpe_reached (6,144 steps, sharpe=+4549346589.54)
#   Batch timeout: 3 tasks in 578.2s
#
# Meta-iter 166: Outer update (FOMAML) amb 3 tasques
#   Task 758: target_sharpe_reached (28,160 steps, sharpe=+3987333021.47)
#   Task 759: target_sharpe_reached (18,432 steps, sharpe=+2470066718.98)
#   Task 760: target_sharpe_reached (6,144 steps, sharpe=+986589822.52)
#   Batch timeout: 3 tasks in 349.6s
#
# Meta-iter 167: Outer update (FOMAML) amb 3 tasques
#   Task 761: FAIL (max_steps_timeout)
#   Task 762: target_sharpe_reached (8,192 steps, sharpe=+1130327464.17)
#   Task 763: FAIL (max_steps_timeout)
#   Task 764: target_sharpe_reached (8,192 steps, sharpe=+2869459592.33)
#   Task 765: target_sharpe_reached (16,384 steps, sharpe=+470725877.88)
#   Batch timeout: 3 tasks in 608.4s
#
# Meta-iter 168: Outer update (FOMAML) amb 3 tasques
#   Task 766: target_sharpe_reached (6,144 steps, sharpe=+3410234831.70)
#   Task 767: target_sharpe_reached (10,240 steps, sharpe=+6631355587.88)
#   Task 768: target_sharpe_reached (6,144 steps, sharpe=+3732434247.11)
#   Task 769: target_sharpe_reached (8,192 steps, sharpe=+2075374648.42)
#   Task 770: target_sharpe_reached (10,240 steps, sharpe=+94332637.59)
#
# Meta-iter 169: Outer update (FOMAML) amb 5 tasques
#   Task 771: target_sharpe_reached (6,144 steps, sharpe=+2632020285.85)
#   Task 772: target_sharpe_reached (6,144 steps, sharpe=+291130796.45)
#   Task 773: performance_plateau (28,160 steps, sharpe=+0.00)
#   Task 774: target_sharpe_reached (12,288 steps, sharpe=+27299446.89)
#   Batch timeout: 4 tasks in 341.2s
#
# Meta-iter 170: Outer update (FOMAML) amb 4 tasques
#   Val: sharpe=-16.6023 ret=-19.77% best=-11.9647 [plateau 15/20]
#
#   Task 775: target_sharpe_reached (6,144 steps, sharpe=+988999254.71)
#   Task 776: target_sharpe_reached (6,144 steps, sharpe=+1625866982.31)
#   Task 777: performance_plateau (18,432 steps, sharpe=-614191766.82)
#   Task 778: target_sharpe_reached (6,144 steps, sharpe=+205616057.14)
#   Task 779: target_sharpe_reached (8,192 steps, sharpe=+2829677150.23)
#
# Meta-iter 171: Outer update (FOMAML) amb 5 tasques
#   Task 780: FAIL (max_steps_timeout)
#   Task 781: FAIL (max_steps_timeout)
#   Task 782: performance_plateau (18,432 steps, sharpe=+0.00)
#   Task 783: target_sharpe_reached (26,112 steps, sharpe=+76122600.82)
#   Task 784: target_sharpe_reached (10,240 steps, sharpe=+1928161610.75)
#   Batch timeout: 3 tasks in 734.9s
#
# Meta-iter 172: Outer update (FOMAML) amb 3 tasques
#   Task 785: SKIP (gradient_explosion)
#   Task 786: SKIP (gradient_explosion)
#   Task 787: target_sharpe_reached (6,144 steps, sharpe=+412073825.06)
#   Task 788: SKIP (gradient_explosion)
#   Task 789: target_sharpe_reached (6,144 steps, sharpe=+1850165805.38)
#   Task 790: target_sharpe_reached (6,144 steps, sharpe=+1321947592.73)
#   Task 791: performance_plateau (18,432 steps, sharpe=+0.00)
#   Batch timeout: 4 tasks in 325.7s
#
# Meta-iter 173: Outer update (FOMAML) amb 4 tasques
#   Task 792: performance_plateau (22,016 steps, sharpe=-1117069588.21)
#   Task 793: target_sharpe_reached (26,112 steps, sharpe=+1216306819.14)
#   Task 794: target_sharpe_reached (6,144 steps, sharpe=+1541234927.81)
#   Batch timeout: 3 tasks in 346.6s
#
# Meta-iter 174: Outer update (FOMAML) amb 3 tasques
#   Task 795: FAIL (max_steps_timeout)
#   Task 796: target_sharpe_reached (6,144 steps, sharpe=+317231813.07)
#   Task 797: target_sharpe_reached (6,144 steps, sharpe=+434973902.26)
#   Task 798: target_sharpe_reached (24,064 steps, sharpe=+1726477325.14)
#   Batch timeout: 3 tasks in 394.4s
#
# Meta-iter 175: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-39.4832 ret=-20.18% best=-11.9647 [plateau 16/20]
#
#   Task 799: target_sharpe_reached (8,192 steps, sharpe=+26776440.14)
#   Task 800: target_sharpe_reached (6,144 steps, sharpe=+2484018941.90)
#   Task 801: target_sharpe_reached (20,480 steps, sharpe=+802101321.58)
#   Task 802: target_sharpe_reached (6,144 steps, sharpe=+3654273230.92)
#   Task 803: target_sharpe_reached (30,000 steps, sharpe=+248677193.18)
#
# Meta-iter 176: Outer update (FOMAML) amb 5 tasques
#   Task 804: target_sharpe_reached (10,240 steps, sharpe=+3141677196.48)
#   Task 805: target_sharpe_reached (10,240 steps, sharpe=+1200895130.57)
#   Task 806: FAIL (max_steps_timeout)
#   Task 807: target_sharpe_reached (6,144 steps, sharpe=+15497124.21)
#   Batch timeout: 3 tasks in 389.7s
#
# Meta-iter 177: Outer update (FOMAML) amb 3 tasques
#   Task 808: target_sharpe_reached (10,240 steps, sharpe=+2682061039.25)
#   Task 809: target_sharpe_reached (6,144 steps, sharpe=+2525161619.72)
#   Task 810: target_sharpe_reached (6,144 steps, sharpe=+1173685146.95)
#   Task 811: SKIP (gradient_explosion)
#   Batch timeout: 3 tasks in 393.1s
#
# Meta-iter 178: Outer update (FOMAML) amb 3 tasques
#   Task 812: target_sharpe_reached (18,432 steps, sharpe=+96140405.23)
#   Task 813: target_sharpe_reached (8,192 steps, sharpe=+1743226628.13)
#   Task 814: SKIP (gradient_explosion)
#   Task 815: target_sharpe_reached (6,144 steps, sharpe=+1594441137.05)
#   Task 816: target_sharpe_reached (18,432 steps, sharpe=+344756715.00)
#   Batch timeout: 4 tasks in 373.5s
#
# Meta-iter 179: Outer update (FOMAML) amb 4 tasques
#   Task 817: SKIP (gradient_explosion)
#   Task 818: target_sharpe_reached (20,480 steps, sharpe=+1792269313.70)
#   Task 819: target_sharpe_reached (14,336 steps, sharpe=+3827173664.18)
#   Task 820: SKIP (gradient_explosion)
#   Task 821: target_sharpe_reached (6,144 steps, sharpe=+1936166332.68)
#   Batch timeout: 3 tasks in 360.6s
#
# Meta-iter 180: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-24.5762 ret=-20.11% best=-11.9647 [plateau 17/20]
#
#   Task 822: target_sharpe_reached (6,144 steps, sharpe=+4661596034.12)
#   Task 823: target_sharpe_reached (8,192 steps, sharpe=+847182572.34)
#   Task 824: SKIP (gradient_explosion)
#   Task 825: target_sharpe_reached (6,144 steps, sharpe=+710675171.75)
#   Task 826: target_sharpe_reached (10,240 steps, sharpe=+1946564141.33)
#   Task 827: SKIP (gradient_explosion)
#   Batch timeout: 4 tasks in 318.4s
#
# Meta-iter 181: Outer update (FOMAML) amb 4 tasques
#   Task 828: target_sharpe_reached (26,112 steps, sharpe=+228701143.73)
#   Task 829: SKIP (gradient_explosion)
#   Task 830: target_sharpe_reached (6,144 steps, sharpe=+3286995405.47)
#   Task 831: FAIL (max_steps_timeout)
#   Task 832: FAIL (max_steps_timeout)
#   Task 833: target_sharpe_reached (28,160 steps, sharpe=+3470973740.05)
#   Batch timeout: 3 tasks in 933.6s
#
# Meta-iter 182: Outer update (FOMAML) amb 3 tasques
#   Task 834: target_sharpe_reached (6,144 steps, sharpe=+2813825944.63)
#   Task 835: FAIL (max_steps_timeout)
#   Task 836: target_sharpe_reached (20,480 steps, sharpe=+9937982.89)
#   Task 837: target_sharpe_reached (8,192 steps, sharpe=+2307637358.37)
#   Batch timeout: 3 tasks in 461.8s
#
# Meta-iter 183: Outer update (FOMAML) amb 3 tasques
#   Task 838: SKIP (gradient_explosion)
#   Task 839: performance_plateau (18,432 steps, sharpe=-172019852.93)
#   Task 840: target_sharpe_reached (10,240 steps, sharpe=+656871132.12)
#   Task 841: target_sharpe_reached (12,288 steps, sharpe=+461895894.16)
#   Batch timeout: 3 tasks in 373.5s
#
# Meta-iter 184: Outer update (FOMAML) amb 3 tasques
#   Task 842: SKIP (gradient_explosion)
#   Task 843: SKIP (gradient_explosion)
#   Task 844: SKIP (gradient_explosion)
#   Task 845: SKIP (gradient_explosion)
#   Task 846: SKIP (gradient_explosion)
#   Task 847: target_sharpe_reached (6,144 steps, sharpe=+2158294523.07)
#   Task 848: target_sharpe_reached (12,288 steps, sharpe=+1098705111.29)
#   Task 849: performance_plateau (18,432 steps, sharpe=-1255000397.52)
#   Batch timeout: 3 tasks in 512.9s
#
# Meta-iter 185: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-14.8810 ret=-19.71% best=-11.9647 [plateau 18/20]
#
#   Task 850: target_sharpe_reached (18,432 steps, sharpe=+2372381452.69)
#   Task 851: target_sharpe_reached (6,144 steps, sharpe=+1703376823.04)
#   Task 852: target_sharpe_reached (12,288 steps, sharpe=+357512220.03)
#   Batch timeout: 3 tasks in 349.1s
#
# Meta-iter 186: Outer update (FOMAML) amb 3 tasques
#   Task 853: target_sharpe_reached (6,144 steps, sharpe=+2837442496.68)
#   Task 854: FAIL (max_steps_timeout)
#   Task 855: target_sharpe_reached (6,144 steps, sharpe=+2707988721.04)
#   Task 856: target_sharpe_reached (6,144 steps, sharpe=+2006491622.68)
#   Batch timeout: 3 tasks in 390.9s
#
# Meta-iter 187: Outer update (FOMAML) amb 3 tasques
#   Task 857: target_sharpe_reached (6,144 steps, sharpe=+2944380082.46)
#   Task 858: target_sharpe_reached (10,240 steps, sharpe=+3264346258.95)
#   Task 859: target_sharpe_reached (8,192 steps, sharpe=+1604658946.63)
#   Task 860: target_sharpe_reached (22,016 steps, sharpe=+388159334.00)
#   Batch timeout: 4 tasks in 371.2s
#
# Meta-iter 188: Outer update (FOMAML) amb 4 tasques
#   Task 861: target_sharpe_reached (16,384 steps, sharpe=+48745481.43)
#   Task 862: FAIL (max_steps_timeout)
#   Task 863: target_sharpe_reached (6,144 steps, sharpe=+742278167.91)
#   Task 864: target_sharpe_reached (6,144 steps, sharpe=+1860951773.89)
#   Batch timeout: 3 tasks in 510.9s
#
# Meta-iter 189: Outer update (FOMAML) amb 3 tasques
#   Task 865: FAIL (max_steps_timeout)
#   Task 866: target_sharpe_reached (10,240 steps, sharpe=+1314225158.58)
#   Task 867: target_sharpe_reached (8,192 steps, sharpe=+1591064218.80)
#   Task 868: FAIL (max_steps_timeout)
#   Task 869: target_sharpe_reached (10,240 steps, sharpe=+353466136.90)
#   Batch timeout: 3 tasks in 699.5s
#
# Meta-iter 190: Outer update (FOMAML) amb 3 tasques
#   Val: sharpe=-39.0844 ret=-20.11% best=-11.9647 [plateau 19/20]
#
#   Task 870: FAIL (max_steps_timeout)
#   Task 871: target_sharpe_reached (24,064 steps, sharpe=+794508309.08)
#   Task 872: target_sharpe_reached (6,144 steps, sharpe=+294331650.91)
#   Task 873: target_sharpe_reached (8,192 steps, sharpe=+2820497980.33)
#   Batch timeout: 3 tasks in 612.8s
#
# Meta-iter 191: Outer update (FOMAML) amb 3 tasques
#   Task 874: performance_plateau (30,000 steps, sharpe=-1697535233.32)
#   Task 875: target_sharpe_reached (6,144 steps, sharpe=+6892525776.43)
#   Task 876: FAIL (max_steps_timeout)
#   Task 877: target_sharpe_reached (20,480 steps, sharpe=+6136420445.66)
#   Batch timeout: 3 tasks in 627.5s
#
# Meta-iter 192: Outer update (FOMAML) amb 3 tasques
#   Task 878: FAIL (max_steps_timeout)
#   Task 879: performance_plateau (14,336 steps, sharpe=-841725729.22)
#   Task 880: FAIL (max_steps_timeout)
#   Task 881: FAIL (max_steps_timeout)
#   Task 882: target_sharpe_reached (6,144 steps, sharpe=+244608133.38)
#   Task 883: SKIP (gradient_explosion)
#   Task 884: target_sharpe_reached (20,480 steps, sharpe=+818463770.74)
#   Batch timeout: 3 tasks in 1155.9s
#
# Meta-iter 193: Outer update (FOMAML) amb 3 tasques
#   Task 885: target_sharpe_reached (6,144 steps, sharpe=+4159703566.09)
#   Task 886: target_sharpe_reached (6,144 steps, sharpe=+3088010029.29)
#   Task 887: target_sharpe_reached (6,144 steps, sharpe=+3192915098.96)
#   Task 888: SKIP (gradient_explosion)
#   Task 889: target_sharpe_reached (14,336 steps, sharpe=+635470587.69)
#   Task 890: target_sharpe_reached (16,384 steps, sharpe=+1180918161.43)
#
# Meta-iter 194: Outer update (FOMAML) amb 5 tasques
#   Task 891: performance_plateau (26,112 steps, sharpe=+0.00)
#   Task 892: SKIP (gradient_explosion)
#   Task 893: target_sharpe_reached (6,144 steps, sharpe=+2340087744.04)
#   Task 894: target_sharpe_reached (6,144 steps, sharpe=+2983456200.01)
#   Task 895: target_sharpe_reached (10,240 steps, sharpe=+3123480668.33)
#   Batch timeout: 4 tasks in 311.6s
#
# Meta-iter 195: Outer update (FOMAML) amb 4 tasques
#   Val: sharpe=-14.3455 ret=-19.69% best=-11.9647 [plateau 20/20]
#
# ✗ Meta early stopping: 20 evals sense millora
#
# Restored best meta-agent: val_sharpe=-11.9647
#
# ============================================================
# Meta-entrenament completat: 2219.8 min
#   Total meta-iters: 195
#   Total tasks processades: 895
#   Best val sharpe: -11.9647
#   Emissions meta: 772.25 g CO2eq
# ============================================================
#
# Meta-checkpoint desat: checkpoints_sparse\ppo_fomaml_meta_new_adaptative.pt
#
# Millor val: Sharpe=-11.9647  Ret=-19.76%  iter 95

# %%
# =============================================================================
# CEL·LA 10 — ANÀLISI INNER DIAGNOSTICS
# =============================================================================

if inner_diagnostics:
    print(f'\nInner Loop Diagnostics ({len(inner_diagnostics)} tasques processades)\n')
    print('='*80)
    
    # Estadístiques de convergència
    converged = [d for d in inner_diagnostics if d['converged']]
    reasons = {}
    for d in inner_diagnostics:
        r = d['reason']
        reasons[r] = reasons.get(r, 0) + 1
    
    print(f'Tasques convergides: {len(converged)}/{len(inner_diagnostics)} '
          f'({len(converged)/len(inner_diagnostics)*100:.1f}%)')
    print(f'\nRaons de finalització:')
    for reason, count in sorted(reasons.items(), key=lambda x: -x[1]):
        print(f'  {reason:30s}: {count:4d} ({count/len(inner_diagnostics)*100:5.1f}%)')
    
    # Estadístiques de steps
    steps = [d['steps'] for d in converged]
    if steps:
        print(f'\nSteps per tasca convergida:')
        print(f'  Mean: {np.mean(steps):,.0f}')
        print(f'  Median: {np.median(steps):,.0f}')
        print(f'  Min: {np.min(steps):,.0f}')
        print(f'  Max: {np.max(steps):,.0f}')
    
    # Sharpe final
    sharpes = [d['final_sharpe'] for d in converged]
    if sharpes:
        print(f'\nSharpe final (tasques convergides):')
        print(f'  Mean: {np.mean(sharpes):+.4f}')
        print(f'  Median: {np.median(sharpes):+.4f}')
        print(f'  Min: {np.min(sharpes):+.4f}')
        print(f'  Max: {np.max(sharpes):+.4f}')
    
    print('='*80)
else:
    print('No inner diagnostics disponibles')
# Out:
# Inner Loop Diagnostics (895 tasques processades)
#
# ================================================================================
# Tasques convergides: 743/895 (83.0%)
#
# Raons de finalització:
#   target_sharpe_reached         :  549 ( 61.3%)
#   max_steps_timeout             :  152 ( 17.0%)
#   gradient_explosion            :  124 ( 13.9%)
#   performance_plateau           :   70 (  7.8%)
#
# Steps per tasca convergida:
#   Mean: 11,268
#   Median: 8,192
#   Min: 6,144
#   Max: 30,000
#
# Sharpe final (tasques convergides):
#   Mean: +1269839237.7678
#   Median: +829442179.1992
#   Min: -2263324985.2878
#   Max: +12733770023.8165
# ================================================================================

# %%
# =============================================================================
# CEL·LA 11 — META-TRAINING CURVES
# =============================================================================

if meta_history:
    fig, axes = plt.subplots(2, 2, figsize=(16, 10))
    
    iters = [h['meta_iter'] for h in meta_history]
    ret_v = [h['val_return'] for h in meta_history]
    sh_v  = [h['val_sharpe'] for h in meta_history]
    n_adapted = [h['n_adapted'] for h in meta_history]
    
    # Val Return
    axes[0, 0].plot(iters, ret_v, 'o-', color='#1f77b4', lw=2)
    axes[0, 0].axhline(0, color='gray', ls='--', lw=0.8)
    axes[0, 0].set_title('Reptile Adaptatiu — Retorn mig (val)')
    axes[0, 0].set_xlabel('Meta-iteració')
    axes[0, 0].set_ylabel('Return (%)')
    axes[0, 0].grid(alpha=0.3)
    
    # Val Sharpe
    axes[0, 1].plot(iters, sh_v, 'o-', color='#2ca02c', lw=2)
    axes[0, 1].axhline(0, color='gray', ls='--', lw=0.8)
    if meta_criteria.target_val_sharpe is not None:
        axes[0, 1].axhline(meta_criteria.target_val_sharpe, color='red', ls='--', lw=1.0, alpha=0.5, label=f'Target ({meta_criteria.target_val_sharpe})')
    axes[0, 1].set_title('Reptile Adaptatiu — Sharpe (val)')
    axes[0, 1].set_xlabel('Meta-iteració')
    axes[0, 1].set_ylabel('Sharpe')
    axes[0, 1].legend()
    axes[0, 1].grid(alpha=0.3)
    
    # N tasques adaptades per batch
    axes[1, 0].plot(iters, n_adapted, 'o-', color='#ff7f0e', lw=2)
    axes[1, 0].axhline(outer_trigger.batch_size, color='red', ls='--', lw=1.0, alpha=0.5, label=f'Target batch ({outer_trigger.batch_size})')
    axes[1, 0].set_title('Tasques convergides per outer update')
    axes[1, 0].set_xlabel('Meta-iteració')
    axes[1, 0].set_ylabel('N tasques')
    axes[1, 0].legend()
    axes[1, 0].grid(alpha=0.3)
    
    # Millora acumulada
    if len(sh_v) > 0:
        improvement = [s - sh_v[0] for s in sh_v]
        axes[1, 1].plot(iters, improvement, 'o-', color='#d62728', lw=2)
        axes[1, 1].axhline(0, color='gray', ls='--', lw=0.8)
        axes[1, 1].set_title('Millora Sharpe des inici')
        axes[1, 1].set_xlabel('Meta-iteració')
        axes[1, 1].set_ylabel('Δ Sharpe')
        axes[1, 1].grid(alpha=0.3)
    
    plt.suptitle('NB06d — PPO Reptile Adaptatiu Meta-training', fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.savefig(RESULTS / 'meta_training_curves.png', dpi=120, bbox_inches='tight')
    plt.show()
else:
    print('Sense historial de meta-entrenament')

# %% [markdown]
# ## Continua amb avaluació (rolling-window, etc.)
#
# A partir d'aquí pots copiar les cel·les d'avaluació del notebook original (CEL·LA 12-18):
# - `ppo_walk_forward`
# - `ppo_rolling_meta_eval` (amb fast-adaptation)
# - Equity curves
# - Action distribution
# - Comparative table
#
# Les funcions d'avaluació són idèntiques, només canvia el `meta_policy` que és el resultat del sistema adaptatiu.
